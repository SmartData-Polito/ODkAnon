# %%
import pandas as pd
import random
import numpy as np
import seaborn as sns
import ast
import json
import os
import re
import itertools
import folium
import hdbscan
import h3

from scipy.spatial.transform import Rotation as R
from scipy.spatial.distance import euclidean
from scipy.spatial.distance import pdist, squareform
from sklearn.cluster import DBSCAN
from sklearn.neighbors import NearestNeighbors
import matplotlib.pyplot as plt
import matplotlib.pylab as pl
import matplotlib.patches as patches
from pydp.algorithms.numerical_mechanisms import LaplaceMechanism
from itertools import combinations
from collections import defaultdict
from collections import Counter

# %%
file_path = "C:\\Users\\dmc\\Desktop\\Privacy-and-Anonymization-of-Trajectories-of-Data\\toyDataset\\torino_3_mesi.csv"

df = pd.read_csv(file_path)
print(df)

def is_in_torino_string(coord_str):
    try:
        # Trova tutte le coppie di float nella stringa
        matches = re.findall(r'\[\s*([\d.]+)\s*,\s*([\d.]+)\s*\]', coord_str)
        if not matches:
            return False
        for lon_str, lat_str in matches:
            lon = float(lon_str)
            lat = float(lat_str)
            if not (6.0 <= lon <= 19.0 and 36.0 <= lat <= 47.5):
                return False
        return True
    except Exception:
        return False

df = df[df['coordinates'].apply(is_in_torino_string)]

df['coordinates'] = df['coordinates'].apply(ast.literal_eval)

df['start_lon'] = df['coordinates'].apply(lambda x: x[0][0])
df['start_lat'] = df['coordinates'].apply(lambda x: x[0][1])
df['end_lon'] = df['coordinates'].apply(lambda x: x[-1][0])
df['end_lat'] = df['coordinates'].apply(lambda x: x[-1][1])

h3_resolution = 10

df['start_h3'] = df.apply(lambda row: h3.latlng_to_cell(row['start_lat'], row['start_lon'], h3_resolution), axis=1)
df['end_h3'] = df.apply(lambda row: h3.latlng_to_cell(row['end_lat'], row['end_lon'], h3_resolution), axis=1)

od_matrix_first = df.groupby(['start_h3', 'end_h3']).size().reset_index(name='count')

parent_hexes = ["871f98402ffffff", "871f98403ffffff", "871f98401ffffff", "871f98400ffffff", "871f98405ffffff", 
                "871f98404ffffff", "871f9840effffff", "871f98406ffffff", "871f98411ffffff", "871f9841cffffff", 
                "871f9841effffff", "871f9841effffff", "871f98415ffffff", "871f9841dffffff", "871f98413ffffff"]

target_resolution = 10
start_valid_h3 = set()
end_valid_h3 = set()

for parent in parent_hexes:
    children = h3.cell_to_children(parent, target_resolution)
    for child in children:
        start_valid_h3.add(child)
        end_valid_h3.add(child)

mask = (
    (od_matrix_first["start_h3"].isin(start_valid_h3))
    & (od_matrix_first["end_h3"].isin(end_valid_h3))
)

od_matrix_first = od_matrix_first[mask].copy()

od_matrix = od_matrix_first.copy()

od_matrix
# Out:
#         Unnamed: 0   init_time  final_time        plate                vin  \
# 0                0  1481650842  1481650980  325/FF050VV  WME4533421K152585
# 1                1  1481651119  1481651409  297/FF039SJ  WME4533421K152474
# 2                2  1481651458  1481651507  122/FF130NT  WME4533421K152254
# 3                3  1481651458  1481651507  039/FF800KW  WME4533421K148970
# 4                4  1481651458  1481651507  297/FF039SJ  WME4533421K152474
# ...            ...         ...         ...          ...                ...
# 873235      873235  1517404040  1517404092  314/FF289SJ  WME4533421K151750
# 873236      873236  1517404040  1517404092  417/FK618LX  WME4530421Y135096
# 873237      873237  1517404092  1517404148  276/FF187SJ  WME4533421K152055
# 873238      873238  1517404092  1517404245  106/FF094NT  WME4533421K148895
# 873239      873239  1517404195  1517404245  264/FF157SJ  WME4533421K150729
#
#                                        coordinates
# 0       [[7.67936, 45.07162], [7.67936, 45.07162]]
# 1       [[7.65013, 45.02163], [7.64055, 45.02211]]
# 2       [[7.70481, 45.05988], [7.70481, 45.05988]]
# 3       [[7.66921, 45.05716], [7.66921, 45.05716]]
# 4       [[7.64055, 45.02211], [7.64055, 45.02211]]
# ...                                            ...
# 873235  [[7.67408, 45.05101], [7.67408, 45.05101]]
# 873236  [[7.65445, 45.08599], [7.65445, 45.08599]]
# 873237  [[7.67592, 45.06657], [7.67592, 45.06657]]
# 873238  [[7.66493, 45.06752], [7.65795, 45.05541]]
# 873239  [[7.65535, 45.04939], [7.65535, 45.04939]]
#
# [873240 rows x 6 columns]
#                start_h3           end_h3  count
# 0       8a1f98400007fff  8a1f98400007fff     23
# 1       8a1f98400007fff  8a1f98400017fff      1
# 2       8a1f98400007fff  8a1f9840002ffff      1
# 3       8a1f98400007fff  8a1f98400037fff      1
# 4       8a1f98400007fff  8a1f98400207fff      1
# ...                 ...              ...    ...
# 493384  8a1f9841edb7fff  8a1f9841e78ffff      1
# 493385  8a1f9841edb7fff  8a1f9841e99ffff      1
# 493386  8a1f9841edb7fff  8a1f9841eac7fff      1
# 493387  8a1f9841edb7fff  8a1f9841eae7fff      1
# 493388  8a1f9841edb7fff  8a1f9841edb7fff     60
#
# [458918 rows x 3 columns]

# %%
filtered_df = df.merge(
    od_matrix[['start_h3', 'end_h3']],
    on=['start_h3', 'end_h3'],
    how='inner'
)

# %%
import pandas as pd
import h3
from collections import defaultdict, deque
from typing import Dict, Set, List, Optional, Tuple

class H3TreeNode:
    """Nodo dell'albero gerarchico H3"""
    def __init__(self, h3_id: str, resolution: int, count: int = 0):
        self.h3_id = h3_id
        self.resolution = resolution
        self.count = count
        self.children: Dict[str, 'H3TreeNode'] = {}
        self.parent: Optional['H3TreeNode'] = None
    
    def add_child(self, child: 'H3TreeNode'):
        """Aggiunge un figlio al nodo"""
        self.children[child.h3_id] = child
        child.parent = self
    
    def add_count(self, count: int):
        """Aggiunge conteggio al nodo e propaga verso l'alto"""
        self.count += count
        if self.parent:
            self.parent.add_count(count)
    
    def __repr__(self):
        return f"H3Node(id={self.h3_id}, res={self.resolution}, count={self.count}, children={len(self.children)})"

class H3HierarchicalTree:
    def __init__(self, od_matrix: pd.DataFrame, target_resolution: int = 10, hex_column: str = 'start_h3'):
        self.od_matrix = od_matrix
        self.target_resolution = target_resolution
        self.hex_column = hex_column  # 'start_h3' o 'end_h3'
        self.nodes: Dict[str, H3TreeNode] = {}
        self.root = None
        self.min_resolution = None  # Sarà calcolato dinamicamente
        
    def get_all_hexagons(self) -> Set[str]:
        """Estrae tutti gli esagoni unici dalla colonna specificata"""
        return set(self.od_matrix[self.hex_column].unique())
    
    def get_resolution_coverage(self, hexagons: Set[str], target_res: int) -> Set[str]:
        """
        Ottiene tutti gli esagoni di risoluzione target che coprono l'area
        definita dagli esagoni di input
        """
        coverage_hexagons = set()
        
        for hex_id in hexagons:
            current_res = h3.get_resolution(hex_id)
            
            if current_res == target_res:
                coverage_hexagons.add(hex_id)
            elif current_res < target_res:
                # Dobbiamo espandere a risoluzione più alta
                children = self._get_all_children_at_resolution(hex_id, target_res)
                coverage_hexagons.update(children)
            else:
                # Dobbiamo salire a risoluzione più bassa
                parent = h3.cell_to_parent(hex_id, target_res)
                coverage_hexagons.add(parent)
        
        return coverage_hexagons
    
    def find_optimal_min_resolution(self, hexagons: Set[str]) -> int:
        """
        Trova la risoluzione più alta dove c'è ancora un solo nodo che copre tutti gli esagoni
        """
        print("🔍 Analizzando risoluzione ottimale per radice...")
        
        # Per ogni risoluzione da 0 alla target, conta quanti nodi servono per coprire tutti gli esagoni
        resolution_stats = {}
        
        for resolution in range(0, self.target_resolution + 1):
            ancestors = set()
            for hex_id in hexagons:
                current_res = h3.get_resolution(hex_id)
                if current_res >= resolution:
                    ancestor = h3.cell_to_parent(hex_id, resolution)
                    ancestors.add(ancestor)
                else:
                    # L'esagono è già a risoluzione più bassa, aggiungi direttamente
                    ancestors.add(hex_id)
            
            resolution_stats[resolution] = len(ancestors)
            print(f"  - Risoluzione {resolution}: {len(ancestors)} nodi")
        
        # Trova la risoluzione più alta con count = 1
        optimal_resolution = 0
        for resolution in range(self.target_resolution, -1, -1):
            if resolution_stats[resolution] == 1:
                optimal_resolution = resolution
                break
        
        print(f"✅ Risoluzione ottimale trovata: {optimal_resolution}")
        return optimal_resolution
    
    def get_siblings(self, node_id: str) -> List[str]:
        """Restituisce gli h3_id dei nodi fratelli di node_id (stesso genitore, escluso node_id stesso)"""
        if node_id not in self.nodes:
            return []

        node = self.nodes[node_id]
        parent = node.parent
        if parent is None:
            # Nodo root, non ha fratelli
            return []

        siblings = [child.h3_id for child in parent.children.values() if child.h3_id != node_id]
        return siblings
    
    def get_parent(self, node_id: str) -> Optional[str]:
        """Restituisce l'h3_id del genitore del nodo dato, o None se root o nodo non trovato"""
        if node_id not in self.nodes:
            return None
        node = self.nodes[node_id]
        if node.parent is None:
            return None
        return node.parent.h3_id
    
    def _get_all_children_at_resolution(self, hex_id: str, target_res: int) -> Set[str]:
        """Ricorsivamente ottiene tutti i figli a una risoluzione specifica"""
        current_res = h3.get_resolution(hex_id)
        
        if current_res == target_res:
            return {hex_id}
        elif current_res > target_res:
            # Non dovrebbe succedere in questo contesto
            return set()
        
        children = set()
        direct_children = h3.cell_to_children(hex_id, current_res + 1)
        
        for child in direct_children:
            children.update(self._get_all_children_at_resolution(child, target_res))
        
        return children
    
    def build_hierarchy_path(self, hex_id: str, min_resolution: int) -> List[str]:
        """Costruisce il percorso gerarchico da un esagono fino alla risoluzione minima"""
        path = [hex_id]
        current = hex_id
        current_res = h3.get_resolution(current)
        
        while current_res > min_resolution:
            parent = h3.cell_to_parent(current, current_res - 1)
            path.append(parent)
            current = parent
            current_res -= 1
        
        return path
    
    def create_tree_structure(self):
        """Crea la struttura dell'albero ottimizzato"""
        target_hexagons = self.get_all_hexagons()
        
        # Ottieni copertura completa alla risoluzione target
        coverage_hexagons = self.get_resolution_coverage(target_hexagons, self.target_resolution)
        
        # Trova la risoluzione minima ottimale (quella più alta con count=1)
        self.min_resolution = self.find_optimal_min_resolution(coverage_hexagons)
        
        print(f"🏗️ Costruendo albero da risoluzione {self.min_resolution} a {self.target_resolution}")
        
        # Costruisci tutti i percorsi gerarchici
        all_paths = []
        for hex_id in coverage_hexagons:
            path = self.build_hierarchy_path(hex_id, self.min_resolution)
            all_paths.append(path)
        
        # Crea tutti i nodi
        for path in all_paths:
            for hex_id in path:
                if hex_id not in self.nodes:
                    resolution = h3.get_resolution(hex_id)
                    self.nodes[hex_id] = H3TreeNode(hex_id, resolution)
        
        # Stabilisci relazioni parent-child
        for path in all_paths:
            for i in range(len(path) - 1):
                child_id = path[i]
                parent_id = path[i + 1]
                self.nodes[parent_id].add_child(self.nodes[child_id])
        
        # Identifica la radice
        self.root = self.nodes[self._find_root_hexagon(coverage_hexagons, self.min_resolution)]
        
        return self
    
    def _find_root_hexagon(self, hexagons: Set[str], min_resolution: int) -> str:
        """Trova l'esagono radice che contiene tutti gli altri"""
        sample_hex = next(iter(hexagons))
        return h3.cell_to_parent(sample_hex, min_resolution)
    
    def populate_counts(self):
        """Popola i conteggi nell'albero basandosi sui dati OD"""
        
        # Raggruppa per esagono della colonna specificata
        hex_counts = self.od_matrix.groupby(self.hex_column)['count'].sum().to_dict()
        
        # Per ogni esagono nei dati, aggiungi il conteggio all'albero
        for hex_id, count in hex_counts.items():
            # Trova a quale esagono di risoluzione target corrisponde
            target_hex = self._map_to_target_resolution(hex_id)
            
            if target_hex in self.nodes:
                self.nodes[target_hex].add_count(count)
            else:
                print(f"⚠️ Avviso: esagono {target_hex} non trovato nell'albero")
        
        return self
    
    def _map_to_target_resolution(self, hex_id: str) -> str:
        """Mappa un esagono alla risoluzione target"""
        current_res = h3.get_resolution(hex_id)
        
        if current_res == self.target_resolution:
            return hex_id
        elif current_res < self.target_resolution:
            # Prendi il primo figlio disponibile (potrebbe essere migliorato)
            children = self._get_all_children_at_resolution(hex_id, self.target_resolution)
            return next(iter(children)) if children else hex_id
        else:
            return h3.cell_to_parent(hex_id, self.target_resolution)
    
    def get_tree_statistics(self) -> Dict:
        """Ottiene statistiche dell'albero"""
        if not self.root:
            return {}
        
        stats = {
            'total_nodes': len(self.nodes),
            'root_resolution': self.root.resolution,
            'min_resolution': self.min_resolution,
            'target_resolution': self.target_resolution,
            'total_trips': self.root.count,
            'nodes_by_resolution': defaultdict(int),
            'resolution_range': f"{self.min_resolution} → {self.target_resolution}"
        }
        
        for node in self.nodes.values():
            stats['nodes_by_resolution'][node.resolution] += 1
        
        return stats
    
    def print_tree(self, max_children_per_level: int = 10):
        """Stampa l'albero completo con tutti i livelli"""
        if not self.root:
            print("❌ Albero non costruito")
            return
        
        print(f"\n🌳 STRUTTURA ALBERO OTTIMIZZATA")
        print(f"📏 Range risoluzione: {self.min_resolution} → {self.target_resolution}")
        print("=" * 80)
        
        def _print_node(node: H3TreeNode, depth: int = 0, is_last: bool = True, prefix: str = ""):
            # Crea il connettore appropriato
            connector = "└─ " if is_last else "├─ "
            print(f"{prefix}{connector}{node.h3_id} (res:{node.resolution}, count:{node.count}, children:{len(node.children)})")
            
            # Prepara il prefisso per i figli
            if is_last:
                child_prefix = prefix + "   "
            else:
                child_prefix = prefix + "│  "
            
            # Mostra tutti i figli (o solo i primi se troppi)
            children_list = list(node.children.values())
            
            if len(children_list) <= max_children_per_level:
                # Mostra tutti i figli
                for i, child in enumerate(children_list):
                    is_last_child = (i == len(children_list) - 1)
                    _print_node(child, depth + 1, is_last_child, child_prefix)
            else:
                # Mostra solo i primi N figli + riassunto
                for i in range(max_children_per_level):
                    child = children_list[i]
                    is_last_child = (i == max_children_per_level - 1) and (len(children_list) == max_children_per_level)
                    _print_node(child, depth + 1, is_last_child, child_prefix)
                
                # Aggiungi riassunto per i rimanenti
                remaining = len(children_list) - max_children_per_level
                print(f"{child_prefix}└─ ... e altri {remaining} figli con stesso pattern")
        
        _print_node(self.root, 0, True, "")

# Esempio di utilizzo aggiornato
def create_h3_hierarchical_tree(od_matrix_df: pd.DataFrame, target_resolution: int = 11, hex_column: str = 'start_h3'):
    """
    Crea un albero gerarchico H3 ottimizzato dal dataset OD matrix
    
    Args:
        od_matrix_df: DataFrame con colonne 'start_h3', 'end_h3', 'count'
        target_resolution: Risoluzione target per le foglie dell'albero
        hex_column: Colonna da analizzare ('start_h3' o 'end_h3')
    
    Returns:
        H3HierarchicalTree: Albero gerarchico costruito e ottimizzato
    """
    
    tree = H3HierarchicalTree(od_matrix_df, target_resolution, hex_column)
    tree.create_tree_structure()
    tree.populate_counts()
    
    stats = tree.get_tree_statistics()
    print(f"\n📈 STATISTICHE ALBERO OTTIMIZZATO ({hex_column.upper()})")
    print("=" * 50)
    print(f"• Nodi totali: {stats['total_nodes']:,}")
    print(f"• Range risoluzione: {stats['resolution_range']}")
    print(f"• Risoluzione radice: {stats['root_resolution']}")
    print(f"• Risoluzione foglie: {stats['target_resolution']}")
    print(f"• Viaggi totali: {stats['total_trips']:,}")
    print(f"• Nodi per risoluzione:")
    for res in sorted(stats['nodes_by_resolution'].keys()):
        print(f"  - Risoluzione {res}: {stats['nodes_by_resolution'][res]:,} nodi")
    
    # Calcola risparmio in nodi
    total_resolutions_possible = target_resolution + 1  # da 0 a target
    resolutions_used = len(stats['nodes_by_resolution'])
    resolutions_saved = total_resolutions_possible - resolutions_used
    
    print(f"\n💡 OTTIMIZZAZIONI:")
    print(f"• Risoluzioni risparmiate: {resolutions_saved}")
    print(f"• Efficienza albero: {resolutions_used}/{total_resolutions_possible} livelli utilizzati")
    
    tree.print_tree()
    
    return tree

# %%
tree_start = create_h3_hierarchical_tree(od_matrix, target_resolution=10, hex_column='start_h3')
tree_end = create_h3_hierarchical_tree(od_matrix, target_resolution=10, hex_column='end_h3')
# Out:
# 🔍 Analizzando risoluzione ottimale per radice...
#   - Risoluzione 0: 1 nodi
#   - Risoluzione 1: 1 nodi
#   - Risoluzione 2: 1 nodi
#   - Risoluzione 3: 1 nodi
#   - Risoluzione 4: 1 nodi
#   - Risoluzione 5: 1 nodi
#   - Risoluzione 6: 4 nodi
#   - Risoluzione 7: 14 nodi
#   - Risoluzione 8: 90 nodi
#   - Risoluzione 9: 548 nodi
#   - Risoluzione 10: 3285 nodi
# ✅ Risoluzione ottimale trovata: 5
# 🏗️ Costruendo albero da risoluzione 5 a 10
#
# 📈 STATISTICHE ALBERO OTTIMIZZATO (START_H3)
# ==================================================
# • Nodi totali: 3,942
# • Range risoluzione: 5 → 10
# • Risoluzione radice: 5
# • Risoluzione foglie: 10
# • Viaggi totali: 789,222
# • Nodi per risoluzione:
#   - Risoluzione 5: 1 nodi
#   - Risoluzione 6: 4 nodi
#   - Risoluzione 7: 14 nodi
#   - Risoluzione 8: 90 nodi
#   - Risoluzione 9: 548 nodi
#   - Risoluzione 10: 3,285 nodi
#
# 💡 OTTIMIZZAZIONI:
# • Risoluzioni risparmiate: 5
# • Efficienza albero: 6/11 livelli utilizzati
#
# 🌳 STRUTTURA ALBERO OTTIMIZZATA
# 📏 Range risoluzione: 5 → 10
# ================================================================================
# └─ 851f9843fffffff (res:5, count:789222, children:4)
#    ├─ 861f98407ffffff (res:6, count:495290, children:7)
#    │  ├─ 871f98401ffffff (res:7, count:40101, children:7)
#    │  │  ├─ 881f984017fffff (res:8, count:6266, children:6)
#    │  │  │  ├─ 891f9840173ffff (res:9, count:1060, children:7)
#    │  │  │  │  ├─ 8a1f98401707fff (res:10, count:92, children:0)
#    │  │  │  │  ├─ 8a1f9840171ffff (res:10, count:74, children:0)
#    │  │  │  │  ├─ 8a1f98401727fff (res:10, count:255, children:0)
#    │  │  │  │  ├─ 8a1f98401717fff (res:10, count:168, children:0)
#    │  │  │  │  ├─ 8a1f9840170ffff (res:10, count:223, children:0)
#    │  │  │  │  ├─ 8a1f98401737fff (res:10, count:78, children:0)
#    │  │  │  │  └─ 8a1f9840172ffff (res:10, count:170, children:0)
#    │  │  │  ├─ 891f984016bffff (res:9, count:1846, children:7)
#    │  │  │  │  ├─ 8a1f984016b7fff (res:10, count:280, children:0)
#    │  │  │  │  ├─ 8a1f9840168ffff (res:10, count:298, children:0)
#    │  │  │  │  ├─ 8a1f98401697fff (res:10, count:333, children:0)
#    │  │  │  │  ├─ 8a1f984016a7fff (res:10, count:324, children:0)
#    │  │  │  │  ├─ 8a1f9840169ffff (res:10, count:249, children:0)
#    │  │  │  │  ├─ 8a1f984016affff (res:10, count:182, children:0)
#    │  │  │  │  └─ 8a1f98401687fff (res:10, count:180, children:0)
#    │  │  │  ├─ 891f9840163ffff (res:9, count:1103, children:5)
#    │  │  │  │  ├─ 8a1f98401627fff (res:10, count:10, children:0)
#    │  │  │  │  ├─ 8a1f9840161ffff (res:10, count:494, children:0)
#    │  │  │  │  ├─ 8a1f98401637fff (res:10, count:302, children:0)
#    │  │  │  │  ├─ 8a1f98401607fff (res:10, count:73, children:0)
#    │  │  │  │  └─ 8a1f98401617fff (res:10, count:224, children:0)
#    │  │  │  ├─ 891f984017bffff (res:9, count:1167, children:7)
#    │  │  │  │  ├─ 8a1f98401797fff (res:10, count:116, children:0)
#    │  │  │  │  ├─ 8a1f98401787fff (res:10, count:116, children:0)
#    │  │  │  │  ├─ 8a1f984017affff (res:10, count:110, children:0)
#    │  │  │  │  ├─ 8a1f9840179ffff (res:10, count:391, children:0)
#    │  │  │  │  ├─ 8a1f9840178ffff (res:10, count:123, children:0)
#    │  │  │  │  ├─ 8a1f984017a7fff (res:10, count:178, children:0)
#    │  │  │  │  └─ 8a1f984017b7fff (res:10, count:133, children:0)
#    │  │  │  ├─ 891f9840177ffff (res:9, count:899, children:5)
#    │  │  │  │  ├─ 8a1f9840176ffff (res:10, count:155, children:0)
#    │  │  │  │  ├─ 8a1f98401747fff (res:10, count:318, children:0)
#    │  │  │  │  ├─ 8a1f98401767fff (res:10, count:250, children:0)
#    │  │  │  │  ├─ 8a1f98401777fff (res:10, count:41, children:0)
#    │  │  │  │  └─ 8a1f98401757fff (res:10, count:135, children:0)
#    │  │  │  └─ 891f984016fffff (res:9, count:191, children:4)
#    │  │  │     ├─ 8a1f984016c7fff (res:10, count:3, children:0)
#    │  │  │     ├─ 8a1f984016dffff (res:10, count:1, children:0)
#    │  │  │     ├─ 8a1f984016d7fff (res:10, count:102, children:0)
#    │  │  │     └─ 8a1f984016f7fff (res:10, count:85, children:0)
#    │  │  ├─ 881f984015fffff (res:8, count:8509, children:7)
#    │  │  │  ├─ 891f9840147ffff (res:9, count:1466, children:7)
#    │  │  │  │  ├─ 8a1f9840146ffff (res:10, count:216, children:0)
#    │  │  │  │  ├─ 8a1f98401457fff (res:10, count:228, children:0)
#    │  │  │  │  ├─ 8a1f98401477fff (res:10, count:183, children:0)
#    │  │  │  │  ├─ 8a1f9840144ffff (res:10, count:124, children:0)
#    │  │  │  │  ├─ 8a1f98401447fff (res:10, count:354, children:0)
#    │  │  │  │  ├─ 8a1f9840145ffff (res:10, count:200, children:0)
#    │  │  │  │  └─ 8a1f98401467fff (res:10, count:161, children:0)
#    │  │  │  ├─ 891f9840157ffff (res:9, count:684, children:7)
#    │  │  │  │  ├─ 8a1f98401557fff (res:10, count:61, children:0)
#    │  │  │  │  ├─ 8a1f98401577fff (res:10, count:101, children:0)
#    │  │  │  │  ├─ 8a1f98401547fff (res:10, count:70, children:0)
#    │  │  │  │  ├─ 8a1f98401567fff (res:10, count:44, children:0)
#    │  │  │  │  ├─ 8a1f9840155ffff (res:10, count:110, children:0)
#    │  │  │  │  ├─ 8a1f9840154ffff (res:10, count:135, children:0)
#    │  │  │  │  └─ 8a1f9840156ffff (res:10, count:163, children:0)
#    │  │  │  ├─ 891f984014fffff (res:9, count:1566, children:7)
#    │  │  │  │  ├─ 8a1f984014e7fff (res:10, count:340, children:0)
#    │  │  │  │  ├─ 8a1f984014cffff (res:10, count:56, children:0)
#    │  │  │  │  ├─ 8a1f984014effff (res:10, count:185, children:0)
#    │  │  │  │  ├─ 8a1f984014d7fff (res:10, count:203, children:0)
#    │  │  │  │  ├─ 8a1f984014f7fff (res:10, count:443, children:0)
#    │  │  │  │  ├─ 8a1f984014dffff (res:10, count:27, children:0)
#    │  │  │  │  └─ 8a1f984014c7fff (res:10, count:312, children:0)
#    │  │  │  ├─ 891f984014bffff (res:9, count:1413, children:7)
#    │  │  │  │  ├─ 8a1f98401497fff (res:10, count:32, children:0)
#    │  │  │  │  ├─ 8a1f984014b7fff (res:10, count:255, children:0)
#    │  │  │  │  ├─ 8a1f9840149ffff (res:10, count:214, children:0)
#    │  │  │  │  ├─ 8a1f984014a7fff (res:10, count:401, children:0)
#    │  │  │  │  ├─ 8a1f984014affff (res:10, count:188, children:0)
#    │  │  │  │  ├─ 8a1f9840148ffff (res:10, count:287, children:0)
#    │  │  │  │  └─ 8a1f98401487fff (res:10, count:36, children:0)
#    │  │  │  ├─ 891f984015bffff (res:9, count:945, children:7)
#    │  │  │  │  ├─ 8a1f9840158ffff (res:10, count:267, children:0)
#    │  │  │  │  ├─ 8a1f984015b7fff (res:10, count:123, children:0)
#    │  │  │  │  ├─ 8a1f98401597fff (res:10, count:9, children:0)
#    │  │  │  │  ├─ 8a1f98401587fff (res:10, count:36, children:0)
#    │  │  │  │  ├─ 8a1f9840159ffff (res:10, count:101, children:0)
#    │  │  │  │  ├─ 8a1f984015a7fff (res:10, count:286, children:0)
#    │  │  │  │  └─ 8a1f984015affff (res:10, count:123, children:0)
#    │  │  │  ├─ 891f9840153ffff (res:9, count:1173, children:7)
#    │  │  │  │  ├─ 8a1f98401537fff (res:10, count:150, children:0)
#    │  │  │  │  ├─ 8a1f9840152ffff (res:10, count:46, children:0)
#    │  │  │  │  ├─ 8a1f9840151ffff (res:10, count:331, children:0)
#    │  │  │  │  ├─ 8a1f9840150ffff (res:10, count:331, children:0)
#    │  │  │  │  ├─ 8a1f98401527fff (res:10, count:276, children:0)
#    │  │  │  │  ├─ 8a1f98401507fff (res:10, count:29, children:0)
#    │  │  │  │  └─ 8a1f98401517fff (res:10, count:10, children:0)
#    │  │  │  └─ 891f9840143ffff (res:9, count:1262, children:7)
#    │  │  │     ├─ 8a1f9840141ffff (res:10, count:270, children:0)
#    │  │  │     ├─ 8a1f98401427fff (res:10, count:58, children:0)
#    │  │  │     ├─ 8a1f98401407fff (res:10, count:197, children:0)
#    │  │  │     ├─ 8a1f9840140ffff (res:10, count:169, children:0)
#    │  │  │     ├─ 8a1f98401417fff (res:10, count:244, children:0)
#    │  │  │     ├─ 8a1f9840142ffff (res:10, count:51, children:0)
#    │  │  │     └─ 8a1f98401437fff (res:10, count:273, children:0)
#    │  │  ├─ 881f984019fffff (res:8, count:4709, children:7)
#    │  │  │  ├─ 891f9840187ffff (res:9, count:937, children:7)
#    │  │  │  │  ├─ 8a1f98401857fff (res:10, count:68, children:0)
#    │  │  │  │  ├─ 8a1f9840185ffff (res:10, count:132, children:0)
#    │  │  │  │  ├─ 8a1f98401867fff (res:10, count:134, children:0)
#    │  │  │  │  ├─ 8a1f9840186ffff (res:10, count:259, children:0)
#    │  │  │  │  ├─ 8a1f98401877fff (res:10, count:181, children:0)
#    │  │  │  │  ├─ 8a1f9840184ffff (res:10, count:102, children:0)
#    │  │  │  │  └─ 8a1f98401847fff (res:10, count:61, children:0)
#    │  │  │  ├─ 891f984018fffff (res:9, count:535, children:7)
#    │  │  │  │  ├─ 8a1f984018dffff (res:10, count:67, children:0)
#    │  │  │  │  ├─ 8a1f984018f7fff (res:10, count:68, children:0)
#    │  │  │  │  ├─ 8a1f984018e7fff (res:10, count:125, children:0)
#    │  │  │  │  ├─ 8a1f984018effff (res:10, count:49, children:0)
#    │  │  │  │  ├─ 8a1f984018cffff (res:10, count:54, children:0)
#    │  │  │  │  ├─ 8a1f984018c7fff (res:10, count:90, children:0)
#    │  │  │  │  └─ 8a1f984018d7fff (res:10, count:82, children:0)
#    │  │  │  ├─ 891f9840193ffff (res:9, count:505, children:6)
#    │  │  │  │  ├─ 8a1f98401907fff (res:10, count:219, children:0)
#    │  │  │  │  ├─ 8a1f9840192ffff (res:10, count:50, children:0)
#    │  │  │  │  ├─ 8a1f98401927fff (res:10, count:35, children:0)
#    │  │  │  │  ├─ 8a1f9840190ffff (res:10, count:143, children:0)
#    │  │  │  │  ├─ 8a1f9840191ffff (res:10, count:13, children:0)
#    │  │  │  │  └─ 8a1f98401937fff (res:10, count:45, children:0)
#    │  │  │  ├─ 891f9840183ffff (res:9, count:841, children:7)
#    │  │  │  │  ├─ 8a1f9840180ffff (res:10, count:74, children:0)
#    │  │  │  │  ├─ 8a1f98401807fff (res:10, count:32, children:0)
#    │  │  │  │  ├─ 8a1f98401827fff (res:10, count:109, children:0)
#    │  │  │  │  ├─ 8a1f9840182ffff (res:10, count:397, children:0)
#    │  │  │  │  ├─ 8a1f98401837fff (res:10, count:15, children:0)
#    │  │  │  │  ├─ 8a1f9840181ffff (res:10, count:44, children:0)
#    │  │  │  │  └─ 8a1f98401817fff (res:10, count:170, children:0)
#    │  │  │  ├─ 891f984019bffff (res:9, count:469, children:6)
#    │  │  │  │  ├─ 8a1f984019b7fff (res:10, count:14, children:0)
#    │  │  │  │  ├─ 8a1f98401987fff (res:10, count:69, children:0)
#    │  │  │  │  ├─ 8a1f9840199ffff (res:10, count:52, children:0)
#    │  │  │  │  ├─ 8a1f9840198ffff (res:10, count:111, children:0)
#    │  │  │  │  ├─ 8a1f98401997fff (res:10, count:150, children:0)
#    │  │  │  │  └─ 8a1f984019affff (res:10, count:73, children:0)
#    │  │  │  ├─ 891f9840197ffff (res:9, count:768, children:7)
#    │  │  │  │  ├─ 8a1f98401947fff (res:10, count:126, children:0)
#    │  │  │  │  ├─ 8a1f9840196ffff (res:10, count:104, children:0)
#    │  │  │  │  ├─ 8a1f98401967fff (res:10, count:159, children:0)
#    │  │  │  │  ├─ 8a1f9840195ffff (res:10, count:123, children:0)
#    │  │  │  │  ├─ 8a1f9840194ffff (res:10, count:160, children:0)
#    │  │  │  │  ├─ 8a1f98401977fff (res:10, count:15, children:0)
#    │  │  │  │  └─ 8a1f98401957fff (res:10, count:81, children:0)
#    │  │  │  └─ 891f984018bffff (res:9, count:654, children:7)
#    │  │  │     ├─ 8a1f98401897fff (res:10, count:114, children:0)
#    │  │  │     ├─ 8a1f984018b7fff (res:10, count:62, children:0)
#    │  │  │     ├─ 8a1f98401887fff (res:10, count:48, children:0)
#    │  │  │     ├─ 8a1f984018affff (res:10, count:167, children:0)
#    │  │  │     ├─ 8a1f984018a7fff (res:10, count:28, children:0)
#    │  │  │     ├─ 8a1f9840188ffff (res:10, count:173, children:0)
#    │  │  │     └─ 8a1f9840189ffff (res:10, count:62, children:0)
#    │  │  ├─ 881f984011fffff (res:8, count:5140, children:7)
#    │  │  │  ├─ 891f984010bffff (res:9, count:1077, children:7)
#    │  │  │  │  ├─ 8a1f98401097fff (res:10, count:118, children:0)
#    │  │  │  │  ├─ 8a1f9840109ffff (res:10, count:180, children:0)
#    │  │  │  │  ├─ 8a1f984010b7fff (res:10, count:420, children:0)
#    │  │  │  │  ├─ 8a1f984010a7fff (res:10, count:77, children:0)
#    │  │  │  │  ├─ 8a1f9840108ffff (res:10, count:95, children:0)
#    │  │  │  │  ├─ 8a1f98401087fff (res:10, count:115, children:0)
#    │  │  │  │  └─ 8a1f984010affff (res:10, count:72, children:0)
#    │  │  │  ├─ 891f984011bffff (res:9, count:735, children:7)
#    │  │  │  │  ├─ 8a1f9840119ffff (res:10, count:131, children:0)
#    │  │  │  │  ├─ 8a1f984011b7fff (res:10, count:40, children:0)
#    │  │  │  │  ├─ 8a1f98401187fff (res:10, count:68, children:0)
#    │  │  │  │  ├─ 8a1f984011a7fff (res:10, count:58, children:0)
#    │  │  │  │  ├─ 8a1f984011affff (res:10, count:110, children:0)
#    │  │  │  │  ├─ 8a1f98401197fff (res:10, count:169, children:0)
#    │  │  │  │  └─ 8a1f9840118ffff (res:10, count:159, children:0)
#    │  │  │  ├─ 891f9840103ffff (res:9, count:569, children:7)
#    │  │  │  │  ├─ 8a1f9840100ffff (res:10, count:61, children:0)
#    │  │  │  │  ├─ 8a1f9840102ffff (res:10, count:65, children:0)
#    │  │  │  │  ├─ 8a1f98401027fff (res:10, count:98, children:0)
#    │  │  │  │  ├─ 8a1f9840101ffff (res:10, count:138, children:0)
#    │  │  │  │  ├─ 8a1f98401017fff (res:10, count:119, children:0)
#    │  │  │  │  ├─ 8a1f98401037fff (res:10, count:77, children:0)
#    │  │  │  │  └─ 8a1f98401007fff (res:10, count:11, children:0)
#    │  │  │  ├─ 891f984010fffff (res:9, count:779, children:7)
#    │  │  │  │  ├─ 8a1f984010cffff (res:10, count:44, children:0)
#    │  │  │  │  ├─ 8a1f984010effff (res:10, count:193, children:0)
#    │  │  │  │  ├─ 8a1f984010f7fff (res:10, count:97, children:0)
#    │  │  │  │  ├─ 8a1f984010e7fff (res:10, count:131, children:0)
#    │  │  │  │  ├─ 8a1f984010c7fff (res:10, count:203, children:0)
#    │  │  │  │  ├─ 8a1f984010d7fff (res:10, count:8, children:0)
#    │  │  │  │  └─ 8a1f984010dffff (res:10, count:103, children:0)
#    │  │  │  ├─ 891f9840117ffff (res:9, count:444, children:7)
#    │  │  │  │  ├─ 8a1f98401147fff (res:10, count:43, children:0)
#    │  │  │  │  ├─ 8a1f98401157fff (res:10, count:103, children:0)
#    │  │  │  │  ├─ 8a1f9840114ffff (res:10, count:84, children:0)
#    │  │  │  │  ├─ 8a1f98401177fff (res:10, count:66, children:0)
#    │  │  │  │  ├─ 8a1f9840115ffff (res:10, count:58, children:0)
#    │  │  │  │  ├─ 8a1f9840116ffff (res:10, count:44, children:0)
#    │  │  │  │  └─ 8a1f98401167fff (res:10, count:46, children:0)
#    │  │  │  ├─ 891f9840113ffff (res:9, count:806, children:7)
#    │  │  │  │  ├─ 8a1f98401127fff (res:10, count:99, children:0)
#    │  │  │  │  ├─ 8a1f98401107fff (res:10, count:169, children:0)
#    │  │  │  │  ├─ 8a1f98401117fff (res:10, count:104, children:0)
#    │  │  │  │  ├─ 8a1f9840110ffff (res:10, count:151, children:0)
#    │  │  │  │  ├─ 8a1f98401137fff (res:10, count:79, children:0)
#    │  │  │  │  ├─ 8a1f9840111ffff (res:10, count:145, children:0)
#    │  │  │  │  └─ 8a1f9840112ffff (res:10, count:59, children:0)
#    │  │  │  └─ 891f9840107ffff (res:9, count:730, children:7)
#    │  │  │     ├─ 8a1f9840106ffff (res:10, count:59, children:0)
#    │  │  │     ├─ 8a1f98401057fff (res:10, count:175, children:0)
#    │  │  │     ├─ 8a1f9840104ffff (res:10, count:83, children:0)
#    │  │  │     ├─ 8a1f9840105ffff (res:10, count:42, children:0)
#    │  │  │     ├─ 8a1f98401077fff (res:10, count:109, children:0)
#    │  │  │     ├─ 8a1f98401067fff (res:10, count:67, children:0)
#    │  │  │     └─ 8a1f98401047fff (res:10, count:195, children:0)
#    │  │  ├─ 881f98401dfffff (res:8, count:8828, children:7)
#    │  │  │  ├─ 891f98401dbffff (res:9, count:883, children:7)
#    │  │  │  │  ├─ 8a1f98401da7fff (res:10, count:266, children:0)
#    │  │  │  │  ├─ 8a1f98401d9ffff (res:10, count:160, children:0)
#    │  │  │  │  ├─ 8a1f98401d87fff (res:10, count:70, children:0)
#    │  │  │  │  ├─ 8a1f98401d8ffff (res:10, count:76, children:0)
#    │  │  │  │  ├─ 8a1f98401d97fff (res:10, count:82, children:0)
#    │  │  │  │  ├─ 8a1f98401db7fff (res:10, count:116, children:0)
#    │  │  │  │  └─ 8a1f98401daffff (res:10, count:113, children:0)
#    │  │  │  ├─ 891f98401c3ffff (res:9, count:1527, children:7)
#    │  │  │  │  ├─ 8a1f98401c17fff (res:10, count:117, children:0)
#    │  │  │  │  ├─ 8a1f98401c0ffff (res:10, count:104, children:0)
#    │  │  │  │  ├─ 8a1f98401c2ffff (res:10, count:184, children:0)
#    │  │  │  │  ├─ 8a1f98401c07fff (res:10, count:369, children:0)
#    │  │  │  │  ├─ 8a1f98401c37fff (res:10, count:358, children:0)
#    │  │  │  │  ├─ 8a1f98401c27fff (res:10, count:137, children:0)
#    │  │  │  │  └─ 8a1f98401c1ffff (res:10, count:258, children:0)
#    │  │  │  ├─ 891f98401c7ffff (res:9, count:827, children:7)
#    │  │  │  │  ├─ 8a1f98401c57fff (res:10, count:241, children:0)
#    │  │  │  │  ├─ 8a1f98401c6ffff (res:10, count:83, children:0)
#    │  │  │  │  ├─ 8a1f98401c67fff (res:10, count:136, children:0)
#    │  │  │  │  ├─ 8a1f98401c5ffff (res:10, count:126, children:0)
#    │  │  │  │  ├─ 8a1f98401c77fff (res:10, count:81, children:0)
#    │  │  │  │  ├─ 8a1f98401c4ffff (res:10, count:52, children:0)
#    │  │  │  │  └─ 8a1f98401c47fff (res:10, count:108, children:0)
#    │  │  │  ├─ 891f98401cbffff (res:9, count:1545, children:7)
#    │  │  │  │  ├─ 8a1f98401ca7fff (res:10, count:352, children:0)
#    │  │  │  │  ├─ 8a1f98401c87fff (res:10, count:207, children:0)
#    │  │  │  │  ├─ 8a1f98401c8ffff (res:10, count:125, children:0)
#    │  │  │  │  ├─ 8a1f98401cb7fff (res:10, count:108, children:0)
#    │  │  │  │  ├─ 8a1f98401c97fff (res:10, count:359, children:0)
#    │  │  │  │  ├─ 8a1f98401c9ffff (res:10, count:348, children:0)
#    │  │  │  │  └─ 8a1f98401caffff (res:10, count:46, children:0)
#    │  │  │  ├─ 891f98401cfffff (res:9, count:1584, children:6)
#    │  │  │  │  ├─ 8a1f98401ccffff (res:10, count:201, children:0)
#    │  │  │  │  ├─ 8a1f98401ce7fff (res:10, count:452, children:0)
#    │  │  │  │  ├─ 8a1f98401cdffff (res:10, count:211, children:0)
#    │  │  │  │  ├─ 8a1f98401cc7fff (res:10, count:139, children:0)
#    │  │  │  │  ├─ 8a1f98401cf7fff (res:10, count:362, children:0)
#    │  │  │  │  └─ 8a1f98401ceffff (res:10, count:219, children:0)
#    │  │  │  ├─ 891f98401d7ffff (res:9, count:588, children:7)
#    │  │  │  │  ├─ 8a1f98401d67fff (res:10, count:52, children:0)
#    │  │  │  │  ├─ 8a1f98401d4ffff (res:10, count:183, children:0)
#    │  │  │  │  ├─ 8a1f98401d6ffff (res:10, count:82, children:0)
#    │  │  │  │  ├─ 8a1f98401d77fff (res:10, count:1, children:0)
#    │  │  │  │  ├─ 8a1f98401d5ffff (res:10, count:87, children:0)
#    │  │  │  │  ├─ 8a1f98401d57fff (res:10, count:50, children:0)
#    │  │  │  │  └─ 8a1f98401d47fff (res:10, count:133, children:0)
#    │  │  │  └─ 891f98401d3ffff (res:9, count:1874, children:7)
#    │  │  │     ├─ 8a1f98401d07fff (res:10, count:475, children:0)
#    │  │  │     ├─ 8a1f98401d17fff (res:10, count:149, children:0)
#    │  │  │     ├─ 8a1f98401d27fff (res:10, count:260, children:0)
#    │  │  │     ├─ 8a1f98401d37fff (res:10, count:385, children:0)
#    │  │  │     ├─ 8a1f98401d2ffff (res:10, count:20, children:0)
#    │  │  │     ├─ 8a1f98401d1ffff (res:10, count:430, children:0)
#    │  │  │     └─ 8a1f98401d0ffff (res:10, count:155, children:0)
#    │  │  ├─ 881f98401bfffff (res:8, count:3745, children:7)
#    │  │  │  ├─ 891f98401bbffff (res:9, count:748, children:7)
#    │  │  │  │  ├─ 8a1f98401b97fff (res:10, count:37, children:0)
#    │  │  │  │  ├─ 8a1f98401bb7fff (res:10, count:36, children:0)
#    │  │  │  │  ├─ 8a1f98401baffff (res:10, count:226, children:0)
#    │  │  │  │  ├─ 8a1f98401b8ffff (res:10, count:73, children:0)
#    │  │  │  │  ├─ 8a1f98401b87fff (res:10, count:112, children:0)
#    │  │  │  │  ├─ 8a1f98401b9ffff (res:10, count:1, children:0)
#    │  │  │  │  └─ 8a1f98401ba7fff (res:10, count:263, children:0)
#    │  │  │  ├─ 891f98401a7ffff (res:9, count:664, children:7)
#    │  │  │  │  ├─ 8a1f98401a47fff (res:10, count:42, children:0)
#    │  │  │  │  ├─ 8a1f98401a67fff (res:10, count:43, children:0)
#    │  │  │  │  ├─ 8a1f98401a6ffff (res:10, count:52, children:0)
#    │  │  │  │  ├─ 8a1f98401a4ffff (res:10, count:229, children:0)
#    │  │  │  │  ├─ 8a1f98401a77fff (res:10, count:18, children:0)
#    │  │  │  │  ├─ 8a1f98401a57fff (res:10, count:112, children:0)
#    │  │  │  │  └─ 8a1f98401a5ffff (res:10, count:168, children:0)
#    │  │  │  ├─ 891f98401abffff (res:9, count:671, children:7)
#    │  │  │  │  ├─ 8a1f98401a87fff (res:10, count:133, children:0)
#    │  │  │  │  ├─ 8a1f98401aaffff (res:10, count:117, children:0)
#    │  │  │  │  ├─ 8a1f98401aa7fff (res:10, count:141, children:0)
#    │  │  │  │  ├─ 8a1f98401a8ffff (res:10, count:90, children:0)
#    │  │  │  │  ├─ 8a1f98401a9ffff (res:10, count:80, children:0)
#    │  │  │  │  ├─ 8a1f98401ab7fff (res:10, count:61, children:0)
#    │  │  │  │  └─ 8a1f98401a97fff (res:10, count:49, children:0)
#    │  │  │  ├─ 891f98401a3ffff (res:9, count:579, children:7)
#    │  │  │  │  ├─ 8a1f98401a1ffff (res:10, count:69, children:0)
#    │  │  │  │  ├─ 8a1f98401a27fff (res:10, count:45, children:0)
#    │  │  │  │  ├─ 8a1f98401a0ffff (res:10, count:63, children:0)
#    │  │  │  │  ├─ 8a1f98401a2ffff (res:10, count:97, children:0)
#    │  │  │  │  ├─ 8a1f98401a37fff (res:10, count:197, children:0)
#    │  │  │  │  ├─ 8a1f98401a17fff (res:10, count:81, children:0)
#    │  │  │  │  └─ 8a1f98401a07fff (res:10, count:27, children:0)
#    │  │  │  ├─ 891f98401b7ffff (res:9, count:273, children:7)
#    │  │  │  │  ├─ 8a1f98401b6ffff (res:10, count:72, children:0)
#    │  │  │  │  ├─ 8a1f98401b67fff (res:10, count:5, children:0)
#    │  │  │  │  ├─ 8a1f98401b4ffff (res:10, count:40, children:0)
#    │  │  │  │  ├─ 8a1f98401b77fff (res:10, count:52, children:0)
#    │  │  │  │  ├─ 8a1f98401b5ffff (res:10, count:83, children:0)
#    │  │  │  │  ├─ 8a1f98401b47fff (res:10, count:2, children:0)
#    │  │  │  │  └─ 8a1f98401b57fff (res:10, count:19, children:0)
#    │  │  │  ├─ 891f98401b3ffff (res:9, count:327, children:7)
#    │  │  │  │  ├─ 8a1f98401b37fff (res:10, count:115, children:0)
#    │  │  │  │  ├─ 8a1f98401b1ffff (res:10, count:49, children:0)
#    │  │  │  │  ├─ 8a1f98401b27fff (res:10, count:29, children:0)
#    │  │  │  │  ├─ 8a1f98401b0ffff (res:10, count:46, children:0)
#    │  │  │  │  ├─ 8a1f98401b17fff (res:10, count:40, children:0)
#    │  │  │  │  ├─ 8a1f98401b2ffff (res:10, count:5, children:0)
#    │  │  │  │  └─ 8a1f98401b07fff (res:10, count:43, children:0)
#    │  │  │  └─ 891f98401afffff (res:9, count:483, children:7)
#    │  │  │     ├─ 8a1f98401adffff (res:10, count:68, children:0)
#    │  │  │     ├─ 8a1f98401af7fff (res:10, count:34, children:0)
#    │  │  │     ├─ 8a1f98401acffff (res:10, count:138, children:0)
#    │  │  │     ├─ 8a1f98401aeffff (res:10, count:53, children:0)
#    │  │  │     ├─ 8a1f98401ac7fff (res:10, count:107, children:0)
#    │  │  │     ├─ 8a1f98401ae7fff (res:10, count:20, children:0)
#    │  │  │     └─ 8a1f98401ad7fff (res:10, count:63, children:0)
#    │  │  └─ 881f984013fffff (res:8, count:2904, children:6)
#    │  │     ├─ 891f9840137ffff (res:9, count:428, children:7)
#    │  │     │  ├─ 8a1f9840135ffff (res:10, count:28, children:0)
#    │  │     │  ├─ 8a1f98401347fff (res:10, count:139, children:0)
#    │  │     │  ├─ 8a1f98401357fff (res:10, count:80, children:0)
#    │  │     │  ├─ 8a1f9840134ffff (res:10, count:28, children:0)
#    │  │     │  ├─ 8a1f9840136ffff (res:10, count:47, children:0)
#    │  │     │  ├─ 8a1f98401367fff (res:10, count:50, children:0)
#    │  │     │  └─ 8a1f98401377fff (res:10, count:56, children:0)
#    │  │     ├─ 891f9840123ffff (res:9, count:375, children:7)
#    │  │     │  ├─ 8a1f9840120ffff (res:10, count:72, children:0)
#    │  │     │  ├─ 8a1f98401227fff (res:10, count:70, children:0)
#    │  │     │  ├─ 8a1f98401237fff (res:10, count:6, children:0)
#    │  │     │  ├─ 8a1f98401207fff (res:10, count:70, children:0)
#    │  │     │  ├─ 8a1f9840121ffff (res:10, count:5, children:0)
#    │  │     │  ├─ 8a1f9840122ffff (res:10, count:47, children:0)
#    │  │     │  └─ 8a1f98401217fff (res:10, count:105, children:0)
#    │  │     ├─ 891f9840127ffff (res:9, count:696, children:5)
#    │  │     │  ├─ 8a1f98401277fff (res:10, count:237, children:0)
#    │  │     │  ├─ 8a1f98401247fff (res:10, count:172, children:0)
#    │  │     │  ├─ 8a1f9840124ffff (res:10, count:63, children:0)
#    │  │     │  ├─ 8a1f98401267fff (res:10, count:82, children:0)
#    │  │     │  └─ 8a1f9840126ffff (res:10, count:142, children:0)
#    │  │     ├─ 891f9840133ffff (res:9, count:325, children:7)
#    │  │     │  ├─ 8a1f9840131ffff (res:10, count:36, children:0)
#    │  │     │  ├─ 8a1f9840132ffff (res:10, count:66, children:0)
#    │  │     │  ├─ 8a1f98401327fff (res:10, count:50, children:0)
#    │  │     │  ├─ 8a1f98401337fff (res:10, count:35, children:0)
#    │  │     │  ├─ 8a1f9840130ffff (res:10, count:45, children:0)
#    │  │     │  ├─ 8a1f98401307fff (res:10, count:42, children:0)
#    │  │     │  └─ 8a1f98401317fff (res:10, count:51, children:0)
#    │  │     ├─ 891f984013bffff (res:9, count:845, children:6)
#    │  │     │  ├─ 8a1f9840139ffff (res:10, count:272, children:0)
#    │  │     │  ├─ 8a1f984013a7fff (res:10, count:44, children:0)
#    │  │     │  ├─ 8a1f98401387fff (res:10, count:67, children:0)
#    │  │     │  ├─ 8a1f98401397fff (res:10, count:103, children:0)
#    │  │     │  ├─ 8a1f984013b7fff (res:10, count:61, children:0)
#    │  │     │  └─ 8a1f9840138ffff (res:10, count:298, children:0)
#    │  │     └─ 891f984012bffff (res:9, count:235, children:2)
#    │  │        ├─ 8a1f984012a7fff (res:10, count:192, children:0)
#    │  │        └─ 8a1f984012b7fff (res:10, count:43, children:0)
#    │  ├─ 871f98404ffffff (res:7, count:26840, children:7)
#    │  │  ├─ 881f984047fffff (res:8, count:1291, children:4)
#    │  │  │  ├─ 891f9840467ffff (res:9, count:131, children:3)
#    │  │  │  │  ├─ 8a1f98404667fff (res:10, count:46, children:0)
#    │  │  │  │  ├─ 8a1f9840464ffff (res:10, count:23, children:0)
#    │  │  │  │  └─ 8a1f9840466ffff (res:10, count:62, children:0)
#    │  │  │  ├─ 891f984046fffff (res:9, count:92, children:1)
#    │  │  │  │  └─ 8a1f984046cffff (res:10, count:92, children:0)
#    │  │  │  ├─ 891f9840477ffff (res:9, count:781, children:6)
#    │  │  │  │  ├─ 8a1f98404767fff (res:10, count:145, children:0)
#    │  │  │  │  ├─ 8a1f98404777fff (res:10, count:180, children:0)
#    │  │  │  │  ├─ 8a1f9840476ffff (res:10, count:106, children:0)
#    │  │  │  │  ├─ 8a1f98404747fff (res:10, count:139, children:0)
#    │  │  │  │  ├─ 8a1f9840475ffff (res:10, count:2, children:0)
#    │  │  │  │  └─ 8a1f9840474ffff (res:10, count:209, children:0)
#    │  │  │  └─ 891f9840473ffff (res:9, count:287, children:2)
#    │  │  │     ├─ 8a1f98404727fff (res:10, count:264, children:0)
#    │  │  │     └─ 8a1f9840472ffff (res:10, count:23, children:0)
#    │  │  ├─ 881f984041fffff (res:8, count:6651, children:7)
#    │  │  │  ├─ 891f984040fffff (res:9, count:454, children:7)
#    │  │  │  │  ├─ 8a1f984040cffff (res:10, count:11, children:0)
#    │  │  │  │  ├─ 8a1f984040dffff (res:10, count:122, children:0)
#    │  │  │  │  ├─ 8a1f984040effff (res:10, count:46, children:0)
#    │  │  │  │  ├─ 8a1f984040f7fff (res:10, count:38, children:0)
#    │  │  │  │  ├─ 8a1f984040e7fff (res:10, count:46, children:0)
#    │  │  │  │  ├─ 8a1f984040c7fff (res:10, count:15, children:0)
#    │  │  │  │  └─ 8a1f984040d7fff (res:10, count:176, children:0)
#    │  │  │  ├─ 891f9840413ffff (res:9, count:1389, children:7)
#    │  │  │  │  ├─ 8a1f9840411ffff (res:10, count:151, children:0)
#    │  │  │  │  ├─ 8a1f98404117fff (res:10, count:19, children:0)
#    │  │  │  │  ├─ 8a1f98404107fff (res:10, count:194, children:0)
#    │  │  │  │  ├─ 8a1f98404137fff (res:10, count:41, children:0)
#    │  │  │  │  ├─ 8a1f9840410ffff (res:10, count:249, children:0)
#    │  │  │  │  ├─ 8a1f9840412ffff (res:10, count:693, children:0)
#    │  │  │  │  └─ 8a1f98404127fff (res:10, count:42, children:0)
#    │  │  │  ├─ 891f9840407ffff (res:9, count:259, children:7)
#    │  │  │  │  ├─ 8a1f98404077fff (res:10, count:50, children:0)
#    │  │  │  │  ├─ 8a1f9840405ffff (res:10, count:19, children:0)
#    │  │  │  │  ├─ 8a1f9840406ffff (res:10, count:36, children:0)
#    │  │  │  │  ├─ 8a1f98404047fff (res:10, count:54, children:0)
#    │  │  │  │  ├─ 8a1f9840404ffff (res:10, count:3, children:0)
#    │  │  │  │  ├─ 8a1f98404057fff (res:10, count:22, children:0)
#    │  │  │  │  └─ 8a1f98404067fff (res:10, count:75, children:0)
#    │  │  │  ├─ 891f984040bffff (res:9, count:1284, children:6)
#    │  │  │  │  ├─ 8a1f984040a7fff (res:10, count:56, children:0)
#    │  │  │  │  ├─ 8a1f9840409ffff (res:10, count:2, children:0)
#    │  │  │  │  ├─ 8a1f984040b7fff (res:10, count:413, children:0)
#    │  │  │  │  ├─ 8a1f98404087fff (res:10, count:281, children:0)
#    │  │  │  │  ├─ 8a1f9840408ffff (res:10, count:363, children:0)
#    │  │  │  │  └─ 8a1f984040affff (res:10, count:169, children:0)
#    │  │  │  ├─ 891f9840417ffff (res:9, count:1226, children:7)
#    │  │  │  │  ├─ 8a1f98404177fff (res:10, count:80, children:0)
#    │  │  │  │  ├─ 8a1f9840416ffff (res:10, count:101, children:0)
#    │  │  │  │  ├─ 8a1f98404147fff (res:10, count:143, children:0)
#    │  │  │  │  ├─ 8a1f9840415ffff (res:10, count:120, children:0)
#    │  │  │  │  ├─ 8a1f9840414ffff (res:10, count:520, children:0)
#    │  │  │  │  ├─ 8a1f98404157fff (res:10, count:111, children:0)
#    │  │  │  │  └─ 8a1f98404167fff (res:10, count:151, children:0)
#    │  │  │  ├─ 891f9840403ffff (res:9, count:688, children:7)
#    │  │  │  │  ├─ 8a1f98404027fff (res:10, count:88, children:0)
#    │  │  │  │  ├─ 8a1f9840402ffff (res:10, count:297, children:0)
#    │  │  │  │  ├─ 8a1f98404037fff (res:10, count:38, children:0)
#    │  │  │  │  ├─ 8a1f98404017fff (res:10, count:23, children:0)
#    │  │  │  │  ├─ 8a1f9840401ffff (res:10, count:111, children:0)
#    │  │  │  │  ├─ 8a1f98404007fff (res:10, count:82, children:0)
#    │  │  │  │  └─ 8a1f9840400ffff (res:10, count:49, children:0)
#    │  │  │  └─ 891f984041bffff (res:9, count:1351, children:6)
#    │  │  │     ├─ 8a1f98404187fff (res:10, count:382, children:0)
#    │  │  │     ├─ 8a1f9840419ffff (res:10, count:9, children:0)
#    │  │  │     ├─ 8a1f9840418ffff (res:10, count:124, children:0)
#    │  │  │     ├─ 8a1f98404197fff (res:10, count:600, children:0)
#    │  │  │     ├─ 8a1f984041a7fff (res:10, count:39, children:0)
#    │  │  │     └─ 8a1f984041affff (res:10, count:197, children:0)
#    │  │  ├─ 881f98404bfffff (res:8, count:5159, children:6)
#    │  │  │  ├─ 891f98404afffff (res:9, count:1153, children:7)
#    │  │  │  │  ├─ 8a1f98404ac7fff (res:10, count:168, children:0)
#    │  │  │  │  ├─ 8a1f98404aeffff (res:10, count:519, children:0)
#    │  │  │  │  ├─ 8a1f98404acffff (res:10, count:92, children:0)
#    │  │  │  │  ├─ 8a1f98404ad7fff (res:10, count:29, children:0)
#    │  │  │  │  ├─ 8a1f98404af7fff (res:10, count:9, children:0)
#    │  │  │  │  ├─ 8a1f98404ae7fff (res:10, count:151, children:0)
#    │  │  │  │  └─ 8a1f98404adffff (res:10, count:185, children:0)
#    │  │  │  ├─ 891f98404abffff (res:9, count:828, children:7)
#    │  │  │  │  ├─ 8a1f98404a97fff (res:10, count:236, children:0)
#    │  │  │  │  ├─ 8a1f98404a87fff (res:10, count:62, children:0)
#    │  │  │  │  ├─ 8a1f98404a8ffff (res:10, count:19, children:0)
#    │  │  │  │  ├─ 8a1f98404aa7fff (res:10, count:87, children:0)
#    │  │  │  │  ├─ 8a1f98404a9ffff (res:10, count:92, children:0)
#    │  │  │  │  ├─ 8a1f98404aaffff (res:10, count:14, children:0)
#    │  │  │  │  └─ 8a1f98404ab7fff (res:10, count:318, children:0)
#    │  │  │  ├─ 891f98404a3ffff (res:9, count:2381, children:6)
#    │  │  │  │  ├─ 8a1f98404a2ffff (res:10, count:538, children:0)
#    │  │  │  │  ├─ 8a1f98404a37fff (res:10, count:111, children:0)
#    │  │  │  │  ├─ 8a1f98404a27fff (res:10, count:1303, children:0)
#    │  │  │  │  ├─ 8a1f98404a07fff (res:10, count:66, children:0)
#    │  │  │  │  ├─ 8a1f98404a1ffff (res:10, count:45, children:0)
#    │  │  │  │  └─ 8a1f98404a0ffff (res:10, count:318, children:0)
#    │  │  │  ├─ 891f98404bbffff (res:9, count:433, children:5)
#    │  │  │  │  ├─ 8a1f98404b97fff (res:10, count:15, children:0)
#    │  │  │  │  ├─ 8a1f98404b9ffff (res:10, count:99, children:0)
#    │  │  │  │  ├─ 8a1f98404b8ffff (res:10, count:51, children:0)
#    │  │  │  │  ├─ 8a1f98404baffff (res:10, count:175, children:0)
#    │  │  │  │  └─ 8a1f98404ba7fff (res:10, count:93, children:0)
#    │  │  │  ├─ 891f98404a7ffff (res:9, count:154, children:1)
#    │  │  │  │  └─ 8a1f98404a57fff (res:10, count:154, children:0)
#    │  │  │  └─ 891f98404b7ffff (res:9, count:210, children:1)
#    │  │  │     └─ 8a1f98404b57fff (res:10, count:210, children:0)
#    │  │  ├─ 881f984049fffff (res:8, count:5440, children:4)
#    │  │  │  ├─ 891f9840487ffff (res:9, count:1985, children:4)
#    │  │  │  │  ├─ 8a1f98404847fff (res:10, count:71, children:0)
#    │  │  │  │  ├─ 8a1f98404857fff (res:10, count:137, children:0)
#    │  │  │  │  ├─ 8a1f9840485ffff (res:10, count:1750, children:0)
#    │  │  │  │  └─ 8a1f98404877fff (res:10, count:27, children:0)
#    │  │  │  ├─ 891f984048fffff (res:9, count:1411, children:7)
#    │  │  │  │  ├─ 8a1f984048cffff (res:10, count:10, children:0)
#    │  │  │  │  ├─ 8a1f984048d7fff (res:10, count:788, children:0)
#    │  │  │  │  ├─ 8a1f984048e7fff (res:10, count:271, children:0)
#    │  │  │  │  ├─ 8a1f984048effff (res:10, count:105, children:0)
#    │  │  │  │  ├─ 8a1f984048f7fff (res:10, count:208, children:0)
#    │  │  │  │  ├─ 8a1f984048c7fff (res:10, count:16, children:0)
#    │  │  │  │  └─ 8a1f984048dffff (res:10, count:13, children:0)
#    │  │  │  ├─ 891f9840483ffff (res:9, count:1980, children:4)
#    │  │  │  │  ├─ 8a1f9840481ffff (res:10, count:2, children:0)
#    │  │  │  │  ├─ 8a1f9840482ffff (res:10, count:1168, children:0)
#    │  │  │  │  ├─ 8a1f98404807fff (res:10, count:325, children:0)
#    │  │  │  │  └─ 8a1f9840480ffff (res:10, count:485, children:0)
#    │  │  │  └─ 891f984048bffff (res:9, count:64, children:4)
#    │  │  │     ├─ 8a1f98404897fff (res:10, count:8, children:0)
#    │  │  │     ├─ 8a1f984048b7fff (res:10, count:1, children:0)
#    │  │  │     ├─ 8a1f9840489ffff (res:10, count:8, children:0)
#    │  │  │     └─ 8a1f9840488ffff (res:10, count:47, children:0)
#    │  │  ├─ 881f98404dfffff (res:8, count:3026, children:5)
#    │  │  │  ├─ 891f98404cbffff (res:9, count:1, children:1)
#    │  │  │  │  └─ 8a1f98404caffff (res:10, count:1, children:0)
#    │  │  │  ├─ 891f98404c7ffff (res:9, count:524, children:5)
#    │  │  │  │  ├─ 8a1f98404c57fff (res:10, count:31, children:0)
#    │  │  │  │  ├─ 8a1f98404c6ffff (res:10, count:44, children:0)
#    │  │  │  │  ├─ 8a1f98404c4ffff (res:10, count:1, children:0)
#    │  │  │  │  ├─ 8a1f98404c67fff (res:10, count:82, children:0)
#    │  │  │  │  └─ 8a1f98404c77fff (res:10, count:366, children:0)
#    │  │  │  ├─ 891f98404d7ffff (res:9, count:577, children:3)
#    │  │  │  │  ├─ 8a1f98404d4ffff (res:10, count:469, children:0)
#    │  │  │  │  ├─ 8a1f98404d47fff (res:10, count:1, children:0)
#    │  │  │  │  └─ 8a1f98404d5ffff (res:10, count:107, children:0)
#    │  │  │  ├─ 891f98404cfffff (res:9, count:1844, children:4)
#    │  │  │  │  ├─ 8a1f98404ce7fff (res:10, count:981, children:0)
#    │  │  │  │  ├─ 8a1f98404cf7fff (res:10, count:342, children:0)
#    │  │  │  │  ├─ 8a1f98404ccffff (res:10, count:151, children:0)
#    │  │  │  │  └─ 8a1f98404cc7fff (res:10, count:370, children:0)
#    │  │  │  └─ 891f98404c3ffff (res:9, count:80, children:1)
#    │  │  │     └─ 8a1f98404c0ffff (res:10, count:80, children:0)
#    │  │  ├─ 881f984043fffff (res:8, count:5115, children:7)
#    │  │  │  ├─ 891f984043bffff (res:9, count:932, children:7)
#    │  │  │  │  ├─ 8a1f98404387fff (res:10, count:358, children:0)
#    │  │  │  │  ├─ 8a1f9840438ffff (res:10, count:105, children:0)
#    │  │  │  │  ├─ 8a1f984043a7fff (res:10, count:285, children:0)
#    │  │  │  │  ├─ 8a1f9840439ffff (res:10, count:62, children:0)
#    │  │  │  │  ├─ 8a1f984043affff (res:10, count:19, children:0)
#    │  │  │  │  ├─ 8a1f98404397fff (res:10, count:77, children:0)
#    │  │  │  │  └─ 8a1f984043b7fff (res:10, count:26, children:0)
#    │  │  │  ├─ 891f9840423ffff (res:9, count:878, children:7)
#    │  │  │  │  ├─ 8a1f9840421ffff (res:10, count:152, children:0)
#    │  │  │  │  ├─ 8a1f98404237fff (res:10, count:132, children:0)
#    │  │  │  │  ├─ 8a1f98404207fff (res:10, count:169, children:0)
#    │  │  │  │  ├─ 8a1f9840420ffff (res:10, count:38, children:0)
#    │  │  │  │  ├─ 8a1f98404227fff (res:10, count:29, children:0)
#    │  │  │  │  ├─ 8a1f98404217fff (res:10, count:167, children:0)
#    │  │  │  │  └─ 8a1f9840422ffff (res:10, count:191, children:0)
#    │  │  │  ├─ 891f9840437ffff (res:9, count:743, children:7)
#    │  │  │  │  ├─ 8a1f98404357fff (res:10, count:131, children:0)
#    │  │  │  │  ├─ 8a1f98404347fff (res:10, count:5, children:0)
#    │  │  │  │  ├─ 8a1f98404377fff (res:10, count:9, children:0)
#    │  │  │  │  ├─ 8a1f98404367fff (res:10, count:97, children:0)
#    │  │  │  │  ├─ 8a1f9840434ffff (res:10, count:60, children:0)
#    │  │  │  │  ├─ 8a1f9840435ffff (res:10, count:190, children:0)
#    │  │  │  │  └─ 8a1f9840436ffff (res:10, count:251, children:0)
#    │  │  │  ├─ 891f984042fffff (res:9, count:391, children:7)
#    │  │  │  │  ├─ 8a1f984042c7fff (res:10, count:32, children:0)
#    │  │  │  │  ├─ 8a1f984042e7fff (res:10, count:112, children:0)
#    │  │  │  │  ├─ 8a1f984042effff (res:10, count:53, children:0)
#    │  │  │  │  ├─ 8a1f984042f7fff (res:10, count:40, children:0)
#    │  │  │  │  ├─ 8a1f984042dffff (res:10, count:47, children:0)
#    │  │  │  │  ├─ 8a1f984042cffff (res:10, count:73, children:0)
#    │  │  │  │  └─ 8a1f984042d7fff (res:10, count:34, children:0)
#    │  │  │  ├─ 891f9840433ffff (res:9, count:548, children:7)
#    │  │  │  │  ├─ 8a1f98404307fff (res:10, count:157, children:0)
#    │  │  │  │  ├─ 8a1f9840430ffff (res:10, count:52, children:0)
#    │  │  │  │  ├─ 8a1f9840432ffff (res:10, count:75, children:0)
#    │  │  │  │  ├─ 8a1f9840431ffff (res:10, count:10, children:0)
#    │  │  │  │  ├─ 8a1f98404317fff (res:10, count:136, children:0)
#    │  │  │  │  ├─ 8a1f98404327fff (res:10, count:69, children:0)
#    │  │  │  │  └─ 8a1f98404337fff (res:10, count:49, children:0)
#    │  │  │  ├─ 891f9840427ffff (res:9, count:731, children:7)
#    │  │  │  │  ├─ 8a1f98404267fff (res:10, count:264, children:0)
#    │  │  │  │  ├─ 8a1f98404257fff (res:10, count:16, children:0)
#    │  │  │  │  ├─ 8a1f98404247fff (res:10, count:123, children:0)
#    │  │  │  │  ├─ 8a1f98404277fff (res:10, count:91, children:0)
#    │  │  │  │  ├─ 8a1f9840424ffff (res:10, count:54, children:0)
#    │  │  │  │  ├─ 8a1f9840426ffff (res:10, count:84, children:0)
#    │  │  │  │  └─ 8a1f9840425ffff (res:10, count:99, children:0)
#    │  │  │  └─ 891f984042bffff (res:9, count:892, children:7)
#    │  │  │     ├─ 8a1f984042a7fff (res:10, count:78, children:0)
#    │  │  │     ├─ 8a1f984042affff (res:10, count:79, children:0)
#    │  │  │     ├─ 8a1f9840429ffff (res:10, count:251, children:0)
#    │  │  │     ├─ 8a1f984042b7fff (res:10, count:125, children:0)
#    │  │  │     ├─ 8a1f9840428ffff (res:10, count:57, children:0)
#    │  │  │     ├─ 8a1f98404287fff (res:10, count:136, children:0)
#    │  │  │     └─ 8a1f98404297fff (res:10, count:166, children:0)
#    │  │  └─ 881f984045fffff (res:8, count:158, children:1)
#    │  │     └─ 891f9840457ffff (res:9, count:158, children:2)
#    │  │        ├─ 8a1f9840456ffff (res:10, count:151, children:0)
#    │  │        └─ 8a1f98404567fff (res:10, count:7, children:0)
#    │  ├─ 871f98403ffffff (res:7, count:184111, children:7)
#    │  │  ├─ 881f984033fffff (res:8, count:27113, children:7)
#    │  │  │  ├─ 891f984032fffff (res:9, count:3574, children:7)
#    │  │  │  │  ├─ 8a1f984032d7fff (res:10, count:163, children:0)
#    │  │  │  │  ├─ 8a1f984032dffff (res:10, count:264, children:0)
#    │  │  │  │  ├─ 8a1f984032f7fff (res:10, count:704, children:0)
#    │  │  │  │  ├─ 8a1f984032c7fff (res:10, count:286, children:0)
#    │  │  │  │  ├─ 8a1f984032e7fff (res:10, count:867, children:0)
#    │  │  │  │  ├─ 8a1f984032cffff (res:10, count:526, children:0)
#    │  │  │  │  └─ 8a1f984032effff (res:10, count:764, children:0)
#    │  │  │  ├─ 891f984033bffff (res:9, count:4987, children:7)
#    │  │  │  │  ├─ 8a1f984033affff (res:10, count:244, children:0)
#    │  │  │  │  ├─ 8a1f9840338ffff (res:10, count:1161, children:0)
#    │  │  │  │  ├─ 8a1f98403397fff (res:10, count:316, children:0)
#    │  │  │  │  ├─ 8a1f98403387fff (res:10, count:428, children:0)
#    │  │  │  │  ├─ 8a1f984033a7fff (res:10, count:1099, children:0)
#    │  │  │  │  ├─ 8a1f9840339ffff (res:10, count:1079, children:0)
#    │  │  │  │  └─ 8a1f984033b7fff (res:10, count:660, children:0)
#    │  │  │  ├─ 891f9840333ffff (res:9, count:2333, children:6)
#    │  │  │  │  ├─ 8a1f98403307fff (res:10, count:20, children:0)
#    │  │  │  │  ├─ 8a1f9840331ffff (res:10, count:174, children:0)
#    │  │  │  │  ├─ 8a1f9840332ffff (res:10, count:1015, children:0)
#    │  │  │  │  ├─ 8a1f98403317fff (res:10, count:101, children:0)
#    │  │  │  │  ├─ 8a1f9840330ffff (res:10, count:914, children:0)
#    │  │  │  │  └─ 8a1f98403327fff (res:10, count:109, children:0)
#    │  │  │  ├─ 891f9840323ffff (res:9, count:2905, children:7)
#    │  │  │  │  ├─ 8a1f98403207fff (res:10, count:40, children:0)
#    │  │  │  │  ├─ 8a1f98403237fff (res:10, count:238, children:0)
#    │  │  │  │  ├─ 8a1f9840320ffff (res:10, count:986, children:0)
#    │  │  │  │  ├─ 8a1f9840322ffff (res:10, count:874, children:0)
#    │  │  │  │  ├─ 8a1f9840321ffff (res:10, count:148, children:0)
#    │  │  │  │  ├─ 8a1f98403227fff (res:10, count:612, children:0)
#    │  │  │  │  └─ 8a1f98403217fff (res:10, count:7, children:0)
#    │  │  │  ├─ 891f984032bffff (res:9, count:5587, children:7)
#    │  │  │  │  ├─ 8a1f9840328ffff (res:10, count:463, children:0)
#    │  │  │  │  ├─ 8a1f984032a7fff (res:10, count:811, children:0)
#    │  │  │  │  ├─ 8a1f98403297fff (res:10, count:589, children:0)
#    │  │  │  │  ├─ 8a1f984032affff (res:10, count:471, children:0)
#    │  │  │  │  ├─ 8a1f98403287fff (res:10, count:817, children:0)
#    │  │  │  │  ├─ 8a1f9840329ffff (res:10, count:1003, children:0)
#    │  │  │  │  └─ 8a1f984032b7fff (res:10, count:1433, children:0)
#    │  │  │  ├─ 891f9840327ffff (res:9, count:3693, children:7)
#    │  │  │  │  ├─ 8a1f98403247fff (res:10, count:632, children:0)
#    │  │  │  │  ├─ 8a1f98403267fff (res:10, count:436, children:0)
#    │  │  │  │  ├─ 8a1f9840324ffff (res:10, count:554, children:0)
#    │  │  │  │  ├─ 8a1f9840325ffff (res:10, count:352, children:0)
#    │  │  │  │  ├─ 8a1f9840326ffff (res:10, count:691, children:0)
#    │  │  │  │  ├─ 8a1f98403257fff (res:10, count:667, children:0)
#    │  │  │  │  └─ 8a1f98403277fff (res:10, count:361, children:0)
#    │  │  │  └─ 891f9840337ffff (res:9, count:4034, children:7)
#    │  │  │     ├─ 8a1f98403347fff (res:10, count:544, children:0)
#    │  │  │     ├─ 8a1f98403377fff (res:10, count:332, children:0)
#    │  │  │     ├─ 8a1f98403367fff (res:10, count:722, children:0)
#    │  │  │     ├─ 8a1f9840335ffff (res:10, count:469, children:0)
#    │  │  │     ├─ 8a1f9840336ffff (res:10, count:768, children:0)
#    │  │  │     ├─ 8a1f98403357fff (res:10, count:698, children:0)
#    │  │  │     └─ 8a1f9840334ffff (res:10, count:501, children:0)
#    │  │  ├─ 881f984039fffff (res:8, count:21675, children:7)
#    │  │  │  ├─ 891f9840397ffff (res:9, count:1218, children:7)
#    │  │  │  │  ├─ 8a1f98403967fff (res:10, count:72, children:0)
#    │  │  │  │  ├─ 8a1f9840394ffff (res:10, count:544, children:0)
#    │  │  │  │  ├─ 8a1f98403977fff (res:10, count:65, children:0)
#    │  │  │  │  ├─ 8a1f98403947fff (res:10, count:264, children:0)
#    │  │  │  │  ├─ 8a1f98403957fff (res:10, count:155, children:0)
#    │  │  │  │  ├─ 8a1f9840395ffff (res:10, count:44, children:0)
#    │  │  │  │  └─ 8a1f9840396ffff (res:10, count:74, children:0)
#    │  │  │  ├─ 891f984038bffff (res:9, count:4343, children:6)
#    │  │  │  │  ├─ 8a1f984038affff (res:10, count:557, children:0)
#    │  │  │  │  ├─ 8a1f984038a7fff (res:10, count:1602, children:0)
#    │  │  │  │  ├─ 8a1f98403887fff (res:10, count:463, children:0)
#    │  │  │  │  ├─ 8a1f984038b7fff (res:10, count:264, children:0)
#    │  │  │  │  ├─ 8a1f98403897fff (res:10, count:1166, children:0)
#    │  │  │  │  └─ 8a1f9840388ffff (res:10, count:291, children:0)
#    │  │  │  ├─ 891f984039bffff (res:9, count:5507, children:7)
#    │  │  │  │  ├─ 8a1f98403997fff (res:10, count:1096, children:0)
#    │  │  │  │  ├─ 8a1f98403987fff (res:10, count:789, children:0)
#    │  │  │  │  ├─ 8a1f984039a7fff (res:10, count:719, children:0)
#    │  │  │  │  ├─ 8a1f9840399ffff (res:10, count:890, children:0)
#    │  │  │  │  ├─ 8a1f9840398ffff (res:10, count:1087, children:0)
#    │  │  │  │  ├─ 8a1f984039affff (res:10, count:668, children:0)
#    │  │  │  │  └─ 8a1f984039b7fff (res:10, count:258, children:0)
#    │  │  │  ├─ 891f9840393ffff (res:9, count:2004, children:7)
#    │  │  │  │  ├─ 8a1f9840392ffff (res:10, count:47, children:0)
#    │  │  │  │  ├─ 8a1f9840390ffff (res:10, count:13, children:0)
#    │  │  │  │  ├─ 8a1f98403917fff (res:10, count:959, children:0)
#    │  │  │  │  ├─ 8a1f9840391ffff (res:10, count:591, children:0)
#    │  │  │  │  ├─ 8a1f98403937fff (res:10, count:238, children:0)
#    │  │  │  │  ├─ 8a1f98403907fff (res:10, count:85, children:0)
#    │  │  │  │  └─ 8a1f98403927fff (res:10, count:71, children:0)
#    │  │  │  ├─ 891f984038fffff (res:9, count:2513, children:7)
#    │  │  │  │  ├─ 8a1f984038d7fff (res:10, count:78, children:0)
#    │  │  │  │  ├─ 8a1f984038cffff (res:10, count:227, children:0)
#    │  │  │  │  ├─ 8a1f984038dffff (res:10, count:1023, children:0)
#    │  │  │  │  ├─ 8a1f984038f7fff (res:10, count:48, children:0)
#    │  │  │  │  ├─ 8a1f984038e7fff (res:10, count:492, children:0)
#    │  │  │  │  ├─ 8a1f984038effff (res:10, count:507, children:0)
#    │  │  │  │  └─ 8a1f984038c7fff (res:10, count:138, children:0)
#    │  │  │  ├─ 891f9840387ffff (res:9, count:2178, children:7)
#    │  │  │  │  ├─ 8a1f98403867fff (res:10, count:397, children:0)
#    │  │  │  │  ├─ 8a1f9840384ffff (res:10, count:369, children:0)
#    │  │  │  │  ├─ 8a1f9840385ffff (res:10, count:335, children:0)
#    │  │  │  │  ├─ 8a1f9840386ffff (res:10, count:387, children:0)
#    │  │  │  │  ├─ 8a1f98403847fff (res:10, count:322, children:0)
#    │  │  │  │  ├─ 8a1f98403877fff (res:10, count:184, children:0)
#    │  │  │  │  └─ 8a1f98403857fff (res:10, count:184, children:0)
#    │  │  │  └─ 891f9840383ffff (res:9, count:3912, children:7)
#    │  │  │     ├─ 8a1f98403837fff (res:10, count:799, children:0)
#    │  │  │     ├─ 8a1f98403817fff (res:10, count:349, children:0)
#    │  │  │     ├─ 8a1f9840381ffff (res:10, count:799, children:0)
#    │  │  │     ├─ 8a1f98403827fff (res:10, count:670, children:0)
#    │  │  │     ├─ 8a1f98403807fff (res:10, count:715, children:0)
#    │  │  │     ├─ 8a1f9840380ffff (res:10, count:268, children:0)
#    │  │  │     └─ 8a1f9840382ffff (res:10, count:312, children:0)
#    │  │  ├─ 881f98403dfffff (res:8, count:37848, children:7)
#    │  │  │  ├─ 891f98403c7ffff (res:9, count:6976, children:7)
#    │  │  │  │  ├─ 8a1f98403c57fff (res:10, count:546, children:0)
#    │  │  │  │  ├─ 8a1f98403c77fff (res:10, count:780, children:0)
#    │  │  │  │  ├─ 8a1f98403c67fff (res:10, count:619, children:0)
#    │  │  │  │  ├─ 8a1f98403c47fff (res:10, count:804, children:0)
#    │  │  │  │  ├─ 8a1f98403c6ffff (res:10, count:853, children:0)
#    │  │  │  │  ├─ 8a1f98403c5ffff (res:10, count:1870, children:0)
#    │  │  │  │  └─ 8a1f98403c4ffff (res:10, count:1504, children:0)
#    │  │  │  ├─ 891f98403c3ffff (res:9, count:3914, children:7)
#    │  │  │  │  ├─ 8a1f98403c07fff (res:10, count:43, children:0)
#    │  │  │  │  ├─ 8a1f98403c27fff (res:10, count:292, children:0)
#    │  │  │  │  ├─ 8a1f98403c37fff (res:10, count:542, children:0)
#    │  │  │  │  ├─ 8a1f98403c17fff (res:10, count:904, children:0)
#    │  │  │  │  ├─ 8a1f98403c2ffff (res:10, count:487, children:0)
#    │  │  │  │  ├─ 8a1f98403c1ffff (res:10, count:1202, children:0)
#    │  │  │  │  └─ 8a1f98403c0ffff (res:10, count:444, children:0)
#    │  │  │  ├─ 891f98403d7ffff (res:9, count:5399, children:7)
#    │  │  │  │  ├─ 8a1f98403d5ffff (res:10, count:870, children:0)
#    │  │  │  │  ├─ 8a1f98403d67fff (res:10, count:588, children:0)
#    │  │  │  │  ├─ 8a1f98403d57fff (res:10, count:664, children:0)
#    │  │  │  │  ├─ 8a1f98403d77fff (res:10, count:558, children:0)
#    │  │  │  │  ├─ 8a1f98403d4ffff (res:10, count:1192, children:0)
#    │  │  │  │  ├─ 8a1f98403d6ffff (res:10, count:839, children:0)
#    │  │  │  │  └─ 8a1f98403d47fff (res:10, count:688, children:0)
#    │  │  │  ├─ 891f98403dbffff (res:9, count:6064, children:7)
#    │  │  │  │  ├─ 8a1f98403da7fff (res:10, count:727, children:0)
#    │  │  │  │  ├─ 8a1f98403d9ffff (res:10, count:939, children:0)
#    │  │  │  │  ├─ 8a1f98403d8ffff (res:10, count:443, children:0)
# ...
#       │     │  ├─ 8a1f98411b07fff (res:10, count:57, children:0)
#       │     │  ├─ 8a1f98411b0ffff (res:10, count:2, children:0)
#       │     │  ├─ 8a1f98411b27fff (res:10, count:547, children:0)
#       │     │  ├─ 8a1f98411b2ffff (res:10, count:405, children:0)
#       │     │  ├─ 8a1f98411b17fff (res:10, count:4, children:0)
#       │     │  ├─ 8a1f98411b1ffff (res:10, count:102, children:0)
#       │     │  └─ 8a1f98411b37fff (res:10, count:78, children:0)
#       │     ├─ 891f98411abffff (res:9, count:861, children:7)
#       │     │  ├─ 8a1f98411aaffff (res:10, count:114, children:0)
#       │     │  ├─ 8a1f98411a9ffff (res:10, count:136, children:0)
#       │     │  ├─ 8a1f98411ab7fff (res:10, count:102, children:0)
#       │     │  ├─ 8a1f98411aa7fff (res:10, count:240, children:0)
#       │     │  ├─ 8a1f98411a87fff (res:10, count:77, children:0)
#       │     │  ├─ 8a1f98411a97fff (res:10, count:147, children:0)
#       │     │  └─ 8a1f98411a8ffff (res:10, count:45, children:0)
#       │     ├─ 891f98411b7ffff (res:9, count:2181, children:7)
#       │     │  ├─ 8a1f98411b67fff (res:10, count:379, children:0)
#       │     │  ├─ 8a1f98411b4ffff (res:10, count:597, children:0)
#       │     │  ├─ 8a1f98411b57fff (res:10, count:195, children:0)
#       │     │  ├─ 8a1f98411b77fff (res:10, count:351, children:0)
#       │     │  ├─ 8a1f98411b47fff (res:10, count:240, children:0)
#       │     │  ├─ 8a1f98411b6ffff (res:10, count:136, children:0)
#       │     │  └─ 8a1f98411b5ffff (res:10, count:283, children:0)
#       │     ├─ 891f98411bbffff (res:9, count:1026, children:6)
#       │     │  ├─ 8a1f98411b9ffff (res:10, count:55, children:0)
#       │     │  ├─ 8a1f98411b8ffff (res:10, count:104, children:0)
#       │     │  ├─ 8a1f98411bb7fff (res:10, count:269, children:0)
#       │     │  ├─ 8a1f98411b87fff (res:10, count:265, children:0)
#       │     │  ├─ 8a1f98411ba7fff (res:10, count:221, children:0)
#       │     │  └─ 8a1f98411b97fff (res:10, count:112, children:0)
#       │     └─ 891f98411a3ffff (res:9, count:1571, children:7)
#       │        ├─ 8a1f98411a17fff (res:10, count:131, children:0)
#       │        ├─ 8a1f98411a1ffff (res:10, count:117, children:0)
#       │        ├─ 8a1f98411a0ffff (res:10, count:194, children:0)
#       │        ├─ 8a1f98411a27fff (res:10, count:178, children:0)
#       │        ├─ 8a1f98411a07fff (res:10, count:105, children:0)
#       │        ├─ 8a1f98411a37fff (res:10, count:341, children:0)
#       │        └─ 8a1f98411a2ffff (res:10, count:505, children:0)
#       └─ 871f98415ffffff (res:7, count:27762, children:6)
#          ├─ 881f984159fffff (res:8, count:6612, children:7)
#          │  ├─ 891f984159bffff (res:9, count:1362, children:7)
#          │  │  ├─ 8a1f984159b7fff (res:10, count:229, children:0)
#          │  │  ├─ 8a1f98415997fff (res:10, count:118, children:0)
#          │  │  ├─ 8a1f9841599ffff (res:10, count:83, children:0)
#          │  │  ├─ 8a1f98415987fff (res:10, count:136, children:0)
#          │  │  ├─ 8a1f984159a7fff (res:10, count:155, children:0)
#          │  │  ├─ 8a1f984159affff (res:10, count:399, children:0)
#          │  │  └─ 8a1f9841598ffff (res:10, count:242, children:0)
#          │  ├─ 891f9841593ffff (res:9, count:949, children:7)
#          │  │  ├─ 8a1f98415907fff (res:10, count:57, children:0)
#          │  │  ├─ 8a1f9841592ffff (res:10, count:51, children:0)
#          │  │  ├─ 8a1f98415937fff (res:10, count:191, children:0)
#          │  │  ├─ 8a1f98415917fff (res:10, count:248, children:0)
#          │  │  ├─ 8a1f9841590ffff (res:10, count:6, children:0)
#          │  │  ├─ 8a1f9841591ffff (res:10, count:150, children:0)
#          │  │  └─ 8a1f98415927fff (res:10, count:246, children:0)
#          │  ├─ 891f9841587ffff (res:9, count:425, children:7)
#          │  │  ├─ 8a1f98415857fff (res:10, count:104, children:0)
#          │  │  ├─ 8a1f9841586ffff (res:10, count:35, children:0)
#          │  │  ├─ 8a1f9841585ffff (res:10, count:100, children:0)
#          │  │  ├─ 8a1f98415877fff (res:10, count:17, children:0)
#          │  │  ├─ 8a1f98415847fff (res:10, count:86, children:0)
#          │  │  ├─ 8a1f9841584ffff (res:10, count:26, children:0)
#          │  │  └─ 8a1f98415867fff (res:10, count:57, children:0)
#          │  ├─ 891f984158fffff (res:9, count:674, children:7)
#          │  │  ├─ 8a1f984158f7fff (res:10, count:94, children:0)
#          │  │  ├─ 8a1f984158d7fff (res:10, count:68, children:0)
#          │  │  ├─ 8a1f984158dffff (res:10, count:62, children:0)
#          │  │  ├─ 8a1f984158cffff (res:10, count:115, children:0)
#          │  │  ├─ 8a1f984158c7fff (res:10, count:165, children:0)
#          │  │  ├─ 8a1f984158effff (res:10, count:71, children:0)
#          │  │  └─ 8a1f984158e7fff (res:10, count:99, children:0)
#          │  ├─ 891f9841597ffff (res:9, count:1440, children:7)
#          │  │  ├─ 8a1f98415957fff (res:10, count:261, children:0)
#          │  │  ├─ 8a1f9841594ffff (res:10, count:137, children:0)
#          │  │  ├─ 8a1f98415947fff (res:10, count:38, children:0)
#          │  │  ├─ 8a1f98415977fff (res:10, count:64, children:0)
#          │  │  ├─ 8a1f98415967fff (res:10, count:478, children:0)
#          │  │  ├─ 8a1f9841596ffff (res:10, count:385, children:0)
#          │  │  └─ 8a1f9841595ffff (res:10, count:77, children:0)
#          │  ├─ 891f9841583ffff (res:9, count:985, children:7)
#          │  │  ├─ 8a1f9841581ffff (res:10, count:119, children:0)
#          │  │  ├─ 8a1f9841582ffff (res:10, count:47, children:0)
#          │  │  ├─ 8a1f98415807fff (res:10, count:111, children:0)
#          │  │  ├─ 8a1f9841580ffff (res:10, count:105, children:0)
#          │  │  ├─ 8a1f98415827fff (res:10, count:89, children:0)
#          │  │  ├─ 8a1f98415817fff (res:10, count:239, children:0)
#          │  │  └─ 8a1f98415837fff (res:10, count:275, children:0)
#          │  └─ 891f984158bffff (res:9, count:777, children:7)
#          │     ├─ 8a1f98415897fff (res:10, count:319, children:0)
#          │     ├─ 8a1f9841588ffff (res:10, count:93, children:0)
#          │     ├─ 8a1f9841589ffff (res:10, count:103, children:0)
#          │     ├─ 8a1f984158a7fff (res:10, count:42, children:0)
#          │     ├─ 8a1f984158affff (res:10, count:153, children:0)
#          │     ├─ 8a1f98415887fff (res:10, count:43, children:0)
#          │     └─ 8a1f984158b7fff (res:10, count:24, children:0)
#          ├─ 881f98415bfffff (res:8, count:8939, children:7)
#          │  ├─ 891f98415abffff (res:9, count:1058, children:7)
#          │  │  ├─ 8a1f98415a9ffff (res:10, count:143, children:0)
#          │  │  ├─ 8a1f98415a97fff (res:10, count:193, children:0)
#          │  │  ├─ 8a1f98415aaffff (res:10, count:83, children:0)
#          │  │  ├─ 8a1f98415ab7fff (res:10, count:58, children:0)
#          │  │  ├─ 8a1f98415a8ffff (res:10, count:207, children:0)
#          │  │  ├─ 8a1f98415a87fff (res:10, count:177, children:0)
#          │  │  └─ 8a1f98415aa7fff (res:10, count:197, children:0)
#          │  ├─ 891f98415a3ffff (res:9, count:815, children:7)
#          │  │  ├─ 8a1f98415a07fff (res:10, count:27, children:0)
#          │  │  ├─ 8a1f98415a37fff (res:10, count:40, children:0)
#          │  │  ├─ 8a1f98415a17fff (res:10, count:127, children:0)
#          │  │  ├─ 8a1f98415a0ffff (res:10, count:150, children:0)
#          │  │  ├─ 8a1f98415a2ffff (res:10, count:211, children:0)
#          │  │  ├─ 8a1f98415a1ffff (res:10, count:190, children:0)
#          │  │  └─ 8a1f98415a27fff (res:10, count:70, children:0)
#          │  ├─ 891f98415b7ffff (res:9, count:1458, children:7)
#          │  │  ├─ 8a1f98415b77fff (res:10, count:209, children:0)
#          │  │  ├─ 8a1f98415b67fff (res:10, count:268, children:0)
#          │  │  ├─ 8a1f98415b5ffff (res:10, count:161, children:0)
#          │  │  ├─ 8a1f98415b4ffff (res:10, count:196, children:0)
#          │  │  ├─ 8a1f98415b6ffff (res:10, count:260, children:0)
#          │  │  ├─ 8a1f98415b47fff (res:10, count:227, children:0)
#          │  │  └─ 8a1f98415b57fff (res:10, count:137, children:0)
#          │  ├─ 891f98415b3ffff (res:9, count:1005, children:7)
#          │  │  ├─ 8a1f98415b27fff (res:10, count:189, children:0)
#          │  │  ├─ 8a1f98415b07fff (res:10, count:78, children:0)
#          │  │  ├─ 8a1f98415b1ffff (res:10, count:85, children:0)
#          │  │  ├─ 8a1f98415b0ffff (res:10, count:193, children:0)
#          │  │  ├─ 8a1f98415b37fff (res:10, count:90, children:0)
#          │  │  ├─ 8a1f98415b17fff (res:10, count:228, children:0)
#          │  │  └─ 8a1f98415b2ffff (res:10, count:142, children:0)
#          │  ├─ 891f98415a7ffff (res:9, count:1638, children:7)
#          │  │  ├─ 8a1f98415a57fff (res:10, count:121, children:0)
#          │  │  ├─ 8a1f98415a77fff (res:10, count:136, children:0)
#          │  │  ├─ 8a1f98415a47fff (res:10, count:298, children:0)
#          │  │  ├─ 8a1f98415a67fff (res:10, count:151, children:0)
#          │  │  ├─ 8a1f98415a4ffff (res:10, count:317, children:0)
#          │  │  ├─ 8a1f98415a5ffff (res:10, count:181, children:0)
#          │  │  └─ 8a1f98415a6ffff (res:10, count:434, children:0)
#          │  ├─ 891f98415afffff (res:9, count:2224, children:7)
#          │  │  ├─ 8a1f98415af7fff (res:10, count:371, children:0)
#          │  │  ├─ 8a1f98415ac7fff (res:10, count:576, children:0)
#          │  │  ├─ 8a1f98415aeffff (res:10, count:101, children:0)
#          │  │  ├─ 8a1f98415ae7fff (res:10, count:191, children:0)
#          │  │  ├─ 8a1f98415adffff (res:10, count:55, children:0)
#          │  │  ├─ 8a1f98415ad7fff (res:10, count:835, children:0)
#          │  │  └─ 8a1f98415acffff (res:10, count:95, children:0)
#          │  └─ 891f98415bbffff (res:9, count:741, children:7)
#          │     ├─ 8a1f98415b9ffff (res:10, count:120, children:0)
#          │     ├─ 8a1f98415ba7fff (res:10, count:58, children:0)
#          │     ├─ 8a1f98415b87fff (res:10, count:148, children:0)
#          │     ├─ 8a1f98415b97fff (res:10, count:106, children:0)
#          │     ├─ 8a1f98415bb7fff (res:10, count:252, children:0)
#          │     ├─ 8a1f98415b8ffff (res:10, count:34, children:0)
#          │     └─ 8a1f98415baffff (res:10, count:23, children:0)
#          ├─ 881f984151fffff (res:8, count:2487, children:5)
#          │  ├─ 891f9841517ffff (res:9, count:764, children:7)
#          │  │  ├─ 8a1f98415147fff (res:10, count:96, children:0)
#          │  │  ├─ 8a1f98415157fff (res:10, count:227, children:0)
#          │  │  ├─ 8a1f9841516ffff (res:10, count:41, children:0)
#          │  │  ├─ 8a1f98415167fff (res:10, count:103, children:0)
#          │  │  ├─ 8a1f9841515ffff (res:10, count:194, children:0)
#          │  │  ├─ 8a1f98415177fff (res:10, count:92, children:0)
#          │  │  └─ 8a1f9841514ffff (res:10, count:11, children:0)
#          │  ├─ 891f9841503ffff (res:9, count:3, children:2)
#          │  │  ├─ 8a1f9841502ffff (res:10, count:2, children:0)
#          │  │  └─ 8a1f98415027fff (res:10, count:1, children:0)
#          │  ├─ 891f9841513ffff (res:9, count:907, children:6)
#          │  │  ├─ 8a1f98415127fff (res:10, count:24, children:0)
#          │  │  ├─ 8a1f9841511ffff (res:10, count:27, children:0)
#          │  │  ├─ 8a1f9841510ffff (res:10, count:381, children:0)
#          │  │  ├─ 8a1f98415137fff (res:10, count:197, children:0)
#          │  │  ├─ 8a1f98415107fff (res:10, count:277, children:0)
#          │  │  └─ 8a1f9841512ffff (res:10, count:1, children:0)
#          │  ├─ 891f9841507ffff (res:9, count:789, children:5)
#          │  │  ├─ 8a1f9841504ffff (res:10, count:116, children:0)
#          │  │  ├─ 8a1f98415057fff (res:10, count:416, children:0)
#          │  │  ├─ 8a1f9841506ffff (res:10, count:115, children:0)
#          │  │  ├─ 8a1f98415077fff (res:10, count:133, children:0)
#          │  │  └─ 8a1f9841505ffff (res:10, count:9, children:0)
#          │  └─ 891f984150fffff (res:9, count:24, children:1)
#          │     └─ 8a1f984150effff (res:10, count:24, children:0)
#          ├─ 881f984153fffff (res:8, count:5945, children:7)
#          │  ├─ 891f984152fffff (res:9, count:716, children:5)
#          │  │  ├─ 8a1f984152cffff (res:10, count:60, children:0)
#          │  │  ├─ 8a1f984152effff (res:10, count:31, children:0)
#          │  │  ├─ 8a1f984152dffff (res:10, count:165, children:0)
#          │  │  ├─ 8a1f984152c7fff (res:10, count:333, children:0)
#          │  │  └─ 8a1f984152e7fff (res:10, count:127, children:0)
#          │  ├─ 891f9841527ffff (res:9, count:1286, children:7)
#          │  │  ├─ 8a1f98415267fff (res:10, count:112, children:0)
#          │  │  ├─ 8a1f9841524ffff (res:10, count:328, children:0)
#          │  │  ├─ 8a1f9841526ffff (res:10, count:102, children:0)
#          │  │  ├─ 8a1f9841525ffff (res:10, count:135, children:0)
#          │  │  ├─ 8a1f98415247fff (res:10, count:327, children:0)
#          │  │  ├─ 8a1f98415257fff (res:10, count:163, children:0)
#          │  │  └─ 8a1f98415277fff (res:10, count:119, children:0)
#          │  ├─ 891f9841533ffff (res:9, count:959, children:7)
#          │  │  ├─ 8a1f9841532ffff (res:10, count:171, children:0)
#          │  │  ├─ 8a1f9841531ffff (res:10, count:82, children:0)
#          │  │  ├─ 8a1f98415317fff (res:10, count:95, children:0)
#          │  │  ├─ 8a1f98415307fff (res:10, count:131, children:0)
#          │  │  ├─ 8a1f98415337fff (res:10, count:197, children:0)
#          │  │  ├─ 8a1f9841530ffff (res:10, count:31, children:0)
#          │  │  └─ 8a1f98415327fff (res:10, count:252, children:0)
#          │  ├─ 891f984153bffff (res:9, count:1051, children:7)
#          │  │  ├─ 8a1f984153a7fff (res:10, count:124, children:0)
#          │  │  ├─ 8a1f98415387fff (res:10, count:226, children:0)
#          │  │  ├─ 8a1f9841539ffff (res:10, count:14, children:0)
#          │  │  ├─ 8a1f98415397fff (res:10, count:101, children:0)
#          │  │  ├─ 8a1f984153affff (res:10, count:132, children:0)
#          │  │  ├─ 8a1f984153b7fff (res:10, count:306, children:0)
#          │  │  └─ 8a1f9841538ffff (res:10, count:148, children:0)
#          │  ├─ 891f9841537ffff (res:9, count:934, children:7)
#          │  │  ├─ 8a1f98415377fff (res:10, count:130, children:0)
#          │  │  ├─ 8a1f9841534ffff (res:10, count:269, children:0)
#          │  │  ├─ 8a1f98415357fff (res:10, count:66, children:0)
#          │  │  ├─ 8a1f9841535ffff (res:10, count:47, children:0)
#          │  │  ├─ 8a1f98415367fff (res:10, count:90, children:0)
#          │  │  ├─ 8a1f98415347fff (res:10, count:79, children:0)
#          │  │  └─ 8a1f9841536ffff (res:10, count:253, children:0)
#          │  ├─ 891f984152bffff (res:9, count:199, children:3)
#          │  │  ├─ 8a1f98415297fff (res:10, count:56, children:0)
#          │  │  ├─ 8a1f9841529ffff (res:10, count:139, children:0)
#          │  │  └─ 8a1f9841528ffff (res:10, count:4, children:0)
#          │  └─ 891f9841523ffff (res:9, count:800, children:5)
#          │     ├─ 8a1f98415207fff (res:10, count:215, children:0)
#          │     ├─ 8a1f9841520ffff (res:10, count:77, children:0)
#          │     ├─ 8a1f98415237fff (res:10, count:134, children:0)
#          │     ├─ 8a1f98415227fff (res:10, count:236, children:0)
#          │     └─ 8a1f9841522ffff (res:10, count:138, children:0)
#          ├─ 881f984157fffff (res:8, count:829, children:2)
#          │  ├─ 891f9841567ffff (res:9, count:778, children:5)
#          │  │  ├─ 8a1f9841564ffff (res:10, count:23, children:0)
#          │  │  ├─ 8a1f98415647fff (res:10, count:214, children:0)
#          │  │  ├─ 8a1f98415667fff (res:10, count:5, children:0)
#          │  │  ├─ 8a1f9841566ffff (res:10, count:66, children:0)
#          │  │  └─ 8a1f9841565ffff (res:10, count:470, children:0)
#          │  └─ 891f9841577ffff (res:9, count:51, children:2)
#          │     ├─ 8a1f9841574ffff (res:10, count:15, children:0)
#          │     └─ 8a1f9841576ffff (res:10, count:36, children:0)
#          └─ 881f984155fffff (res:8, count:2950, children:3)
#             ├─ 891f9841543ffff (res:9, count:5, children:1)
#             │  └─ 8a1f9841541ffff (res:10, count:5, children:0)
#             ├─ 891f984154fffff (res:9, count:9, children:1)
#             │  └─ 8a1f984154e7fff (res:10, count:9, children:0)
#             └─ 891f984154bffff (res:9, count:2936, children:1)
#                └─ 8a1f984154affff (res:10, count:2936, children:0)

# %%
import numpy as np
import pandas as pd
import weakref
from math import *

class H3SbaAggregator:
    def __init__(self, od_matrix, tree_start, tree_end, param):
        """
        Adattamento per lavorare con:
        - od_matrix: DataFrame con colonne ['start_h3', 'end_h3', 'count', 't'] (t opzionale)
        - tree_start: H3HierarchicalTree per le origini
        - tree_end: H3HierarchicalTree per le destinazioni
        """
        # Adattamento per H3 con le colonne corrette
        self.od_matrix = od_matrix.copy()
        self.od_matrix = self.od_matrix.rename(columns={
            'start_h3': 'oi', 
            'end_h3': 'di', 
            'count': 'vol'
        })
        
        self.tree_start = tree_start
        self.tree_end = tree_end
        self.param = param

        if param.get('target_vol_o') is None:
            raise ValueError('Must set a target_vol_o for tree aggregation')
        self.target_vol_o = param['target_vol_o']
        
        self.anon_thres = param['anon_thres']
        self.suppr_thres_frac = param['suppr_thres_frac']

        # Gestione dei timestep
        if 't' in self.od_matrix.columns:
            vol_ori_df = self.od_matrix.groupby('t')['vol'].sum().reset_index()
        else:
            self.od_matrix['t'] = 0
            vol_ori_df = pd.DataFrame({'t': [0], 'vol': [self.od_matrix['vol'].sum()]})

        self.eval_df = pd.DataFrame(columns=['t', 'vol_ori', 'vol_kept', 'nb_flows'])
        self.od_matrix_agg = pd.DataFrame(columns=['coi', 'cdi', 'vol', 't', 'censored'])
        self.od_matrix_agg['censored'] = self.od_matrix_agg['censored'].astype(bool)

        for _, vol_ori_row in vol_ori_df.iterrows():
            timestep = vol_ori_row['t']
            od_matrix_agg_timestep = self.solve_timestep(timestep)

            total_vol = od_matrix_agg_timestep['vol'].sum()
            if total_vol != vol_ori_row['vol']:
                if total_vol >= self.anon_thres:
                    print(f"Warning: missing some volumes! ({od_matrix_agg_timestep['vol'].sum()} vs {vol_ori_row['vol']})")
                else:
                    print('Censored everything as total volume < anon thres')

            self.od_matrix_agg = pd.concat([self.od_matrix_agg, od_matrix_agg_timestep])

            eval_row = {
                't': timestep,
                'vol_ori': vol_ori_row['vol'],
                'vol_kept': (od_matrix_agg_timestep['vol']*(~od_matrix_agg_timestep['censored'])).sum(),
                'nb_flows': len(self.od_matrix_timestep),
            }
            self.eval_df = pd.concat([self.eval_df, pd.DataFrame(eval_row, index=[len(self.eval_df)])])

    def solve_timestep(self, timestep):
        ori_df = self.get_ori_df(timestep)
        total_vol = ori_df.sum()
        
        if total_vol < self.anon_thres:
            return pd.DataFrame({'coi': [self.tree_start.root.h3_id],
                                 'cdi': [self.tree_end.root.h3_id],
                                 'vol': 0,
                                 'censored': total_vol != 0})
        elif total_vol == self.anon_thres:
            return pd.DataFrame({'coi': [self.tree_start.root.h3_id],
                                 'cdi': [self.tree_end.root.h3_id],
                                 'vol': total_vol,
                                 'censored': False})
        
        qo = H3VQuadtree(pop_df=ori_df,
                         h3_root=self.tree_start.root,
                         target_vol=self.target_vol_o,
                         ci_col='oi', vol_col='vol')
        o_partition = qo.flat_leaves

        od_matrix_agg_timestep = self.get_dest_agg(o_partition)
        od_matrix_agg_timestep['t'] = timestep
        od_matrix_agg_timestep['censored'] = (od_matrix_agg_timestep['vol'] < self.param['anon_thres']) & (od_matrix_agg_timestep['vol'] != 0)

        return od_matrix_agg_timestep

    def get_dest_agg(self, clusters_o):
        dest_df = self.get_dest_df(clusters_o)

        tree = H3SbaTree(pop_df=dest_df,
                         h3_root=self.tree_end.root,
                         clusters_o=clusters_o,
                         anon_thres=self.anon_thres)

        OD_report = tree.sba_solve(self.suppr_thres_frac * sum([co.vol for co in clusters_o]))
        od_matrix_agg_timestep = pd.DataFrame(OD_report, columns=['coi', 'cdi', 'vol'])

        return od_matrix_agg_timestep

    def get_ori_df(self, timestep):
        self.od_matrix_timestep = self.od_matrix[self.od_matrix['t'] == timestep]
        ori_df = self.od_matrix_timestep.groupby('oi')['vol'].sum()
        return ori_df

    def get_dest_df(self, clusters_o):
        nb_leaves_by_cluster_o = [len(cluster_o.flat_leaves_name) for cluster_o in clusters_o]
        oicoidf = pd.DataFrame({
             'oi': np.concatenate([cluster_o.flat_leaves_name for cluster_o in clusters_o]),
             'coi': np.repeat([cluster_o.h3_node.h3_id for cluster_o in clusters_o], nb_leaves_by_cluster_o)})

        dest_df = self.od_matrix_timestep.merge(oicoidf, on='oi', how='outer').drop(columns=['oi'])
        dest_df = dest_df.groupby(['coi', 'di'])['vol'].sum().reset_index()
        dest_df = dest_df.groupby('di').agg(list)

        return dest_df


class H3SbaTree:
    def __init__(self, pop_df, h3_root, clusters_o, anon_thres=0):
        self.pop_df = pop_df
        self.anon_thres = anon_thres
        
        self.clusters_o = clusters_o
        self.cluster_order = {cluster.h3_node.h3_id: i for i, cluster in enumerate(clusters_o)}
        
        self.area = h3_root.resolution
        self.areas_o = np.array([co.h3_node.resolution for co in self.clusters_o])
        
        self.root = H3SbaNode(h3_root, weakref.ref(self))

    def sba_solve(self, S):
        left_delta = 0
        self.root.activate(left_delta)
        left_slope = self.root.best_vol_suppr.sum() - S
        left_score = self.root.best_score.sum() - left_delta*S
        if left_slope < 0:
            return self.get_leaves_arr()

        right_delta = self.area
        self.root.activate(right_delta)
        right_slope = self.root.best_vol_suppr.sum() - S
        right_score = self.root.best_score.sum() - right_delta*S
        
        while right_slope > 0:
            left_delta = right_delta
            left_slope = right_slope
            left_score = right_score
            right_delta += self.area
            self.root.activate(right_delta)
            right_slope = self.root.best_vol_suppr.sum() - S
            right_score = self.root.best_score.sum() - right_delta*S
        
        while True:
            mid_delta = (left_slope*left_delta - right_slope*right_delta + right_score - left_score)/(left_slope - right_slope)
            self.root.activate(mid_delta)
            mid_slope = self.root.best_vol_suppr.sum() - S
            mid_score = self.root.best_score.sum() - mid_delta*S
            
            if round(mid_delta-left_delta, 5) == 0 or round(mid_delta-right_delta, 5) == 0:
                return self.get_leaves_arr()
            else:
                if mid_slope > 0:
                    left_delta = mid_delta
                    left_slope = mid_slope
                    left_score = mid_score
                else:
                    right_delta = mid_delta
                    right_slope = mid_slope
                    right_score = mid_score

    def get_leaves_arr(self):
        leaves_arr = []
        for ori_counter in range(len(self.cluster_order)):
            self.root.get_leaves_arr_rec(leaves_arr, ori_counter)
        return leaves_arr


class H3SbaNode:
    def __init__(self, h3_tree_node, tree_weakref, parent=None):
        self.tree_weakref = tree_weakref
        self.h3_node = h3_tree_node
        self.k = self.tree_weakref().anon_thres
        
        self.children = [H3SbaNode(child, tree_weakref, self) for child in h3_tree_node.children.values()]
        cluster_order = self.tree_weakref().cluster_order
        self.vol_raw = np.zeros(len(cluster_order))
        
        if len(self.children) == 0:
            row = None
            try:
                row = self.tree_weakref().pop_df.loc[self.h3_node.h3_id]
            except KeyError:
                pass
            if row is not None:
                vols = row['vol']
                cois = row['coi']
                for i in range(len(cois)):
                    self.vol_raw[cluster_order[cois[i]]] = vols[i]
        elif len(self.children) > 0:
            self.vol_raw = np.sum([c.vol_raw for c in self.children], axis=0)
        
        self.censored = (self.vol_raw > 0) & (self.vol_raw < self.k)
        self.agg_vol_suppr = self.vol_raw * self.censored
        
        self.area = self.h3_node.resolution
        self.agg_error = self.vol_raw * (~self.censored) * (self.tree_weakref().areas_o + self.area)

    def activate(self, delta):
        for c in self.children:
            c.activate(delta)

        self.split_this = np.zeros(len(self.tree_weakref().clusters_o), dtype=bool)
        self.best_vol_suppr = self.agg_vol_suppr.copy()
        self.best_score = self.agg_error + self.agg_vol_suppr * delta

        if len(self.children) > 0:
            split_score = np.sum([c.best_score for c in self.children], axis=0)
            split_mask = (split_score < self.best_score) & (self.vol_raw > self.k)
            self.split_this[split_mask] = True
            self.best_score[split_mask] = split_score[split_mask]
            split_vol_suppr = np.sum([c.best_vol_suppr for c in self.children], axis=0)
            self.best_vol_suppr[split_mask] = split_vol_suppr[split_mask]

    def summary(self, ori_counter):
        cluster_h3_id = self.tree_weakref().clusters_o[ori_counter].h3_node.h3_id
        return [cluster_h3_id, self.h3_node.h3_id, self.vol_raw[ori_counter]]

    def get_leaves_arr_rec(self, leaves_arr, ori_counter):
        if not self.split_this[ori_counter]:
            leaves_arr += [self.summary(ori_counter)]
        else:
            for c in self.children:
                c.get_leaves_arr_rec(leaves_arr, ori_counter)


class H3VQuadtree:
    def __init__(self, pop_df, h3_root, target_vol, ci_col, vol_col):
        self.h3_root = h3_root
        self.pop_df = pop_df
        self.target_vol = target_vol
        self.flat_leaves = []
        self.ci_col = ci_col
        self.vol_col = vol_col
        self.grow()

    def grow(self):
        self.root = H3VQuadNode(self.h3_root, self)
        self.root.compute_best_split()
        self.root.keep_subtree(keep_condition=lambda x: x.split_this)
        self.flat_leaves = self.flatten_leaves()

    def flatten_leaves(self):
        flat_leaves = []
        self.root.flatten_leaves_rec(flat_leaves)
        return flat_leaves

    def get_total_error(self):
        return sum([leaf.error for leaf in self.flat_leaves])


class H3VQuadNode:
    def __init__(self, h3_tree_node, tree):
        self.tree = tree
        self.h3_node = h3_tree_node
        self.children = [H3VQuadNode(child, tree) for child in h3_tree_node.children.values()]
        if len(self.children) == 0:
            try:
                self.vol = self.tree.pop_df.loc[self.h3_node.h3_id]
            except KeyError:
                self.vol = 0
        else:
            self.vol = sum([c.vol for c in self.children])
        self.h3_node.vol = self.vol
        if len(self.children) == 0:
            self.flat_leaves_name = [self.h3_node.h3_id]
        else:
            self.flat_leaves_name = []
            for child in self.children:
                self.flat_leaves_name.extend(child.flat_leaves_name)
        self.error = self.compute_error()

    def compute_error(self):
        if self.vol == 0:
            return 0
        return (self.tree.target_vol - self.vol)**2

    def keep_subtree(self, keep_condition):
        if keep_condition(self):
            for c in self.children:
                c.keep_subtree(keep_condition)
        else:
            self.children = []

    def compute_best_split(self):
        self.split_this = False
        self.best_score = self.error
        if self.vol > 0:
            if len(self.children) == 0:
                self.split_this = False
            else:
                for c in self.children:
                    c.compute_best_split()
                split_score = sum([c.best_score for c in self.children])
                if split_score <= self.error:
                    self.split_this = True
                    self.best_score = split_score

    def flatten_leaves_rec(self, flat_leaves):
        if len(self.children) == 0:
            flat_leaves += [self]
        else:
            for c in self.children:
                c.flatten_leaves_rec(flat_leaves)

param = {
    'anon_thres': 10,
    'suppr_thres_frac': 0.1,
    'target_vol_o': 2500,
}

aggregator = H3SbaAggregator(
    od_matrix=od_matrix,
    tree_start=tree_start,
    tree_end=tree_end,
    param=param
)
# Out:
# C:\Users\dmc\AppData\Local\Temp\ipykernel_11108\1864310396.py:55: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   self.od_matrix_agg = pd.concat([self.od_matrix_agg, od_matrix_agg_timestep])
# C:\Users\dmc\AppData\Local\Temp\ipykernel_11108\1864310396.py:63: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   self.eval_df = pd.concat([self.eval_df, pd.DataFrame(eval_row, index=[len(self.eval_df)])])

# %%
od_matrix_agg = aggregator.od_matrix_agg

# %%
censored_rows = od_matrix_agg[od_matrix_agg["censored"] == True]
print(censored_rows)
# Out:
#                    coi              cdi  vol  t  censored
# 7      891f9840157ffff  871f9841effffff  3.0  0      True
# 9      891f9840157ffff  881f9841c5fffff  1.0  0      True
# 10     891f9840157ffff  881f9841cdfffff  2.0  0      True
# 11     891f9840157ffff  881f9841c9fffff  4.0  0      True
# 12     891f9840157ffff  881f9841c1fffff  6.0  0      True
# ...                ...              ...  ... ..       ...
# 28857  891f98415a7ffff  881f9840e3fffff  1.0  0      True
# 28858  891f98415a7ffff  881f9840edfffff  1.0  0      True
# 28859  891f98415a7ffff  881f9840e7fffff  1.0  0      True
# 28860  891f98415a7ffff  881f9840e9fffff  1.0  0      True
# 28867  8a1f98415d67fff  851f9843fffffff  1.0  0      True
#
# [22961 rows x 5 columns]

# %%
suppressed_count = od_matrix_agg[od_matrix_agg["censored"] == True]["vol"].sum()
print(f"Totale volume soppresso: {suppressed_count}")
# Out:
# Totale volume soppresso: 78108.0

# %%
od_matrix_agg = od_matrix_agg[od_matrix_agg["censored"] == False]
od_matrix_agg = od_matrix_agg.rename(columns={
    "coi": "start_h3",
    "cdi": "end_h3",
    "vol": "count"
})

od_matrix_agg = od_matrix_agg.drop(columns=["t", "censored"], errors="ignore")
od_matrix_agg
# Out:
#               start_h3           end_h3   count
# 0      891f9840173ffff  851f9843fffffff  1060.0
# 1      891f984016bffff  851f9843fffffff  1846.0
# 2      891f9840163ffff  851f9843fffffff  1103.0
# 3      891f984017bffff  851f9843fffffff  1167.0
# 4      891f9840177ffff  851f9843fffffff   899.0
# ...                ...              ...     ...
# 28863  891f98415bbffff  851f9843fffffff   728.0
# 28864  881f984151fffff  851f9843fffffff  2390.0
# 28865  881f984153fffff  851f9843fffffff  5926.0
# 28866  881f984157fffff  851f9843fffffff   840.0
# 28868  881f984155fffff  851f9843fffffff  2964.0
#
# [5908 rows x 3 columns]

# %%
od_matrix_agg[od_matrix_agg['count'] == 0.0]
# Out:
#               start_h3           end_h3  count
# 8      891f9840157ffff  881f9841c3fffff    0.0
# 16     891f9840157ffff  891f9841cabffff    0.0
# 18     891f9840157ffff  891f9841cbbffff    0.0
# 23     891f9840157ffff  881f984047fffff    0.0
# 26     891f9840157ffff  881f984049fffff    0.0
# ...                ...              ...    ...
# 28821  891f98415a7ffff  8a1f984063b7fff    0.0
# 28822  891f98415a7ffff  8a1f98406387fff    0.0
# 28823  891f98415a7ffff  8a1f9840639ffff    0.0
# 28832  891f98415a7ffff  8a1f984066affff    0.0
# 28854  891f98415a7ffff  881f9840ebfffff    0.0
#
# [4920 rows x 3 columns]

# %%
od_matrix_agg = od_matrix_agg[od_matrix_agg['count'] > 0.0]

# %%
import folium
import h3
import pandas as pd
import numpy as np

class H3FoliumODVisualizer:
    """
    Visualizza i risultati di od_matrix_agg su mappa Folium
    """
    def __init__(self, od_matrix_agg, center_lat=45.0703, center_lon=7.6869):
        """
        Args:
            od_matrix_agg: DataFrame con colonne ['start_h3', 'end_h3', 'count']
                           (eventualmente anche altre colonne come censored/t)
            center_lat, center_lon: centro della mappa (default: Torino)
        """
        self.od_matrix = od_matrix_agg.copy()
        self.center_lat = center_lat
        self.center_lon = center_lon
        
        # Calcola aggregati per origine e destinazione
        self.origin_data = self.od_matrix.groupby("start_h3")["count"].sum().to_dict()
        self.destination_data = self.od_matrix.groupby("end_h3")["count"].sum().to_dict()
        
        # Estrai coppie OD con flussi
        self.od_pairs = list(zip(
            self.od_matrix["start_h3"],
            self.od_matrix["end_h3"],
            self.od_matrix["count"]
        ))
        
        print(f"✅ Estratti {len(self.origin_data)} origini, {len(self.destination_data)} destinazioni, {len(self.od_pairs)} coppie OD")

    def _h3_to_geojson(self, h3_id: str) -> dict:
        """Converte un esagono H3 in GeoJSON"""
        boundary = h3.cell_to_boundary(h3_id)
        coords = [[[lon, lat] for lat, lon in boundary]]
        return {
            "type": "Feature",
            "geometry": {"type": "Polygon", "coordinates": coords},
            "properties": {"h3_id": h3_id, "resolution": h3.get_resolution(h3_id)},
        }

    def create_base_map(self, zoom_start=10) -> folium.Map:
        """Crea la mappa base"""
        m = folium.Map(
            location=[self.center_lat, self.center_lon],
            zoom_start=zoom_start,
            tiles="OpenStreetMap"
        )
        return m
    
    def add_origin_hexagons(self, m: folium.Map, alpha=0.6):
        """Aggiunge esagoni di origine"""
        sorted_origins = sorted(self.origin_data.items(), key=lambda x: x[1], reverse=True)
        if not sorted_origins:
            return
        
        flows = [f for _, f in sorted_origins]
        min_flow, max_flow = min(flows), max(flows)
        group = folium.FeatureGroup(name=f"Origini ({len(sorted_origins)})", show=True)
        
        for rank, (h3_id, flow) in enumerate(sorted_origins, 1):
            try:
                geojson = self._h3_to_geojson(h3_id)
                intensity = (flow - min_flow) / (max_flow - min_flow) if max_flow > min_flow else 1.0
                blue_intensity = int(255 * (0.3 + intensity * 0.7))
                fill_color = f"#{0:02x}{0:02x}{blue_intensity:02x}"
                
                folium.GeoJson(
                    geojson,
                    style_function=lambda x, c=fill_color: {
                        "fillColor": c,
                        "color": "darkblue",
                        "weight": 1,
                        "fillOpacity": alpha,
                        "opacity": 0.8
                    },
                    tooltip=f"Origine: {flow:,} viaggi",
                    popup=folium.Popup(
                        f"<b>Origine H3</b><br>ID: {h3_id}<br>"
                        f"Risoluzione: {h3.get_resolution(h3_id)}<br>"
                        f"Flusso totale: {flow:,}<br>"
                        f"Rank: {rank}",
                        max_width=250
                    )
                ).add_to(group)
            except Exception as e:
                print(f"⚠️ Errore con origine {h3_id}: {e}")
        
        group.add_to(m)

    def add_destination_hexagons(self, m: folium.Map, alpha=0.6):
        """Aggiunge esagoni di destinazione"""
        sorted_dests = sorted(self.destination_data.items(), key=lambda x: x[1], reverse=True)
        if not sorted_dests:
            return
        
        flows = [f for _, f in sorted_dests]
        min_flow, max_flow = min(flows), max(flows)
        group = folium.FeatureGroup(name=f"Destinazioni ({len(sorted_dests)})", show=True)
        
        for rank, (h3_id, flow) in enumerate(sorted_dests, 1):
            try:
                geojson = self._h3_to_geojson(h3_id)
                intensity = (flow - min_flow) / (max_flow - min_flow) if max_flow > min_flow else 1.0
                red_intensity = int(255 * (0.3 + intensity * 0.7))
                fill_color = f"#{red_intensity:02x}{0:02x}{0:02x}"
                
                folium.GeoJson(
                    geojson,
                    style_function=lambda x, c=fill_color: {
                        "fillColor": c,
                        "color": "darkred",
                        "weight": 1,
                        "fillOpacity": alpha,
                        "opacity": 0.8
                    },
                    tooltip=f"Destinazione: {flow:,} viaggi",
                    popup=folium.Popup(
                        f"<b>Destinazione H3</b><br>ID: {h3_id}<br>"
                        f"Risoluzione: {h3.get_resolution(h3_id)}<br>"
                        f"Flusso totale: {flow:,}<br>"
                        f"Rank: {rank}",
                        max_width=250
                    )
                ).add_to(group)
            except Exception as e:
                print(f"⚠️ Errore con destinazione {h3_id}: {e}")
        
        group.add_to(m)

# %%
visualizer = H3FoliumODVisualizer(od_matrix_agg)

mappa = visualizer.create_base_map(zoom_start=11)

visualizer.add_origin_hexagons(mappa)
visualizer.add_destination_hexagons(mappa)

folium.LayerControl(collapsed=False).add_to(mappa)

mappa
# Out:
# ✅ Estratti 357 origini, 328 destinazioni, 988 coppie OD
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f0d95d446b784dc7adc3fca94fe8f6bf {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f0d95d446b784dc7adc3fca94fe8f6bf&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f0d95d446b784dc7adc3fca94fe8f6bf = L.map(
#                 &quot;map_f0d95d446b784dc7adc3fca94fe8f6bf&quot;,
#                 {
#                     center: [45.0703, 7.6869],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 11,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_af41b5f918b8df03af7a350c43eff31b = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_af41b5f918b8df03af7a350c43eff31b.addTo(map_f0d95d446b784dc7adc3fca94fe8f6bf);
#
#
#             var feature_group_47ccab21824fd0c8364c83549675cefd = L.featureGroup(
#                 {
# }
#             );
#
#
#         function geo_json_ea8a49b977c736d9dac75b6a8b272527_styler(feature) {
#             switch(feature.properties.h3_id) {
#                 default:
#                     return {&quot;color&quot;: &quot;darkblue&quot;, &quot;fillColor&quot;: &quot;#0000ff&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 0.8, &quot;weight&quot;: 1};
#             }
#         }
#
#         function geo_json_ea8a49b977c736d9dac75b6a8b272527_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_ea8a49b977c736d9dac75b6a8b272527 = L.geoJson(null, {
#                 onEachFeature: geo_json_ea8a49b977c736d9dac75b6a8b272527_onEachFeature,
#
#                 style: geo_json_ea8a49b977c736d9dac75b6a8b272527_styler,
#             ...{
# }
#         });
#
#         function geo_json_ea8a49b977c736d9dac75b6a8b272527_add (data) {
#             geo_json_ea8a49b977c736d9dac75b6a8b272527
#                 .addData(data);
#         }
#             geo_json_ea8a49b977c736d9dac75b6a8b272527_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[7.674419178187734, 45.06684137456642], [7.674653652720017, 45.06507302646515], [7.676977976357782, 45.064433852221164], [7.679067921287347, 45.06556302408581], [7.678833536394339, 45.06733139621468], [7.676509116929832, 45.06797057245236]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;properties&quot;: {&quot;h3_id&quot;: &quot;891f9840357ffff&quot;, &quot;resolution&quot;: 9}, &quot;type&quot;: &quot;Feature&quot;}], &quot;type&quot;: &quot;FeatureCollection&quot;});
#
#
#
#             geo_json_ea8a49b977c736d9dac75b6a8b272527.bindTooltip(
#                 `&lt;div&gt;
#                      Origine: 6,704.0 viaggi
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#         var popup_16faf97e99a1d9669899db4ea05eed4f = L.popup({
#   &quot;maxWidth&quot;: 250,
# });
#
#
#
#                 var html_1e1ae164fbaf0b941f80ffddb0db467c = $(`&lt;div id=&quot;html_1e1ae164fbaf0b941f80ffddb0db467c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Origine H3&lt;/b&gt;&lt;br&gt;ID: 891f9840357ffff&lt;br&gt;Risoluzione: 9&lt;br&gt;Flusso totale: 6,704.0&lt;br&gt;Rank: 1&lt;/div&gt;`)[0];
#                 popup_16faf97e99a1d9669899db4ea05eed4f.setContent(html_1e1ae164fbaf0b941f80ffddb0db467c);
#
#
#
#         geo_json_ea8a49b977c736d9dac75b6a8b272527.bindPopup(popup_16faf97e99a1d9669899db4ea05eed4f)
#         ;
#
#
#
#
#             geo_json_ea8a49b977c736d9dac75b6a8b272527.addTo(feature_group_47ccab21824fd0c8364c83549675cefd);
#
#
#         function geo_json_595091de2737519152596d9708c91b37_styler(feature) {
#             switch(feature.properties.h3_id) {
#                 default:
#                     return {&quot;color&quot;: &quot;darkblue&quot;, &quot;fillColor&quot;: &quot;#0000fd&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 0.8, &quot;weight&quot;: 1};
#             }
#         }
#
#         function geo_json_595091de2737519152596d9708c91b37_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_595091de2737519152596d9708c91b37 = L.geoJson(null, {
#                 onEachFeature: geo_json_595091de2737519152596d9708c91b37_onEachFeature,
#
#                 style: geo_json_595091de2737519152596d9708c91b37_styler,
#             ...{
# }
#         });
#
#         function geo_json_595091de2737519152596d9708c91b37_add (data) {
#             geo_json_595091de2737519152596d9708c91b37
#                 .addData(data);
#         }
#             geo_json_595091de2737519152596d9708c91b37_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[7.642293381233596, 45.106324479955134], [7.640673940602421, 45.10166016310049], [7.645559449995199, 45.09861674870909], [7.65206471955784, 45.10023751531358], [7.653684909065164, 45.10490189451702], [7.648799080162008, 45.10794544478656]]],

# %%
import numpy as np
import pandas as pd

def compute_discernability_and_cavg(df: pd.DataFrame, k: int, suppressed_count: int = 0) -> dict:
    """
    Calcola C_DM e C_AVG per un dataset OD generalizzato.
    
    Args:
        df: DataFrame con colonne ['start_h3', 'end_h3', 'count']
        k: soglia k-anonimity
        suppressed_count: numero di coppie OD soppressi (facoltativo)
    
    Returns:
        dict con C_DM, C_AVG, numero totale record e classi equivalenza
    """
    counts = df['count'].values
    total_records = counts.sum() + suppressed_count
    total_equiv_classes = len(counts) + suppressed_count
    total_records_avg = counts.sum()
    total_equiv_classes_avg = len(counts)
    
    # C_DM: somma dei quadrati dei count >= k
    k_anonymous_counts = counts[counts >= k]
    c_dm_gen = np.sum(k_anonymous_counts**2)
    
    # Penalità per record soppressi
    suppression_penalty = suppressed_count * counts.sum()  # ogni record soppresso "costa" quanto l'intero dataset
    c_dm = c_dm_gen + suppression_penalty
    
    # C_AVG: (total_records / total_equiv_classes) / k
    c_avg = (total_records_avg / total_equiv_classes_avg) / k if total_equiv_classes_avg > 0 else float('inf')
    
    return {
        'C_DM': c_dm,
        'C_AVG': c_avg,
        'total_records': total_records,
        'total_equivalence_classes': total_equiv_classes,
        'k': k
    }

# Esempio di utilizzo
metrics = compute_discernability_and_cavg(od_matrix_agg, k=10, suppressed_count=suppressed_count)
print("\n📊 Metrics di Discernibilità e CAVG:")
print(f"C_DM: {metrics['C_DM']:,}")
print(f"C_AVG: {metrics['C_AVG']:.4f}")
# Out:
# 📊 Metrics di Discernibilità e CAVG:
# C_DM: 57,975,486,138.0
# C_AVG: 71.9751

# %%
from geopy.distance import geodesic

def calculate_generalization_distance_metric(df: pd.DataFrame, od_matrix_generalized: pd.DataFrame) -> Dict:
   
   print("🔍 Calcolo metrica di distanza post-generalizzazione...")
   
   # 1. Crea mapping da esagoni originali a esagoni generalizzati
   start_original_to_generalized = {}
   end_original_to_generalized = {}
   
   # Ottieni tutti gli esagoni generalizzati unici
   generalized_start_h3 = set(od_matrix_generalized['start_h3'].unique())
   generalized_end_h3 = set(od_matrix_generalized['end_h3'].unique())
   
   # Per ogni esagono originale, trova l'esagono generalizzato corrispondente
   unique_start_h3 = df['start_h3'].unique()
   unique_end_h3 = df['end_h3'].unique()
   
   print(f"📊 Mappatura {len(unique_start_h3)} esagoni origine...")
   for original_h3 in unique_start_h3:
       generalized_h3 = find_generalized_hexagon(original_h3, generalized_start_h3)
       if generalized_h3:
           start_original_to_generalized[original_h3] = generalized_h3
   
   print(f"📊 Mappatura {len(unique_end_h3)} esagoni destinazione...")
   for original_h3 in unique_end_h3:
       generalized_h3 = find_generalized_hexagon(original_h3, generalized_end_h3)
       if generalized_h3:
           end_original_to_generalized[original_h3] = generalized_h3
   
   # 3. Calcola distanze per i punti di partenza
   start_distances = []
   start_coords = []
   
   for idx, row in df.iterrows():
       original_h3 = row['start_h3']
       original_coords = (row['start_lat'], row['start_lon'])
       
       if original_h3 in start_original_to_generalized:
           generalized_h3 = start_original_to_generalized[original_h3]
           generalized_coords = h3.cell_to_latlng(generalized_h3)
           
           distance = geodesic(original_coords, generalized_coords).meters
           
           start_distances.append(distance)
           start_coords.append({
               'original_h3': original_h3,
               'generalized_h3': generalized_h3,
               'original_coords': original_coords,
               'generalized_coords': generalized_coords,
               'distance': distance
           })
   
   # 4. Calcola distanze per i punti di destinazione
   end_distances = []
   end_coords = []
   
   for idx, row in df.iterrows():
       original_h3 = row['end_h3']
       original_coords = (row['end_lat'], row['end_lon'])
       
       if original_h3 in end_original_to_generalized:
           generalized_h3 = end_original_to_generalized[original_h3]
           generalized_coords = h3.cell_to_latlng(generalized_h3)
           
           distance = geodesic(original_coords, generalized_coords).meters
               
           end_distances.append(distance)
           end_coords.append({
               'original_h3': original_h3,
               'generalized_h3': generalized_h3,
               'original_coords': original_coords,
               'generalized_coords': generalized_coords,
               'distance': distance
           })
   
   # 5. Calcola statistiche
   results = {
       'start_distances': {
           'mean': np.mean(start_distances) if start_distances else 0,
           'median': np.median(start_distances) if start_distances else 0,
           'std': np.std(start_distances) if start_distances else 0,
           'min': np.min(start_distances) if start_distances else 0,
           'max': np.max(start_distances) if start_distances else 0,
           'count': len(start_distances)
       },
       'end_distances': {
           'mean': np.mean(end_distances) if end_distances else 0,
           'median': np.median(end_distances) if end_distances else 0,
           'std': np.std(end_distances) if end_distances else 0,
           'min': np.min(end_distances) if end_distances else 0,
           'max': np.max(end_distances) if end_distances else 0,
           'count': len(end_distances)
       },
       'overall': {
           'mean': np.mean(start_distances + end_distances) if (start_distances or end_distances) else 0,
           'median': np.median(start_distances + end_distances) if (start_distances or end_distances) else 0,
           'std': np.std(start_distances + end_distances) if (start_distances or end_distances) else 0,
           'total_points': len(start_distances) + len(end_distances)
       },
       'mappings': {
           'start_original_to_generalized': start_original_to_generalized,
           'end_original_to_generalized': end_original_to_generalized
       },
       'detailed_coords': {
           'start': start_coords,
           'end': end_coords
       }
   }
   
   # 6. Stampa risultati
   print("\n" + "="*60)
   print("📏 METRICHE DI DISTANZA POST-GENERALIZZAZIONE")
   print("="*60)
   
   print(f"\n🎯 PUNTI DI PARTENZA:")
   print(f"   • Distanza media: {results['start_distances']['mean']:.2f} metri")
   print(f"   • Distanza mediana: {results['start_distances']['median']:.2f} metri")
   print(f"   • Deviazione standard: {results['start_distances']['std']:.2f} metri")
   print(f"   • Min-Max: {results['start_distances']['min']:.2f} - {results['start_distances']['max']:.2f} metri")
   print(f"   • Punti analizzati: {results['start_distances']['count']:,}")
   
   print(f"\n🏁 PUNTI DI DESTINAZIONE:")
   print(f"   • Distanza media: {results['end_distances']['mean']:.2f} metri")
   print(f"   • Distanza mediana: {results['end_distances']['median']:.2f} metri")
   print(f"   • Deviazione standard: {results['end_distances']['std']:.2f} metri")
   print(f"   • Min-Max: {results['end_distances']['min']:.2f} - {results['end_distances']['max']:.2f} metri")
   print(f"   • Punti analizzati: {results['end_distances']['count']:,}")
   
   print(f"\n🌍 COMPLESSIVO:")
   print(f"   • Distanza media totale: {results['overall']['mean']:.2f} metri")
   print(f"   • Distanza mediana totale: {results['overall']['median']:.2f} metri")
   print(f"   • Deviazione standard totale: {results['overall']['std']:.2f} metri")
   print(f"   • Punti totali: {results['overall']['total_points']:,}")
   
   return results

def find_generalized_hexagon(original_h3: str, generalized_hexagons: set) -> str:
   """
   Trova l'esagono generalizzato corrispondente a un esagono originale
   """
   # Se l'esagono è già nella lista degli esagoni generalizzati
   if original_h3 in generalized_hexagons:
       return original_h3
   
   # Altrimenti cerca tra tutti gli esagoni generalizzati se l'originale è loro discendente
   for generalized_h3 in generalized_hexagons:
       if is_descendant_of(original_h3, generalized_h3):
           return generalized_h3
   
   return None

def is_descendant_of(child_h3: str, parent_h3: str) -> bool:
   """
   Controlla se child_h3 è discendente di parent_h3
   """
   child_res = h3.get_resolution(child_h3)
   parent_res = h3.get_resolution(parent_h3)
   
   if parent_res >= child_res:
       return False
   
   current = child_h3
   while h3.get_resolution(current) > parent_res:
       current = h3.cell_to_parent(current, h3.get_resolution(current) - 1)
   
   return current == parent_h3

def analyze_generalization_impact(results: Dict) -> None:
   """
   Analizza l'impatto della generalizzazione sulle distanze
   """
   print("\n" + "="*60)
   print("📊 ANALISI IMPATTO GENERALIZZAZIONE")
   print("="*60)
   
   # Calcola percentili
   all_distances = []
   for coord in results['detailed_coords']['start'] + results['detailed_coords']['end']:
       all_distances.append(coord['distance'])
   
   if all_distances:
       percentiles = [25, 50, 75, 90, 95, 99]
       print("\n📏 Distribuzione distanze:")
       for p in percentiles:
           value = np.percentile(all_distances, p)
           print(f"   • {p}° percentile: {value:.2f} metri")
   
   # Analizza per risoluzione
   resolution_analysis = {}
   for coord in results['detailed_coords']['start'] + results['detailed_coords']['end']:
       original_res = h3.get_resolution(coord['original_h3'])
       generalized_res = h3.get_resolution(coord['generalized_h3'])
       
       key = f"{original_res}→{generalized_res}"
       if key not in resolution_analysis:
           resolution_analysis[key] = []
       resolution_analysis[key].append(coord['distance'])
   
   print("\n🔍 Analisi per risoluzione:")
   for resolution_change, distances in resolution_analysis.items():
       mean_dist = np.mean(distances)
       count = len(distances)
       print(f"   • {resolution_change}: {mean_dist:.2f}m (n={count})")

distance_results = calculate_generalization_distance_metric(
   df=filtered_df, 
   od_matrix_generalized=od_matrix_agg
)

analyze_generalization_impact(distance_results)
# Out:
# 🔍 Calcolo metrica di distanza post-generalizzazione...
# 📊 Mappatura 3285 esagoni origine...
# 📊 Mappatura 3285 esagoni destinazione...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[16], line 206
#     203        count = len(distances)
#     204        print(f"   • {resolution_change}: {mean_dist:.2f}m (n={count})")
# --> 206 distance_results = calculate_generalization_distance_metric(
#     207    df=filtered_df,
#     208    od_matrix_generalized=od_matrix_agg
#     209 )
#     211 analyze_generalization_impact(distance_results)
#
# Cell In[16], line 35, in calculate_generalization_distance_metric(df, od_matrix_generalized)
#      32 start_distances = []
#      33 start_coords = []
# ---> 35 for idx, row in df.iterrows():
#      36     original_h3 = row['start_h3']
#      37     original_coords = (row['start_lat'], row['start_lon'])
#
# File c:\Users\dmc\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:1554, in DataFrame.iterrows(self)
#    1552 using_cow = using_copy_on_write()
#    1553 for k, v in zip(self.index, self.values):
# -> 1554     s = klass(v, index=columns, name=k).__finalize__(self)
#    1555     if using_cow and self._mgr.is_single_block:
#    1556         s._mgr.add_references(self._mgr)  # type: ignore[arg-type]
#
# File c:\Users\dmc\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\series.py:584, in Series.__init__(self, data, index, dtype, name, copy, fastpath)
#     582         data = data.copy()
#     583 else:
# --> 584     data = sanitize_array(data, index, dtype, copy)
#     586     manager = _get_option("mode.data_manager", silent=True)
#     587     if manager == "block":
#
# File c:\Users\dmc\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\construction.py:606, in sanitize_array(data, index, dtype, copy, allow_2d)
#     604 subarr = data
#     605 if data.dtype == object:
# --> 606     subarr = maybe_infer_to_datetimelike(data)
#     607     if (
#     608         object_index
#     609         and using_pyarrow_string_dtype()
#     610         and is_string_dtype(subarr)
#     611     ):
#     612         # Avoid inference when string option is set
#     613         subarr = data
#
# File c:\Users\dmc\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\dtypes\cast.py:1189, in maybe_infer_to_datetimelike(value)
#    1184     return value
#    1186 # error: Incompatible return value type (got "Union[ExtensionArray,
#    1187 # ndarray[Any, Any]]", expected "Union[ndarray[Any, Any], DatetimeArray,
#    1188 # TimedeltaArray, PeriodArray, IntervalArray]")
# -> 1189 return lib.maybe_convert_objects(  # type: ignore[return-value]
#    1190     value,
#    1191     # Here we do not convert numeric dtypes, as if we wanted that,
#    1192     #  numpy would have done it for us.
#    1193     convert_numeric=False,
#    1194     convert_non_numeric=True,
#    1195     dtype_if_all_nat=np.dtype("M8[ns]"),
#    1196 )
#
# File lib.pyx:2543, in pandas._libs.lib.maybe_convert_objects()
#
# File c:\Users\dmc\AppData\Local\Programs\Python\Python311\Lib\site-packages\numpy\_core\numeric.py:353, in full(shape, fill_value, dtype, order, device, like)
#     351     dtype = fill_value.dtype
#     352 a = empty(shape, dtype, order, device=device)
# --> 353 multiarray.copyto(a, fill_value, casting='unsafe')
#     354 return a
#
# KeyboardInterrupt:

# %%
import pandas as pd
import h3

class GeneralizationMetric:
    """
    Ḡ = (1/V+) × Σ(|o| + |d|) × v_{o→d}
    """
    def __init__(self, k_threshold: int = 10):
        self.k_threshold = k_threshold

    def calculate_generalization_error(self, od_matrix_generalized: pd.DataFrame, od_matrix: pd.DataFrame) -> float:
        # Costruisci dizionari: generalizzato -> numero di celle originali
        origin_counts = self._build_hexagon_counts(
            od_matrix_generalized, od_matrix, column_gen="start_h3", column_orig="start_h3"
        )
        destination_counts = self._build_hexagon_counts(
            od_matrix_generalized, od_matrix, column_gen="end_h3", column_orig="end_h3"
        )

        total_volume_anonymous = 0
        weighted_count_sum = 0

        for _, row in od_matrix_generalized.iterrows():
            flow_value = row["count"]
            if flow_value >= self.k_threshold:
                origin_h3 = row["start_h3"]
                dest_h3   = row["end_h3"]

                origin_count = origin_counts.get(origin_h3, 1)
                dest_count   = destination_counts.get(dest_h3, 1)

                total_volume_anonymous += flow_value
                weighted_count_sum += (origin_count + dest_count) * flow_value

        return weighted_count_sum / total_volume_anonymous if total_volume_anonymous > 0 else 0.0

    def _build_hexagon_counts(
        self, od_matrix_generalized: pd.DataFrame, od_matrix: pd.DataFrame, 
        column_gen: str, column_orig: str
    ) -> dict:
        """
        Conta quanti esagoni originali appartengono a ciascun esagono generalizzato
        """
        generalized_hexagons = od_matrix_generalized[column_gen].unique()
        original_hexagons = od_matrix[column_orig].unique()

        counts = {}
        for gen_hex in generalized_hexagons:
            target_res = h3.get_resolution(gen_hex)

            # Trova tutti i parent degli originali alla risoluzione target
            parent_series = [h3.cell_to_parent(h, target_res) for h in original_hexagons]

            # Conta quante volte compare il parent == gen_hex
            count = sum(1 for p in parent_series if p == gen_hex)
            counts[gen_hex] = max(count, 1)  # fallback a 1

        return counts


# Esempio di utilizzo:
metric = GeneralizationMetric(k_threshold=10)
error = metric.calculate_generalization_error(od_matrix_agg, od_matrix)
print(f"Errore di generalizzazione medio Ḡ: {error:.3f}")
# Out:
# Errore di generalizzazione medio Ḡ: 3073.866

# %%
import pandas as pd
import h3
from collections import defaultdict

def fast_reconstruction_loss(original_od_df: pd.DataFrame,
                                       od_matrix_generalized: pd.DataFrame) -> float:
    """
    Calcola la reconstruction loss includendo anche le celle con 0 viaggi.
    Versione ottimizzata, evita itertools.product su tutte le foglie.
    """
    # Dizionario dei flussi originali
    original_flows = {(row['start_h3'], row['end_h3']): row['count']
                      for _, row in original_od_df.iterrows()}

    total_volume = sum(original_flows.values())
    if total_volume == 0:
        return 0.0

    # Dizionario dei flussi generalizzati
    generalized_flows = {(row['start_h3'], row['end_h3']): row['count']
                         for _, row in od_matrix_generalized.iterrows()}

    gen_start_hexes = od_matrix_generalized['start_h3'].unique()
    gen_end_hexes   = od_matrix_generalized['end_h3'].unique()

    # Cache: gen_hex → leaves
    leaf_cache = {}

    def get_leaves(gen_hex, target_res):
        key = (gen_hex, target_res)
        if key in leaf_cache:
            return leaf_cache[key]
        res = h3.get_resolution(gen_hex)
        leaves = {gen_hex} if res == target_res else set(h3.cell_to_children(gen_hex, target_res))
        leaf_cache[key] = leaves
        return leaves

    # Risoluzione target
    target_res_start = h3.get_resolution(original_od_df['start_h3'].iloc[0])
    target_res_end   = h3.get_resolution(original_od_df['end_h3'].iloc[0])

    # Precompute mappe: leaf → parent generalized
    start_leaf_to_parent = {}
    for gen in gen_start_hexes:
        for leaf in get_leaves(gen, target_res_start):
            start_leaf_to_parent[leaf] = gen

    end_leaf_to_parent = {}
    for gen in gen_end_hexes:
        for leaf in get_leaves(gen, target_res_end):
            end_leaf_to_parent[leaf] = gen

    total_abs_error = 0.0

    # Itera solo sulle coppie presenti nell'originale
    for (s, d), true_count in original_flows.items():
        gen_s = start_leaf_to_parent.get(s)
        gen_d = end_leaf_to_parent.get(d)

        if gen_s is None or gen_d is None:
            reconstructed_count = 0.0
        else:
            gen_count = generalized_flows.get((gen_s, gen_d), 0.0)
            start_leaves = get_leaves(gen_s, target_res_start)
            end_leaves   = get_leaves(gen_d, target_res_end)
            reconstructed_count = gen_count / (len(start_leaves) * len(end_leaves))

        total_abs_error += abs(reconstructed_count - true_count)

    # Aggiungi errore per le coppie con count=0 nei generalized flows
    for (gen_s, gen_d), gen_count in generalized_flows.items():
        start_leaves = get_leaves(gen_s, target_res_start)
        end_leaves   = get_leaves(gen_d, target_res_end)
        count_per_leaf = gen_count / (len(start_leaves) * len(end_leaves))

        # Sottrai le coppie già contate
        for s in start_leaves:
            for d in end_leaves:
                if (s, d) not in original_flows:
                    total_abs_error += abs(count_per_leaf - 0.0)

    return total_abs_error / total_volume

loss = fast_reconstruction_loss(
    original_od_df=od_matrix,
    od_matrix_generalized=od_matrix_agg
)
print(f"Reconstruction Loss: {loss:.6f}")
# Out:
# Reconstruction Loss: 1.881413
