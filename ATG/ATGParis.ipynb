# %%
import pandas as pd
import os
from datetime import datetime, timedelta
import glob
import pandas as pd
import random
import numpy as np
import seaborn as sns
import ast
import json
import os
import re
import itertools
import folium
import hdbscan
import h3

from scipy.spatial.transform import Rotation as R
from scipy.spatial.distance import euclidean
from scipy.spatial.distance import pdist, squareform
from sklearn.cluster import DBSCAN
from sklearn.neighbors import NearestNeighbors
import matplotlib.pyplot as plt
import matplotlib.pylab as pl
import matplotlib.patches as patches
from pydp.algorithms.numerical_mechanisms import LaplaceMechanism
from itertools import combinations
from collections import defaultdict
from collections import Counter
from typing import Dict, Set, List, Optional, Tuple

# %%
df_gps = pd.read_csv("C:\\Users\\dmc\\Desktop\\extracted_trips_data.csv")

df_people = pd.read_csv("C:\\Users\\dmc\\Desktop\\individuals_dataset.csv")
df_people = df_people[df_people['GPS_RECORD'] == True]

df_merged = pd.merge(
    df_gps,
    df_people[['ID', 'WEIGHT_INDIV']],
    left_on='person_id',
    right_on='ID',
    how='inner'
).drop(columns='ID')

h3_resolution = 10

df_merged['start_h3'] = df_merged.apply(lambda row: h3.latlng_to_cell(row['start_lat'], row['start_lon'], h3_resolution), axis=1)
df_merged['end_h3'] = df_merged.apply(lambda row: h3.latlng_to_cell(row['end_lat'], row['end_lon'], h3_resolution), axis=1)

media_peso = df_merged['WEIGHT_INDIV'].mean()
print(f"📏 Media del peso individuale: {media_peso:.3f}")

od_matrix_first = df_merged.groupby(['start_h3', 'end_h3']).agg({
    'WEIGHT_INDIV': ['sum', 'count']
}).reset_index()

od_matrix_first.columns = ['start_h3', 'end_h3', 'total_weight', 'count']
# Out:
# 📏 Media del peso individuale: 2674.163

# %%
# Singolo esagono res=5 : "851fb467fffffff"
# 4 figli di res5 che coprono Parigi centro res=6 : "861fb4667ffffff", "861fb4677ffffff", "861fb466fffffff", "861fb4647ffffff"
# res=7 "871fb4674ffffff", "871fb475bffffff", "871fb4675ffffff", "871fb4666ffffff", "871fb4662ffffff", "871fb4660ffffff"
# "861fb4667ffffff", "861fb4677ffffff", "861fb466fffffff", "861fb4647ffffff", "861fb4297ffffff", "861fb474fffffff", "861fb475fffffff", "861fb462fffffff"
parent_hexes = ["861fb4667ffffff", "861fb4677ffffff", "861fb466fffffff", "861fb4647ffffff", "861fb475fffffff"]

# Genera la lista dei figli a risoluzione 10
target_resolution = 10
start_valid_h3 = set()
end_valid_h3 = set()

for parent in parent_hexes:
    children = h3.cell_to_children(parent, target_resolution)  # <-- NON serve compact
    for child in children:
        start_valid_h3.add(child)
        end_valid_h3.add(child)

mask = (
    (od_matrix_first["start_h3"].isin(start_valid_h3))
    & (od_matrix_first["end_h3"].isin(end_valid_h3))
)

od_matrix_first = od_matrix_first[mask].copy()
print(f"Numero di righe filtrate: {len(od_matrix_first):,}")
# Out:
# Numero di righe filtrate: 23,264

# %%
od_matrix = od_matrix_first.copy()
filtered_df = df_merged.merge(
    od_matrix[['start_h3', 'end_h3']],
    on=['start_h3', 'end_h3'],
    how='inner'
)

# %%
class H3TreeNode:
    """Nodo dell'albero gerarchico H3"""
    def __init__(self, h3_id: str, resolution: int, total_weight: int = 0, count: int = 0):
        self.h3_id = h3_id
        self.resolution = resolution
        self.total_weight = total_weight
        self.count = count
        self.children: Dict[str, 'H3TreeNode'] = {}
        self.parent: Optional['H3TreeNode'] = None
    
    def add_child(self, child: 'H3TreeNode'):
        """Aggiunge un figlio al nodo"""
        self.children[child.h3_id] = child
        child.parent = self
    
    def add_weight(self, weight: int):
        self.total_weight += weight
        if self.parent:
            self.parent.add_weight(weight)
    
    def add_count(self, count: int):
        self.count += count
        if self.parent:
            self.parent.add_count(count)
    
    def __repr__(self):
        return (f"H3Node(id={self.h3_id}, res={self.resolution}, "
                f"total_weight={self.total_weight}, count={self.count}, children={len(self.children)})")

class H3HierarchicalTree:
    def __init__(self, od_matrix: pd.DataFrame, target_resolution: int = 11, hex_column: str = 'start_h3'):
        self.od_matrix = od_matrix
        self.target_resolution = target_resolution
        self.hex_column = hex_column  # 'start_h3' o 'end_h3'
        self.nodes: Dict[str, H3TreeNode] = {}
        self.root = None
        self.min_resolution = None  # Sarà calcolato dinamicamente
        
    def get_all_hexagons(self) -> Set[str]:
        """Estrae tutti gli esagoni unici dalla colonna specificata"""
        return set(self.od_matrix[self.hex_column].unique())
    
    def get_resolution_coverage(self, hexagons: Set[str], target_res: int) -> Set[str]:
        """
        Ottiene tutti gli esagoni di risoluzione target che coprono l'area
        definita dagli esagoni di input
        """
        coverage_hexagons = set()
        
        for hex_id in hexagons:
            current_res = h3.get_resolution(hex_id)
            
            if current_res == target_res:
                coverage_hexagons.add(hex_id)
            elif current_res < target_res:
                # Dobbiamo espandere a risoluzione più alta
                children = self._get_all_children_at_resolution(hex_id, target_res)
                coverage_hexagons.update(children)
            else:
                # Dobbiamo salire a risoluzione più bassa
                parent = h3.cell_to_parent(hex_id, target_res)
                coverage_hexagons.add(parent)
        
        return coverage_hexagons
    
    def find_optimal_min_resolution(self, hexagons: Set[str]) -> int:
        """
        Trova la risoluzione più alta dove c'è ancora un solo nodo che copre tutti gli esagoni
        """
        print("🔍 Analizzando risoluzione ottimale per radice...")
        
        # Per ogni risoluzione da 0 alla target, conta quanti nodi servono per coprire tutti gli esagoni
        resolution_stats = {}
        
        for resolution in range(0, self.target_resolution + 1):
            ancestors = set()
            for hex_id in hexagons:
                current_res = h3.get_resolution(hex_id)
                if current_res >= resolution:
                    ancestor = h3.cell_to_parent(hex_id, resolution)
                    ancestors.add(ancestor)
                else:
                    # L'esagono è già a risoluzione più bassa, aggiungi direttamente
                    ancestors.add(hex_id)
            
            resolution_stats[resolution] = len(ancestors)
            print(f"  - Risoluzione {resolution}: {len(ancestors)} nodi")
        
        # Trova la risoluzione più alta con count = 1
        optimal_resolution = 0
        for resolution in range(self.target_resolution, -1, -1):
            if resolution_stats[resolution] == 1:
                optimal_resolution = resolution
                break
        
        print(f"✅ Risoluzione ottimale trovata: {optimal_resolution}")
        return optimal_resolution
    
    def get_siblings(self, node_id: str) -> List[str]:
        """Restituisce gli h3_id dei nodi fratelli di node_id (stesso genitore, escluso node_id stesso)"""
        if node_id not in self.nodes:
            return []

        node = self.nodes[node_id]
        parent = node.parent
        if parent is None:
            # Nodo root, non ha fratelli
            return []

        siblings = [child.h3_id for child in parent.children.values() if child.h3_id != node_id]
        return siblings
    
    def get_parent(self, node_id: str) -> Optional[str]:
        """Restituisce l'h3_id del genitore del nodo dato, o None se root o nodo non trovato"""
        if node_id not in self.nodes:
            return None
        node = self.nodes[node_id]
        if node.parent is None:
            return None
        return node.parent.h3_id
    
    def _get_all_children_at_resolution(self, hex_id: str, target_res: int) -> Set[str]:
        """Ricorsivamente ottiene tutti i figli a una risoluzione specifica"""
        current_res = h3.get_resolution(hex_id)
        
        if current_res == target_res:
            return {hex_id}
        elif current_res > target_res:
            # Non dovrebbe succedere in questo contesto
            return set()
        
        children = set()
        direct_children = h3.cell_to_children(hex_id, current_res + 1)
        
        for child in direct_children:
            children.update(self._get_all_children_at_resolution(child, target_res))
        
        return children
    
    def build_hierarchy_path(self, hex_id: str, min_resolution: int) -> List[str]:
        """Costruisce il percorso gerarchico da un esagono fino alla risoluzione minima"""
        path = [hex_id]
        current = hex_id
        current_res = h3.get_resolution(current)
        
        while current_res > min_resolution:
            parent = h3.cell_to_parent(current, current_res - 1)
            path.append(parent)
            current = parent
            current_res -= 1
        
        return path
    
    def create_tree_structure(self):
        """Crea la struttura dell'albero ottimizzato"""
        target_hexagons = self.get_all_hexagons()
        
        # Ottieni copertura completa alla risoluzione target
        coverage_hexagons = self.get_resolution_coverage(target_hexagons, self.target_resolution)
        
        # Trova la risoluzione minima ottimale (quella più alta con count=1)
        self.min_resolution = self.find_optimal_min_resolution(coverage_hexagons)
        
        print(f"🏗️ Costruendo albero da risoluzione {self.min_resolution} a {self.target_resolution}")
        
        # Costruisci tutti i percorsi gerarchici
        all_paths = []
        for hex_id in coverage_hexagons:
            path = self.build_hierarchy_path(hex_id, self.min_resolution)
            all_paths.append(path)
        
        # Crea tutti i nodi
        for path in all_paths:
            for hex_id in path:
                if hex_id not in self.nodes:
                    resolution = h3.get_resolution(hex_id)
                    self.nodes[hex_id] = H3TreeNode(hex_id, resolution)
        
        # Stabilisci relazioni parent-child
        for path in all_paths:
            for i in range(len(path) - 1):
                child_id = path[i]
                parent_id = path[i + 1]
                self.nodes[parent_id].add_child(self.nodes[child_id])
        
        # Identifica la radice
        self.root = self.nodes[self._find_root_hexagon(coverage_hexagons, self.min_resolution)]
        
        return self
    
    def _find_root_hexagon(self, hexagons: Set[str], min_resolution: int) -> str:
        """Trova l'esagono radice che contiene tutti gli altri"""
        sample_hex = next(iter(hexagons))
        return h3.cell_to_parent(sample_hex, min_resolution)
    
    def populate_counts(self):
        # Raggruppa per esagono le due metriche
        agg_df = self.od_matrix.groupby(self.hex_column).agg({'total_weight': 'sum', 'count': 'sum'}).reset_index()
        
        for _, row in agg_df.iterrows():
            hex_id = row[self.hex_column]
            weight = int(row['total_weight'])
            count = int(row['count'])
            
            target_hex = self._map_to_target_resolution(hex_id)
            
            if target_hex in self.nodes:
                self.nodes[target_hex].add_weight(weight)
                self.nodes[target_hex].add_count(count)
            else:
                print(f"⚠️ Avviso: esagono {target_hex} non trovato nell'albero")
        
        return self
    
    def _map_to_target_resolution(self, hex_id: str) -> str:
        """Mappa un esagono alla risoluzione target"""
        current_res = h3.get_resolution(hex_id)
        
        if current_res == self.target_resolution:
            return hex_id
        elif current_res < self.target_resolution:
            # Prendi il primo figlio disponibile (potrebbe essere migliorato)
            children = self._get_all_children_at_resolution(hex_id, self.target_resolution)
            return next(iter(children)) if children else hex_id
        else:
            return h3.cell_to_parent(hex_id, self.target_resolution)
    
    def get_tree_statistics(self) -> Dict:
        """Ottiene statistiche dell'albero"""
        if not self.root:
            return {}
        
        stats = {
            'total_nodes': len(self.nodes),
            'root_resolution': self.root.resolution,
            'min_resolution': self.min_resolution,
            'target_resolution': self.target_resolution,
            'total_weight': self.root.total_weight,
            'nodes_by_resolution': defaultdict(int),
            'resolution_range': f"{self.min_resolution} → {self.target_resolution}"
        }
        
        for node in self.nodes.values():
            stats['nodes_by_resolution'][node.resolution] += 1
        
        return stats
    
    def print_tree(self, max_children_per_level: int = 10):
        if not self.root:
            print("❌ Albero non costruito")
            return
        
        print(f"\n🌳 STRUTTURA ALBERO OTTIMIZZATA")
        print(f"📏 Range risoluzione: {self.min_resolution} → {self.target_resolution}")
        print("=" * 80)
        
        def _print_node(node: H3TreeNode, depth: int = 0, is_last: bool = True, prefix: str = ""):
            connector = "└─ " if is_last else "├─ "
            print(f"{prefix}{connector}{node.h3_id} (res:{node.resolution}, total_weight:{node.total_weight}, count:{node.count}, children:{len(node.children)})")
            
            if is_last:
                child_prefix = prefix + "   "
            else:
                child_prefix = prefix + "│  "
            
            children_list = list(node.children.values())
            
            if len(children_list) <= max_children_per_level:
                for i, child in enumerate(children_list):
                    is_last_child = (i == len(children_list) - 1)
                    _print_node(child, depth + 1, is_last_child, child_prefix)
            else:
                for i in range(max_children_per_level):
                    child = children_list[i]
                    is_last_child = (i == max_children_per_level - 1) and (len(children_list) == max_children_per_level)
                    _print_node(child, depth + 1, is_last_child, child_prefix)
                
                remaining = len(children_list) - max_children_per_level
                print(f"{child_prefix}└─ ... e altri {remaining} figli con stesso pattern")
        
        _print_node(self.root, 0, True, "")

def create_h3_hierarchical_tree(od_matrix_df: pd.DataFrame, target_resolution: int = 10, hex_column: str = 'start_h3'):
    """
    Crea un albero gerarchico H3 ottimizzato dal dataset OD matrix
    
    Args:
        od_matrix_df: DataFrame con colonne 'start_h3', 'end_h3', 'count'
        target_resolution: Risoluzione target per le foglie dell'albero
        hex_column: Colonna da analizzare ('start_h3' o 'end_h3')
    
    Returns:
        H3HierarchicalTree: Albero gerarchico costruito e ottimizzato
    """
    
    tree = H3HierarchicalTree(od_matrix_df, target_resolution, hex_column)
    tree.create_tree_structure()
    tree.populate_counts()
    
    stats = tree.get_tree_statistics()
    print(f"\n📈 STATISTICHE ALBERO OTTIMIZZATO ({hex_column.upper()})")
    print("=" * 50)
    print(f"• Nodi totali: {stats['total_nodes']:,}")
    print(f"• Range risoluzione: {stats['resolution_range']}")
    print(f"• Risoluzione radice: {stats['root_resolution']}")
    print(f"• Risoluzione foglie: {stats['target_resolution']}")
    print(f"• Nodi per risoluzione:")
    for res in sorted(stats['nodes_by_resolution'].keys()):
        print(f"  - Risoluzione {res}: {stats['nodes_by_resolution'][res]:,} nodi")
    
    # Calcola risparmio in nodi
    total_resolutions_possible = target_resolution + 1  # da 0 a target
    resolutions_used = len(stats['nodes_by_resolution'])
    resolutions_saved = total_resolutions_possible - resolutions_used
    
    print(f"\n💡 OTTIMIZZAZIONI:")
    print(f"• Risoluzioni risparmiate: {resolutions_saved}")
    print(f"• Efficienza albero: {resolutions_used}/{total_resolutions_possible} livelli utilizzati")
    
    tree.print_tree()
    
    return tree

# %%
tree_start = create_h3_hierarchical_tree(od_matrix, target_resolution=10, hex_column='start_h3')
tree_end = create_h3_hierarchical_tree(od_matrix, target_resolution=10, hex_column='end_h3')
# Out:
# 🔍 Analizzando risoluzione ottimale per radice...
#   - Risoluzione 0: 1 nodi
#   - Risoluzione 1: 1 nodi
#   - Risoluzione 2: 1 nodi
#   - Risoluzione 3: 1 nodi
#   - Risoluzione 4: 1 nodi
#   - Risoluzione 5: 2 nodi
#   - Risoluzione 6: 5 nodi
#   - Risoluzione 7: 35 nodi
#   - Risoluzione 8: 244 nodi
#   - Risoluzione 9: 1522 nodi
#   - Risoluzione 10: 6624 nodi
# ✅ Risoluzione ottimale trovata: 4
# 🏗️ Costruendo albero da risoluzione 4 a 10
#
# 📈 STATISTICHE ALBERO OTTIMIZZATO (START_H3)
# ==================================================
# • Nodi totali: 8,433
# • Range risoluzione: 4 → 10
# • Risoluzione radice: 4
# • Risoluzione foglie: 10
# • Nodi per risoluzione:
#   - Risoluzione 4: 1 nodi
#   - Risoluzione 5: 2 nodi
#   - Risoluzione 6: 5 nodi
#   - Risoluzione 7: 35 nodi
#   - Risoluzione 8: 244 nodi
#   - Risoluzione 9: 1,522 nodi
#   - Risoluzione 10: 6,624 nodi
#
# 💡 OTTIMIZZAZIONI:
# • Risoluzioni risparmiate: 4
# • Efficienza albero: 7/11 livelli utilizzati
#
# 🌳 STRUTTURA ALBERO OTTIMIZZATA
# 📏 Range risoluzione: 4 → 10
# ================================================================================
# └─ 841fb47ffffffff (res:4, total_weight:72646323, count:28203, children:2)
#    ├─ 851fb467fffffff (res:5, total_weight:63947362, count:24758, children:4)
#    │  ├─ 861fb4647ffffff (res:6, total_weight:16536499, count:5695, children:7)
#    │  │  ├─ 871fb4644ffffff (res:7, total_weight:5173062, count:2011, children:7)
#    │  │  │  ├─ 881fb46443fffff (res:8, total_weight:446172, count:181, children:7)
#    │  │  │  │  ├─ 891fb464423ffff (res:9, total_weight:124371, count:46, children:7)
#    │  │  │  │  │  ├─ 8a1fb4644237fff (res:10, total_weight:5706, count:3, children:0)
#    │  │  │  │  │  ├─ 8a1fb464421ffff (res:10, total_weight:42901, count:15, children:0)
#    │  │  │  │  │  ├─ 8a1fb464420ffff (res:10, total_weight:20482, count:8, children:0)
#    │  │  │  │  │  ├─ 8a1fb464422ffff (res:10, total_weight:3067, count:2, children:0)
#    │  │  │  │  │  ├─ 8a1fb4644227fff (res:10, total_weight:8108, count:3, children:0)
#    │  │  │  │  │  ├─ 8a1fb4644207fff (res:10, total_weight:33785, count:12, children:0)
#    │  │  │  │  │  └─ 8a1fb4644217fff (res:10, total_weight:10322, count:3, children:0)
#    │  │  │  │  ├─ 891fb46443bffff (res:9, total_weight:53097, count:13, children:5)
#    │  │  │  │  │  ├─ 8a1fb464438ffff (res:10, total_weight:10133, count:5, children:0)
#    │  │  │  │  │  ├─ 8a1fb46443a7fff (res:10, total_weight:543, count:1, children:0)
#    │  │  │  │  │  ├─ 8a1fb464439ffff (res:10, total_weight:10378, count:1, children:0)
#    │  │  │  │  │  ├─ 8a1fb46443b7fff (res:10, total_weight:2861, count:2, children:0)
#    │  │  │  │  │  └─ 8a1fb4644387fff (res:10, total_weight:29182, count:4, children:0)
#    │  │  │  │  ├─ 891fb46442bffff (res:9, total_weight:17793, count:9, children:3)
#    │  │  │  │  │  ├─ 8a1fb464429ffff (res:10, total_weight:3147, count:2, children:0)
#    │  │  │  │  │  ├─ 8a1fb4644297fff (res:10, total_weight:2903, count:2, children:0)
#    │  │  │  │  │  └─ 8a1fb46442affff (res:10, total_weight:11743, count:5, children:0)
#    │  │  │  │  ├─ 891fb464437ffff (res:9, total_weight:72005, count:31, children:7)
#    │  │  │  │  │  ├─ 8a1fb464434ffff (res:10, total_weight:343, count:1, children:0)
#    │  │  │  │  │  ├─ 8a1fb464436ffff (res:10, total_weight:6209, count:4, children:0)
#    │  │  │  │  │  ├─ 8a1fb464435ffff (res:10, total_weight:7737, count:3, children:0)
#    │  │  │  │  │  ├─ 8a1fb4644357fff (res:10, total_weight:8625, count:4, children:0)
#    │  │  │  │  │  ├─ 8a1fb4644347fff (res:10, total_weight:5147, count:2, children:0)
#    │  │  │  │  │  ├─ 8a1fb4644377fff (res:10, total_weight:12204, count:4, children:0)
#    │  │  │  │  │  └─ 8a1fb4644367fff (res:10, total_weight:31740, count:13, children:0)
#    │  │  │  │  ├─ 891fb46442fffff (res:9, total_weight:24907, count:14, children:6)
#    │  │  │  │  │  ├─ 8a1fb46442d7fff (res:10, total_weight:2742, count:1, children:0)
#    │  │  │  │  │  ├─ 8a1fb46442dffff (res:10, total_weight:4233, count:3, children:0)
#    │  │  │  │  │  ├─ 8a1fb46442cffff (res:10, total_weight:2618, count:2, children:0)
#    │  │  │  │  │  ├─ 8a1fb46442e7fff (res:10, total_weight:3904, count:2, children:0)
#    │  │  │  │  │  ├─ 8a1fb46442c7fff (res:10, total_weight:3837, count:3, children:0)
#    │  │  │  │  │  └─ 8a1fb46442f7fff (res:10, total_weight:7573, count:3, children:0)
#    │  │  │  │  ├─ 891fb464433ffff (res:9, total_weight:88156, count:29, children:6)
#    │  │  │  │  │  ├─ 8a1fb464432ffff (res:10, total_weight:8504, count:2, children:0)
#    │  │  │  │  │  ├─ 8a1fb4644337fff (res:10, total_weight:39726, count:14, children:0)
#    │  │  │  │  │  ├─ 8a1fb4644307fff (res:10, total_weight:15783, count:4, children:0)
#    │  │  │  │  │  ├─ 8a1fb464430ffff (res:10, total_weight:6008, count:2, children:0)
#    │  │  │  │  │  ├─ 8a1fb4644317fff (res:10, total_weight:10154, count:2, children:0)
#    │  │  │  │  │  └─ 8a1fb4644327fff (res:10, total_weight:7981, count:5, children:0)
#    │  │  │  │  └─ 891fb464427ffff (res:9, total_weight:65843, count:39, children:7)
#    │  │  │  │     ├─ 8a1fb464424ffff (res:10, total_weight:21229, count:12, children:0)
#    │  │  │  │     ├─ 8a1fb4644267fff (res:10, total_weight:5535, count:3, children:0)
#    │  │  │  │     ├─ 8a1fb4644257fff (res:10, total_weight:2767, count:2, children:0)
#    │  │  │  │     ├─ 8a1fb4644277fff (res:10, total_weight:4465, count:2, children:0)
#    │  │  │  │     ├─ 8a1fb4644247fff (res:10, total_weight:10682, count:6, children:0)
#    │  │  │  │     ├─ 8a1fb464425ffff (res:10, total_weight:4968, count:5, children:0)
#    │  │  │  │     └─ 8a1fb464426ffff (res:10, total_weight:16197, count:9, children:0)
#    │  │  │  ├─ 881fb4644bfffff (res:8, total_weight:636088, count:267, children:7)
#    │  │  │  │  ├─ 891fb4644b7ffff (res:9, total_weight:58103, count:31, children:5)
#    │  │  │  │  │  ├─ 8a1fb4644b4ffff (res:10, total_weight:27101, count:16, children:0)
#    │  │  │  │  │  ├─ 8a1fb4644b5ffff (res:10, total_weight:1083, count:1, children:0)
#    │  │  │  │  │  ├─ 8a1fb4644b47fff (res:10, total_weight:16070, count:7, children:0)
#    │  │  │  │  │  ├─ 8a1fb4644b67fff (res:10, total_weight:4455, count:3, children:0)
#    │  │  │  │  │  └─ 8a1fb4644b57fff (res:10, total_weight:9394, count:4, children:0)
#    │  │  │  │  ├─ 891fb4644bbffff (res:9, total_weight:99484, count:45, children:6)
#    │  │  │  │  │  ├─ 8a1fb4644b9ffff (res:10, total_weight:22834, count:8, children:0)
#    │  │  │  │  │  ├─ 8a1fb4644b97fff (res:10, total_weight:12139, count:7, children:0)
#    │  │  │  │  │  ├─ 8a1fb4644b87fff (res:10, total_weight:17094, count:11, children:0)
#    │  │  │  │  │  ├─ 8a1fb4644ba7fff (res:10, total_weight:2937, count:2, children:0)
#    │  │  │  │  │  ├─ 8a1fb4644baffff (res:10, total_weight:15565, count:8, children:0)
#    │  │  │  │  │  └─ 8a1fb4644b8ffff (res:10, total_weight:28915, count:9, children:0)
#    │  │  │  │  ├─ 891fb4644b3ffff (res:9, total_weight:127532, count:56, children:7)
#    │  │  │  │  │  ├─ 8a1fb4644b17fff (res:10, total_weight:3834, count:2, children:0)
#    │  │  │  │  │  ├─ 8a1fb4644b0ffff (res:10, total_weight:30393, count:16, children:0)
#    │  │  │  │  │  ├─ 8a1fb4644b1ffff (res:10, total_weight:11705, count:3, children:0)
#    │  │  │  │  │  ├─ 8a1fb4644b37fff (res:10, total_weight:12996, count:6, children:0)
#    │  │  │  │  │  ├─ 8a1fb4644b07fff (res:10, total_weight:44067, count:19, children:0)
#    │  │  │  │  │  ├─ 8a1fb4644b2ffff (res:10, total_weight:13185, count:5, children:0)
#    │  │  │  │  │  └─ 8a1fb4644b27fff (res:10, total_weight:11352, count:5, children:0)
#    │  │  │  │  ├─ 891fb4644a3ffff (res:9, total_weight:203215, count:68, children:5)
#    │  │  │  │  │  ├─ 8a1fb4644a2ffff (res:10, total_weight:20877, count:2, children:0)
#    │  │  │  │  │  ├─ 8a1fb4644a1ffff (res:10, total_weight:818, count:1, children:0)
#    │  │  │  │  │  ├─ 8a1fb4644a37fff (res:10, total_weight:13975, count:6, children:0)
#    │  │  │  │  │  ├─ 8a1fb4644a17fff (res:10, total_weight:50485, count:22, children:0)
#    │  │  │  │  │  └─ 8a1fb4644a0ffff (res:10, total_weight:117060, count:37, children:0)
#    │  │  │  │  ├─ 891fb4644a7ffff (res:9, total_weight:25276, count:9, children:4)
#    │  │  │  │  │  ├─ 8a1fb4644a4ffff (res:10, total_weight:3051, count:1, children:0)
#    │  │  │  │  │  ├─ 8a1fb4644a57fff (res:10, total_weight:7525, count:3, children:0)
#    │  │  │  │  │  ├─ 8a1fb4644a47fff (res:10, total_weight:1619, count:1, children:0)
#    │  │  │  │  │  └─ 8a1fb4644a67fff (res:10, total_weight:13081, count:4, children:0)
#    │  │  │  │  ├─ 891fb4644abffff (res:9, total_weight:67392, count:34, children:7)
#    │  │  │  │  │  ├─ 8a1fb4644aa7fff (res:10, total_weight:35446, count:15, children:0)
#    │  │  │  │  │  ├─ 8a1fb4644a9ffff (res:10, total_weight:10067, count:5, children:0)
#    │  │  │  │  │  ├─ 8a1fb4644aaffff (res:10, total_weight:3882, count:2, children:0)
#    │  │  │  │  │  ├─ 8a1fb4644a87fff (res:10, total_weight:5374, count:3, children:0)
#    │  │  │  │  │  ├─ 8a1fb4644a8ffff (res:10, total_weight:2591, count:2, children:0)
#    │  │  │  │  │  ├─ 8a1fb4644a97fff (res:10, total_weight:2774, count:3, children:0)
#    │  │  │  │  │  └─ 8a1fb4644ab7fff (res:10, total_weight:7258, count:4, children:0)
#    │  │  │  │  └─ 891fb4644afffff (res:9, total_weight:55086, count:24, children:6)
#    │  │  │  │     ├─ 8a1fb4644adffff (res:10, total_weight:2618, count:1, children:0)
#    │  │  │  │     ├─ 8a1fb4644ae7fff (res:10, total_weight:36936, count:11, children:0)
#    │  │  │  │     ├─ 8a1fb4644ad7fff (res:10, total_weight:3033, count:2, children:0)
#    │  │  │  │     ├─ 8a1fb4644aeffff (res:10, total_weight:3842, count:3, children:0)
#    │  │  │  │     ├─ 8a1fb4644af7fff (res:10, total_weight:414, count:1, children:0)
#    │  │  │  │     └─ 8a1fb4644acffff (res:10, total_weight:8243, count:6, children:0)
#    │  │  │  ├─ 881fb4644dfffff (res:8, total_weight:1273728, count:452, children:7)
#    │  │  │  │  ├─ 891fb4644d7ffff (res:9, total_weight:304997, count:108, children:7)
#    │  │  │  │  │  ├─ 8a1fb4644d4ffff (res:10, total_weight:39978, count:14, children:0)
#    │  │  │  │  │  ├─ 8a1fb4644d47fff (res:10, total_weight:15298, count:8, children:0)
#    │  │  │  │  │  ├─ 8a1fb4644d57fff (res:10, total_weight:65310, count:19, children:0)
#    │  │  │  │  │  ├─ 8a1fb4644d5ffff (res:10, total_weight:105434, count:35, children:0)
#    │  │  │  │  │  ├─ 8a1fb4644d6ffff (res:10, total_weight:5400, count:3, children:0)
#    │  │  │  │  │  ├─ 8a1fb4644d67fff (res:10, total_weight:1447, count:1, children:0)
#    │  │  │  │  │  └─ 8a1fb4644d77fff (res:10, total_weight:72130, count:28, children:0)
#    │  │  │  │  ├─ 891fb4644c3ffff (res:9, total_weight:74713, count:32, children:7)
#    │  │  │  │  │  ├─ 8a1fb4644c27fff (res:10, total_weight:3236, count:1, children:0)
#    │  │  │  │  │  ├─ 8a1fb4644c2ffff (res:10, total_weight:12944, count:7, children:0)
#    │  │  │  │  │  ├─ 8a1fb4644c17fff (res:10, total_weight:21778, count:3, children:0)
#    │  │  │  │  │  ├─ 8a1fb4644c0ffff (res:10, total_weight:4839, count:2, children:0)
#    │  │  │  │  │  ├─ 8a1fb4644c37fff (res:10, total_weight:7043, count:4, children:0)
#    │  │  │  │  │  ├─ 8a1fb4644c07fff (res:10, total_weight:5234, count:4, children:0)
#    │  │  │  │  │  └─ 8a1fb4644c1ffff (res:10, total_weight:19639, count:11, children:0)
#    │  │  │  │  ├─ 891fb4644cbffff (res:9, total_weight:293548, count:82, children:7)
#    │  │  │  │  │  ├─ 8a1fb4644caffff (res:10, total_weight:101867, count:29, children:0)
#    │  │  │  │  │  ├─ 8a1fb4644c8ffff (res:10, total_weight:87015, count:20, children:0)
#    │  │  │  │  │  ├─ 8a1fb4644ca7fff (res:10, total_weight:36750, count:8, children:0)
#    │  │  │  │  │  ├─ 8a1fb4644cb7fff (res:10, total_weight:6392, count:6, children:0)
#    │  │  │  │  │  ├─ 8a1fb4644c97fff (res:10, total_weight:6960, count:3, children:0)
#    │  │  │  │  │  ├─ 8a1fb4644c9ffff (res:10, total_weight:615, count:1, children:0)
#    │  │  │  │  │  └─ 8a1fb4644c87fff (res:10, total_weight:53949, count:15, children:0)
#    │  │  │  │  ├─ 891fb4644d3ffff (res:9, total_weight:232818, count:81, children:6)
#    │  │  │  │  │  ├─ 8a1fb4644d1ffff (res:10, total_weight:43029, count:21, children:0)
#    │  │  │  │  │  ├─ 8a1fb4644d0ffff (res:10, total_weight:117523, count:38, children:0)
#    │  │  │  │  │  ├─ 8a1fb4644d27fff (res:10, total_weight:6871, count:1, children:0)
#    │  │  │  │  │  ├─ 8a1fb4644d2ffff (res:10, total_weight:14791, count:6, children:0)
#    │  │  │  │  │  ├─ 8a1fb4644d37fff (res:10, total_weight:15204, count:4, children:0)
#    │  │  │  │  │  └─ 8a1fb4644d17fff (res:10, total_weight:35400, count:11, children:0)
#    │  │  │  │  ├─ 891fb4644dbffff (res:9, total_weight:27969, count:19, children:5)
#    │  │  │  │  │  ├─ 8a1fb4644d97fff (res:10, total_weight:5910, count:3, children:0)
#    │  │  │  │  │  ├─ 8a1fb4644daffff (res:10, total_weight:10061, count:9, children:0)
#    │  │  │  │  │  ├─ 8a1fb4644d8ffff (res:10, total_weight:2850, count:3, children:0)
#    │  │  │  │  │  ├─ 8a1fb4644d9ffff (res:10, total_weight:4189, count:2, children:0)
#    │  │  │  │  │  └─ 8a1fb4644d87fff (res:10, total_weight:4959, count:2, children:0)
#    │  │  │  │  ├─ 891fb4644cfffff (res:9, total_weight:75194, count:26, children:5)
#    │  │  │  │  │  ├─ 8a1fb4644ceffff (res:10, total_weight:6947, count:4, children:0)
#    │  │  │  │  │  ├─ 8a1fb4644cd7fff (res:10, total_weight:2561, count:3, children:0)
#    │  │  │  │  │  ├─ 8a1fb4644cc7fff (res:10, total_weight:907, count:1, children:0)
#    │  │  │  │  │  ├─ 8a1fb4644cf7fff (res:10, total_weight:50583, count:16, children:0)
#    │  │  │  │  │  └─ 8a1fb4644ce7fff (res:10, total_weight:14196, count:2, children:0)
#    │  │  │  │  └─ 891fb4644c7ffff (res:9, total_weight:264489, count:104, children:7)
#    │  │  │  │     ├─ 8a1fb4644c57fff (res:10, total_weight:2066, count:2, children:0)
#    │  │  │  │     ├─ 8a1fb4644c67fff (res:10, total_weight:60976, count:29, children:0)
#    │  │  │  │     ├─ 8a1fb4644c6ffff (res:10, total_weight:89479, count:40, children:0)
#    │  │  │  │     ├─ 8a1fb4644c47fff (res:10, total_weight:10709, count:2, children:0)
#    │  │  │  │     ├─ 8a1fb4644c4ffff (res:10, total_weight:43318, count:15, children:0)
#    │  │  │  │     ├─ 8a1fb4644c5ffff (res:10, total_weight:35738, count:7, children:0)
#    │  │  │  │     └─ 8a1fb4644c77fff (res:10, total_weight:22203, count:9, children:0)
#    │  │  │  ├─ 881fb46441fffff (res:8, total_weight:1133788, count:444, children:7)
#    │  │  │  │  ├─ 891fb464417ffff (res:9, total_weight:113912, count:39, children:7)
#    │  │  │  │  │  ├─ 8a1fb4644157fff (res:10, total_weight:6684, count:5, children:0)
#    │  │  │  │  │  ├─ 8a1fb464416ffff (res:10, total_weight:34779, count:9, children:0)
#    │  │  │  │  │  ├─ 8a1fb464414ffff (res:10, total_weight:16806, count:6, children:0)
#    │  │  │  │  │  ├─ 8a1fb4644147fff (res:10, total_weight:22962, count:4, children:0)
#    │  │  │  │  │  ├─ 8a1fb4644177fff (res:10, total_weight:9972, count:8, children:0)
#    │  │  │  │  │  ├─ 8a1fb464415ffff (res:10, total_weight:13018, count:4, children:0)
#    │  │  │  │  │  └─ 8a1fb4644167fff (res:10, total_weight:9691, count:3, children:0)
#    │  │  │  │  ├─ 891fb464413ffff (res:9, total_weight:398777, count:183, children:7)
#    │  │  │  │  │  ├─ 8a1fb4644117fff (res:10, total_weight:73493, count:28, children:0)
#    │  │  │  │  │  ├─ 8a1fb464410ffff (res:10, total_weight:36213, count:17, children:0)
#    │  │  │  │  │  ├─ 8a1fb4644127fff (res:10, total_weight:41153, count:22, children:0)
#    │  │  │  │  │  ├─ 8a1fb4644107fff (res:10, total_weight:66909, count:30, children:0)
#    │  │  │  │  │  ├─ 8a1fb464412ffff (res:10, total_weight:8629, count:7, children:0)
#    │  │  │  │  │  ├─ 8a1fb464411ffff (res:10, total_weight:78711, count:35, children:0)
#    │  │  │  │  │  └─ 8a1fb4644137fff (res:10, total_weight:93669, count:44, children:0)
#    │  │  │  │  ├─ 891fb46440fffff (res:9, total_weight:242069, count:89, children:7)
#    │  │  │  │  │  ├─ 8a1fb46440c7fff (res:10, total_weight:16143, count:4, children:0)
#    │  │  │  │  │  ├─ 8a1fb46440e7fff (res:10, total_weight:19482, count:11, children:0)
#    │  │  │  │  │  ├─ 8a1fb46440cffff (res:10, total_weight:6498, count:3, children:0)
#    │  │  │  │  │  ├─ 8a1fb46440dffff (res:10, total_weight:1731, count:2, children:0)
#    │  │  │  │  │  ├─ 8a1fb46440f7fff (res:10, total_weight:179093, count:63, children:0)
#    │  │  │  │  │  ├─ 8a1fb46440effff (res:10, total_weight:4978, count:3, children:0)
#    │  │  │  │  │  └─ 8a1fb46440d7fff (res:10, total_weight:14144, count:3, children:0)
#    │  │  │  │  ├─ 891fb46441bffff (res:9, total_weight:134038, count:45, children:7)
#    │  │  │  │  │  ├─ 8a1fb46441affff (res:10, total_weight:54882, count:22, children:0)
#    │  │  │  │  │  ├─ 8a1fb4644197fff (res:10, total_weight:2458, count:1, children:0)
#    │  │  │  │  │  ├─ 8a1fb464418ffff (res:10, total_weight:31119, count:7, children:0)
#    │  │  │  │  │  ├─ 8a1fb46441b7fff (res:10, total_weight:2742, count:1, children:0)
#    │  │  │  │  │  ├─ 8a1fb4644187fff (res:10, total_weight:5374, count:4, children:0)
#    │  │  │  │  │  ├─ 8a1fb464419ffff (res:10, total_weight:2742, count:1, children:0)
#    │  │  │  │  │  └─ 8a1fb46441a7fff (res:10, total_weight:34721, count:9, children:0)
#    │  │  │  │  ├─ 891fb46440bffff (res:9, total_weight:166909, count:49, children:7)
#    │  │  │  │  │  ├─ 8a1fb4644097fff (res:10, total_weight:4072, count:4, children:0)
#    │  │  │  │  │  ├─ 8a1fb46440affff (res:10, total_weight:29045, count:12, children:0)
#    │  │  │  │  │  ├─ 8a1fb4644087fff (res:10, total_weight:42945, count:10, children:0)
#    │  │  │  │  │  ├─ 8a1fb464409ffff (res:10, total_weight:21722, count:7, children:0)
#    │  │  │  │  │  ├─ 8a1fb46440a7fff (res:10, total_weight:6316, count:3, children:0)
#    │  │  │  │  │  ├─ 8a1fb46440b7fff (res:10, total_weight:9202, count:1, children:0)
#    │  │  │  │  │  └─ 8a1fb464408ffff (res:10, total_weight:53607, count:12, children:0)
#    │  │  │  │  ├─ 891fb464407ffff (res:9, total_weight:8456, count:6, children:4)
#    │  │  │  │  │  ├─ 8a1fb4644057fff (res:10, total_weight:1031, count:1, children:0)
#    │  │  │  │  │  ├─ 8a1fb464404ffff (res:10, total_weight:2529, count:1, children:0)
#    │  │  │  │  │  ├─ 8a1fb464406ffff (res:10, total_weight:3944, count:3, children:0)
#    │  │  │  │  │  └─ 8a1fb4644067fff (res:10, total_weight:952, count:1, children:0)
#    │  │  │  │  └─ 891fb464403ffff (res:9, total_weight:69627, count:33, children:7)
#    │  │  │  │     ├─ 8a1fb4644037fff (res:10, total_weight:9099, count:7, children:0)
#    │  │  │  │     ├─ 8a1fb464400ffff (res:10, total_weight:5375, count:4, children:0)
#    │  │  │  │     ├─ 8a1fb4644007fff (res:10, total_weight:13211, count:2, children:0)
#    │  │  │  │     ├─ 8a1fb4644017fff (res:10, total_weight:12276, count:7, children:0)
#    │  │  │  │     ├─ 8a1fb4644027fff (res:10, total_weight:4040, count:4, children:0)
#    │  │  │  │     ├─ 8a1fb464401ffff (res:10, total_weight:24222, count:8, children:0)
#    │  │  │  │     └─ 8a1fb464402ffff (res:10, total_weight:1404, count:1, children:0)
#    │  │  │  ├─ 881fb46449fffff (res:8, total_weight:758574, count:350, children:7)
#    │  │  │  │  ├─ 891fb464493ffff (res:9, total_weight:131215, count:52, children:7)
#    │  │  │  │  │  ├─ 8a1fb464492ffff (res:10, total_weight:1879, count:1, children:0)
#    │  │  │  │  │  ├─ 8a1fb4644917fff (res:10, total_weight:58681, count:14, children:0)
#    │  │  │  │  │  ├─ 8a1fb4644907fff (res:10, total_weight:10562, count:5, children:0)
#    │  │  │  │  │  ├─ 8a1fb464491ffff (res:10, total_weight:7628, count:4, children:0)
#    │  │  │  │  │  ├─ 8a1fb464490ffff (res:10, total_weight:4011, count:2, children:0)
#    │  │  │  │  │  ├─ 8a1fb4644927fff (res:10, total_weight:23589, count:15, children:0)
#    │  │  │  │  │  └─ 8a1fb4644937fff (res:10, total_weight:24865, count:11, children:0)
#    │  │  │  │  ├─ 891fb464487ffff (res:9, total_weight:90828, count:54, children:7)
#    │  │  │  │  │  ├─ 8a1fb4644867fff (res:10, total_weight:14760, count:8, children:0)
#    │  │  │  │  │  ├─ 8a1fb4644877fff (res:10, total_weight:22951, count:16, children:0)
#    │  │  │  │  │  ├─ 8a1fb4644857fff (res:10, total_weight:22495, count:12, children:0)
#    │  │  │  │  │  ├─ 8a1fb4644847fff (res:10, total_weight:4866, count:3, children:0)
#    │  │  │  │  │  ├─ 8a1fb464484ffff (res:10, total_weight:7298, count:5, children:0)
#    │  │  │  │  │  ├─ 8a1fb464486ffff (res:10, total_weight:15406, count:7, children:0)
#    │  │  │  │  │  └─ 8a1fb464485ffff (res:10, total_weight:3052, count:3, children:0)
#    │  │  │  │  ├─ 891fb46449bffff (res:9, total_weight:86393, count:33, children:7)
#    │  │  │  │  │  ├─ 8a1fb464498ffff (res:10, total_weight:6217, count:2, children:0)
#    │  │  │  │  │  ├─ 8a1fb46449b7fff (res:10, total_weight:8786, count:5, children:0)
#    │  │  │  │  │  ├─ 8a1fb46449affff (res:10, total_weight:15237, count:5, children:0)
#    │  │  │  │  │  ├─ 8a1fb4644997fff (res:10, total_weight:15786, count:5, children:0)
#    │  │  │  │  │  ├─ 8a1fb464499ffff (res:10, total_weight:7626, count:4, children:0)
#    │  │  │  │  │  ├─ 8a1fb4644987fff (res:10, total_weight:12142, count:4, children:0)
#    │  │  │  │  │  └─ 8a1fb46449a7fff (res:10, total_weight:20599, count:8, children:0)
#    │  │  │  │  ├─ 891fb46448bffff (res:9, total_weight:143927, count:64, children:7)
#    │  │  │  │  │  ├─ 8a1fb46448b7fff (res:10, total_weight:14229, count:9, children:0)
#    │  │  │  │  │  ├─ 8a1fb464488ffff (res:10, total_weight:13956, count:3, children:0)
#    │  │  │  │  │  ├─ 8a1fb4644887fff (res:10, total_weight:15401, count:9, children:0)
#    │  │  │  │  │  ├─ 8a1fb464489ffff (res:10, total_weight:61197, count:26, children:0)
#    │  │  │  │  │  ├─ 8a1fb46448affff (res:10, total_weight:13802, count:3, children:0)
#    │  │  │  │  │  ├─ 8a1fb4644897fff (res:10, total_weight:13266, count:6, children:0)
#    │  │  │  │  │  └─ 8a1fb46448a7fff (res:10, total_weight:12076, count:8, children:0)
#    │  │  │  │  ├─ 891fb464483ffff (res:9, total_weight:84527, count:51, children:7)
#    │  │  │  │  │  ├─ 8a1fb4644837fff (res:10, total_weight:23277, count:8, children:0)
#    │  │  │  │  │  ├─ 8a1fb4644827fff (res:10, total_weight:3147, count:1, children:0)
#    │  │  │  │  │  ├─ 8a1fb464480ffff (res:10, total_weight:27756, count:16, children:0)
#    │  │  │  │  │  ├─ 8a1fb4644807fff (res:10, total_weight:11874, count:13, children:0)
#    │  │  │  │  │  ├─ 8a1fb464481ffff (res:10, total_weight:3509, count:3, children:0)
#    │  │  │  │  │  ├─ 8a1fb464482ffff (res:10, total_weight:7703, count:7, children:0)
#    │  │  │  │  │  └─ 8a1fb4644817fff (res:10, total_weight:7261, count:3, children:0)
#    │  │  │  │  ├─ 891fb464497ffff (res:9, total_weight:119037, count:55, children:7)
#    │  │  │  │  │  ├─ 8a1fb4644977fff (res:10, total_weight:10774, count:7, children:0)
#    │  │  │  │  │  ├─ 8a1fb4644967fff (res:10, total_weight:1026, count:1, children:0)
#    │  │  │  │  │  ├─ 8a1fb464495ffff (res:10, total_weight:49648, count:24, children:0)
#    │  │  │  │  │  ├─ 8a1fb464496ffff (res:10, total_weight:16496, count:7, children:0)
#    │  │  │  │  │  ├─ 8a1fb4644957fff (res:10, total_weight:26236, count:11, children:0)
#    │  │  │  │  │  ├─ 8a1fb4644947fff (res:10, total_weight:11821, count:4, children:0)
#    │  │  │  │  │  └─ 8a1fb464494ffff (res:10, total_weight:3036, count:1, children:0)
#    │  │  │  │  └─ 891fb46448fffff (res:9, total_weight:102647, count:41, children:7)
#    │  │  │  │     ├─ 8a1fb46448cffff (res:10, total_weight:12221, count:4, children:0)
#    │  │  │  │     ├─ 8a1fb46448e7fff (res:10, total_weight:19426, count:9, children:0)
#    │  │  │  │     ├─ 8a1fb46448dffff (res:10, total_weight:18291, count:7, children:0)
#    │  │  │  │     ├─ 8a1fb46448effff (res:10, total_weight:10232, count:4, children:0)
#    │  │  │  │     ├─ 8a1fb46448d7fff (res:10, total_weight:22317, count:10, children:0)
#    │  │  │  │     ├─ 8a1fb46448c7fff (res:10, total_weight:3230, count:1, children:0)
#    │  │  │  │     └─ 8a1fb46448f7fff (res:10, total_weight:16930, count:6, children:0)
#    │  │  │  ├─ 881fb46447fffff (res:8, total_weight:334134, count:142, children:7)
#    │  │  │  │  ├─ 891fb464463ffff (res:9, total_weight:16693, count:5, children:5)
#    │  │  │  │  │  ├─ 8a1fb4644627fff (res:10, total_weight:2547, count:1, children:0)
#    │  │  │  │  │  ├─ 8a1fb464461ffff (res:10, total_weight:3061, count:1, children:0)
#    │  │  │  │  │  ├─ 8a1fb4644617fff (res:10, total_weight:5623, count:1, children:0)
#    │  │  │  │  │  ├─ 8a1fb4644607fff (res:10, total_weight:414, count:1, children:0)
#    │  │  │  │  │  └─ 8a1fb4644637fff (res:10, total_weight:5048, count:1, children:0)
#    │  │  │  │  ├─ 891fb464473ffff (res:9, total_weight:25360, count:7, children:3)
#    │  │  │  │  │  ├─ 8a1fb4644717fff (res:10, total_weight:2492, count:2, children:0)
#    │  │  │  │  │  ├─ 8a1fb464470ffff (res:10, total_weight:909, count:1, children:0)
#    │  │  │  │  │  └─ 8a1fb4644727fff (res:10, total_weight:21959, count:4, children:0)
#    │  │  │  │  ├─ 891fb46446bffff (res:9, total_weight:74824, count:26, children:7)
#    │  │  │  │  │  ├─ 8a1fb46446affff (res:10, total_weight:2697, count:2, children:0)
#    │  │  │  │  │  ├─ 8a1fb4644687fff (res:10, total_weight:15403, count:6, children:0)
#    │  │  │  │  │  ├─ 8a1fb464469ffff (res:10, total_weight:20778, count:4, children:0)
#    │  │  │  │  │  ├─ 8a1fb46446a7fff (res:10, total_weight:17204, count:4, children:0)
#    │  │  │  │  │  ├─ 8a1fb4644697fff (res:10, total_weight:9813, count:6, children:0)
#    │  │  │  │  │  ├─ 8a1fb464468ffff (res:10, total_weight:1549, count:1, children:0)
#    │  │  │  │  │  └─ 8a1fb46446b7fff (res:10, total_weight:7380, count:3, children:0)
#    │  │  │  │  ├─ 891fb464467ffff (res:9, total_weight:138624, count:74, children:6)
#    │  │  │  │  │  ├─ 8a1fb4644667fff (res:10, total_weight:6667, count:6, children:0)
#    │  │  │  │  │  ├─ 8a1fb4644647fff (res:10, total_weight:8075, count:7, children:0)
#    │  │  │  │  │  ├─ 8a1fb464466ffff (res:10, total_weight:7319, count:8, children:0)
#    │  │  │  │  │  ├─ 8a1fb464465ffff (res:10, total_weight:94752, count:41, children:0)
#    │  │  │  │  │  ├─ 8a1fb464464ffff (res:10, total_weight:17513, count:10, children:0)
#    │  │  │  │  │  └─ 8a1fb4644657fff (res:10, total_weight:4298, count:2, children:0)
#    │  │  │  │  ├─ 891fb46447bffff (res:9, total_weight:51042, count:19, children:6)
#    │  │  │  │  │  ├─ 8a1fb464479ffff (res:10, total_weight:14363, count:3, children:0)
#    │  │  │  │  │  ├─ 8a1fb46447b7fff (res:10, total_weight:19758, count:6, children:0)
#    │  │  │  │  │  ├─ 8a1fb4644797fff (res:10, total_weight:9891, count:5, children:0)
#    │  │  │  │  │  ├─ 8a1fb46447affff (res:10, total_weight:4430, count:2, children:0)
#    │  │  │  │  │  ├─ 8a1fb46447a7fff (res:10, total_weight:1985, count:2, children:0)
#    │  │  │  │  │  └─ 8a1fb464478ffff (res:10, total_weight:615, count:1, children:0)
#    │  │  │  │  ├─ 891fb46446fffff (res:9, total_weight:13233, count:5, children:4)
#    │  │  │  │  │  ├─ 8a1fb46446cffff (res:10, total_weight:3484, count:1, children:0)
#    │  │  │  │  │  ├─ 8a1fb46446effff (res:10, total_weight:3158, count:2, children:0)
#    │  │  │  │  │  ├─ 8a1fb46446d7fff (res:10, total_weight:4393, count:1, children:0)
#    │  │  │  │  │  └─ 8a1fb46446e7fff (res:10, total_weight:2198, count:1, children:0)
#    │  │  │  │  └─ 891fb464477ffff (res:9, total_weight:14358, count:6, children:5)
#    │  │  │  │     ├─ 8a1fb4644767fff (res:10, total_weight:758, count:1, children:0)
#    │  │  │  │     ├─ 8a1fb4644757fff (res:10, total_weight:3536, count:1, children:0)
#    │  │  │  │     ├─ 8a1fb464475ffff (res:10, total_weight:2558, count:1, children:0)
#    │  │  │  │     ├─ 8a1fb4644747fff (res:10, total_weight:2411, count:1, children:0)
#    │  │  │  │     └─ 8a1fb4644777fff (res:10, total_weight:5095, count:2, children:0)
#    │  │  │  └─ 881fb46445fffff (res:8, total_weight:590578, count:175, children:7)
#    │  │  │     ├─ 891fb464457ffff (res:9, total_weight:46349, count:14, children:5)
#    │  │  │     │  ├─ 8a1fb4644557fff (res:10, total_weight:4825, count:1, children:0)
#    │  │  │     │  ├─ 8a1fb464456ffff (res:10, total_weight:6652, count:1, children:0)
#    │  │  │     │  ├─ 8a1fb464455ffff (res:10, total_weight:31543, count:10, children:0)
#    │  │  │     │  ├─ 8a1fb4644567fff (res:10, total_weight:587, count:1, children:0)
#    │  │  │     │  └─ 8a1fb4644547fff (res:10, total_weight:2742, count:1, children:0)
#    │  │  │     ├─ 891fb46445bffff (res:9, total_weight:15071, count:7, children:4)
#    │  │  │     │  ├─ 8a1fb464458ffff (res:10, total_weight:6901, count:2, children:0)
#    │  │  │     │  ├─ 8a1fb4644587fff (res:10, total_weight:6287, count:3, children:0)
#    │  │  │     │  ├─ 8a1fb4644597fff (res:10, total_weight:1296, count:1, children:0)
#    │  │  │     │  └─ 8a1fb46445a7fff (res:10, total_weight:587, count:1, children:0)
#    │  │  │     ├─ 891fb464443ffff (res:9, total_weight:120876, count:31, children:6)
#    │  │  │     │  ├─ 8a1fb4644437fff (res:10, total_weight:8421, count:2, children:0)
#    │  │  │     │  ├─ 8a1fb464442ffff (res:10, total_weight:24017, count:4, children:0)
#    │  │  │     │  ├─ 8a1fb4644417fff (res:10, total_weight:53591, count:15, children:0)
#    │  │  │     │  ├─ 8a1fb464440ffff (res:10, total_weight:30161, count:7, children:0)
#    │  │  │     │  ├─ 8a1fb4644407fff (res:10, total_weight:3402, count:2, children:0)
#    │  │  │     │  └─ 8a1fb464441ffff (res:10, total_weight:1284, count:1, children:0)
#    │  │  │     ├─ 891fb46444fffff (res:9, total_weight:167369, count:54, children:6)
#    │  │  │     │  ├─ 8a1fb46444effff (res:10, total_weight:12934, count:6, children:0)
#    │  │  │     │  ├─ 8a1fb46444e7fff (res:10, total_weight:10946, count:3, children:0)
#    │  │  │     │  ├─ 8a1fb46444d7fff (res:10, total_weight:2892, count:2, children:0)
#    │  │  │     │  ├─ 8a1fb46444dffff (res:10, total_weight:61101, count:19, children:0)
#    │  │  │     │  ├─ 8a1fb46444cffff (res:10, total_weight:34567, count:11, children:0)
#    │  │  │     │  └─ 8a1fb46444c7fff (res:10, total_weight:44929, count:13, children:0)
#    │  │  │     ├─ 891fb46444bffff (res:9, total_weight:160069, count:38, children:7)
#    │  │  │     │  ├─ 8a1fb464449ffff (res:10, total_weight:7699, count:4, children:0)
#    │  │  │     │  ├─ 8a1fb4644497fff (res:10, total_weight:10883, count:5, children:0)
#    │  │  │     │  ├─ 8a1fb46444affff (res:10, total_weight:10034, count:6, children:0)
#    │  │  │     │  ├─ 8a1fb46444a7fff (res:10, total_weight:118505, count:15, children:0)
#    │  │  │     │  ├─ 8a1fb464448ffff (res:10, total_weight:3590, count:3, children:0)
#    │  │  │     │  ├─ 8a1fb46444b7fff (res:10, total_weight:7845, count:3, children:0)
#    │  │  │     │  └─ 8a1fb4644487fff (res:10, total_weight:1513, count:2, children:0)
#    │  │  │     ├─ 891fb464447ffff (res:9, total_weight:68237, count:26, children:4)
#    │  │  │     │  ├─ 8a1fb4644467fff (res:10, total_weight:13690, count:8, children:0)
#    │  │  │     │  ├─ 8a1fb464445ffff (res:10, total_weight:1571, count:1, children:0)
#    │  │  │     │  ├─ 8a1fb4644477fff (res:10, total_weight:43275, count:12, children:0)
#    │  │  │     │  └─ 8a1fb4644447fff (res:10, total_weight:9701, count:5, children:0)
#    │  │  │     └─ 891fb464453ffff (res:9, total_weight:12607, count:5, children:3)
#    │  │  │        ├─ 8a1fb464451ffff (res:10, total_weight:9502, count:2, children:0)
#    │  │  │        ├─ 8a1fb4644517fff (res:10, total_weight:1641, count:2, children:0)
#    │  │  │        └─ 8a1fb464450ffff (res:10, total_weight:1464, count:1, children:0)
#    │  │  ├─ 871fb4646ffffff (res:7, total_weight:4506424, count:1394, children:7)
#    │  │  │  ├─ 881fb46463fffff (res:8, total_weight:494426, count:84, children:7)
#    │  │  │  │  ├─ 891fb46463bffff (res:9, total_weight:86202, count:18, children:6)
#    │  │  │  │  │  ├─ 8a1fb464639ffff (res:10, total_weight:28585, count:2, children:0)
#    │  │  │  │  │  ├─ 8a1fb4646387fff (res:10, total_weight:1343, count:1, children:0)
#    │  │  │  │  │  ├─ 8a1fb46463b7fff (res:10, total_weight:23507, count:7, children:0)
#    │  │  │  │  │  ├─ 8a1fb46463affff (res:10, total_weight:13304, count:2, children:0)
#    │  │  │  │  │  ├─ 8a1fb46463a7fff (res:10, total_weight:7805, count:3, children:0)
#    │  │  │  │  │  └─ 8a1fb4646397fff (res:10, total_weight:11658, count:3, children:0)
#    │  │  │  │  ├─ 891fb46462fffff (res:9, total_weight:8914, count:5, children:3)
#    │  │  │  │  │  ├─ 8a1fb46462effff (res:10, total_weight:3476, count:2, children:0)
#    │  │  │  │  │  ├─ 8a1fb46462cffff (res:10, total_weight:1738, count:1, children:0)
#    │  │  │  │  │  └─ 8a1fb46462d7fff (res:10, total_weight:3700, count:2, children:0)
#    │  │  │  │  ├─ 891fb464637ffff (res:9, total_weight:36175, count:9, children:4)
#    │  │  │  │  │  ├─ 8a1fb4646357fff (res:10, total_weight:7144, count:2, children:0)
#    │  │  │  │  │  ├─ 8a1fb4646377fff (res:10, total_weight:16099, count:4, children:0)
#    │  │  │  │  │  ├─ 8a1fb4646367fff (res:10, total_weight:9574, count:2, children:0)
#    │  │  │  │  │  └─ 8a1fb464636ffff (res:10, total_weight:3358, count:1, children:0)
#    │  │  │  │  ├─ 891fb464627ffff (res:9, total_weight:47999, count:9, children:3)
#    │  │  │  │  │  ├─ 8a1fb4646247fff (res:10, total_weight:1738, count:1, children:0)
#    │  │  │  │  │  ├─ 8a1fb464625ffff (res:10, total_weight:37548, count:5, children:0)
#    │  │  │  │  │  └─ 8a1fb4646257fff (res:10, total_weight:8713, count:3, children:0)
#    │  │  │  │  ├─ 891fb46462bffff (res:9, total_weight:215290, count:22, children:7)
#    │  │  │  │  │  ├─ 8a1fb46462a7fff (res:10, total_weight:655, count:1, children:0)
#    │  │  │  │  │  ├─ 8a1fb46462b7fff (res:10, total_weight:51319, count:6, children:0)
#    │  │  │  │  │  ├─ 8a1fb4646297fff (res:10, total_weight:138105, count:8, children:0)
#    │  │  │  │  │  ├─ 8a1fb464629ffff (res:10, total_weight:1951, count:1, children:0)
#    │  │  │  │  │  ├─ 8a1fb464628ffff (res:10, total_weight:2016, count:2, children:0)
#    │  │  │  │  │  ├─ 8a1fb4646287fff (res:10, total_weight:2606, count:2, children:0)
#    │  │  │  │  │  └─ 8a1fb46462affff (res:10, total_weight:18638, count:2, children:0)
#    │  │  │  │  ├─ 891fb464623ffff (res:9, total_weight:5747, count:2, children:2)
#    │  │  │  │  │  ├─ 8a1fb4646237fff (res:10, total_weight:4739, count:1, children:0)
#    │  │  │  │  │  └─ 8a1fb4646217fff (res:10, total_weight:1008, count:1, children:0)
#    │  │  │  │  └─ 891fb464633ffff (res:9, total_weight:94099, count:19, children:5)
#    │  │  │  │     ├─ 8a1fb464631ffff (res:10, total_weight:21506, count:4, children:0)
#    │  │  │  │     ├─ 8a1fb4646337fff (res:10, total_weight:2673, count:2, children:0)
#    │  │  │  │     ├─ 8a1fb4646307fff (res:10, total_weight:12860, count:3, children:0)
#    │  │  │  │     ├─ 8a1fb464632ffff (res:10, total_weight:29741, count:5, children:0)
#    │  │  │  │     └─ 8a1fb464630ffff (res:10, total_weight:27319, count:5, children:0)
#    │  │  │  ├─ 881fb46465fffff (res:8, total_weight:304725, count:100, children:7)
#    │  │  │  │  ├─ 891fb46464bffff (res:9, total_weight:22548, count:6, children:4)
#    │  │  │  │  │  ├─ 8a1fb4646497fff (res:10, total_weight:3914, count:3, children:0)
#    │  │  │  │  │  ├─ 8a1fb464649ffff (res:10, total_weight:655, count:1, children:0)
#    │  │  │  │  │  ├─ 8a1fb46464a7fff (res:10, total_weight:14374, count:1, children:0)
#    │  │  │  │  │  └─ 8a1fb46464affff (res:10, total_weight:3605, count:1, children:0)
#    │  │  │  │  ├─ 891fb46465bffff (res:9, total_weight:2345, count:1, children:1)
#    │  │  │  │  │  └─ 8a1fb46465b7fff (res:10, total_weight:2345, count:1, children:0)
#    │  │  │  │  ├─ 891fb46464fffff (res:9, total_weight:63664, count:28, children:6)
#    │  │  │  │  │  ├─ 8a1fb46464dffff (res:10, total_weight:25682, count:4, children:0)
#    │  │  │  │  │  ├─ 8a1fb46464e7fff (res:10, total_weight:5587, count:3, children:0)
#    │  │  │  │  │  ├─ 8a1fb46464cffff (res:10, total_weight:12091, count:8, children:0)
#    │  │  │  │  │  ├─ 8a1fb46464d7fff (res:10, total_weight:4655, count:1, children:0)
#    │  │  │  │  │  ├─ 8a1fb46464c7fff (res:10, total_weight:13420, count:10, children:0)
#    │  │  │  │  │  └─ 8a1fb46464effff (res:10, total_weight:2229, count:2, children:0)
#    │  │  │  │  ├─ 891fb464657ffff (res:9, total_weight:109890, count:41, children:7)
#    │  │  │  │  │  ├─ 8a1fb464656ffff (res:10, total_weight:1311, count:1, children:0)
#    │  │  │  │  │  ├─ 8a1fb464655ffff (res:10, total_weight:39184, count:17, children:0)
#    │  │  │  │  │  ├─ 8a1fb4646567fff (res:10, total_weight:20018, count:8, children:0)
#    │  │  │  │  │  ├─ 8a1fb4646557fff (res:10, total_weight:28547, count:10, children:0)
#    │  │  │  │  │  ├─ 8a1fb4646577fff (res:10, total_weight:3036, count:1, children:0)
#    │  │  │  │  │  ├─ 8a1fb464654ffff (res:10, total_weight:3827, count:1, children:0)
#    │  │  │  │  │  └─ 8a1fb4646547fff (res:10, total_weight:13967, count:3, children:0)
#    │  │  │  │  ├─ 891fb464647ffff (res:9, total_weight:11865, count:3, children:3)
#    │  │  │  │  │  ├─ 8a1fb4646477fff (res:10, total_weight:2345, count:1, children:0)
#    │  │  │  │  │  ├─ 8a1fb4646457fff (res:10, total_weight:650, count:1, children:0)
#    │  │  │  │  │  └─ 8a1fb464646ffff (res:10, total_weight:8870, count:1, children:0)
#    │  │  │  │  ├─ 891fb464653ffff (res:9, total_weight:59246, count:9, children:5)
#    │  │  │  │  │  ├─ 8a1fb464652ffff (res:10, total_weight:4795, count:1, children:0)
#    │  │  │  │  │  ├─ 8a1fb4646537fff (res:10, total_weight:15243, count:1, children:0)
#    │  │  │  │  │  ├─ 8a1fb4646527fff (res:10, total_weight:16712, count:2, children:0)
#    │  │  │  │  │  ├─ 8a1fb4646507fff (res:10, total_weight:3314, count:1, children:0)
#    │  │  │  │  │  └─ 8a1fb464650ffff (res:10, total_weight:19182, count:4, children:0)
#    │  │  │  │  └─ 891fb464643ffff (res:9, total_weight:35167, count:12, children:5)
#    │  │  │  │     ├─ 8a1fb464640ffff (res:10, total_weight:5666, count:5, children:0)
#    │  │  │  │     ├─ 8a1fb4646407fff (res:10, total_weight:9076, count:1, children:0)
#    │  │  │  │     ├─ 8a1fb464642ffff (res:10, total_weight:13176, count:4, children:0)
#    │  │  │  │     ├─ 8a1fb464641ffff (res:10, total_weight:4655, count:1, children:0)
#    │  │  │  │     └─ 8a1fb4646417fff (res:10, total_weight:2594, count:1, children:0)
#    │  │  │  ├─ 881fb46467fffff (res:8, total_weight:220087, count:39, children:6)
#    │  │  │  │  ├─ 891fb464663ffff (res:9, total_weight:7386, count:4, children:3)
#    │  │  │  │  │  ├─ 8a1fb4646627fff (res:10, total_weight:692, count:1, children:0)
#    │  │  │  │  │  ├─ 8a1fb464661ffff (res:10, total_weight:3552, count:1, children:0)
#    │  │  │  │  │  └─ 8a1fb4646637fff (res:10, total_weight:3142, count:2, children:0)
#    │  │  │  │  ├─ 891fb46466fffff (res:9, total_weight:6758, count:4, children:1)
#    │  │  │  │  │  └─ 8a1fb46466e7fff (res:10, total_weight:6758, count:4, children:0)
#    │  │  │  │  ├─ 891fb46467bffff (res:9, total_weight:12339, count:13, children:4)
#    │  │  │  │  │  ├─ 8a1fb46467a7fff (res:10, total_weight:692, count:1, children:0)
#    │  │  │  │  │  ├─ 8a1fb46467affff (res:10, total_weight:692, count:1, children:0)
#    │  │  │  │  │  ├─ 8a1fb4646787fff (res:10, total_weight:3464, count:5, children:0)
#    │  │  │  │  │  └─ 8a1fb46467b7fff (res:10, total_weight:7491, count:6, children:0)
#    │  │  │  │  ├─ 891fb464677ffff (res:9, total_weight:100219, count:9, children:4)
#    │  │  │  │  │  ├─ 8a1fb464675ffff (res:10, total_weight:20405, count:3, children:0)
#    │  │  │  │  │  ├─ 8a1fb464674ffff (res:10, total_weight:28585, count:2, children:0)
#    │  │  │  │  │  ├─ 8a1fb464676ffff (res:10, total_weight:33966, count:3, children:0)
#    │  │  │  │  │  └─ 8a1fb4646747fff (res:10, total_weight:17263, count:1, children:0)
#    │  │  │  │  ├─ 891fb464667ffff (res:9, total_weight:87886, count:6, children:3)
#    │  │  │  │  │  ├─ 8a1fb4646657fff (res:10, total_weight:17263, count:1, children:0)
#    │  │  │  │  │  ├─ 8a1fb464664ffff (res:10, total_weight:1571, count:1, children:0)
#    │  │  │  │  │  └─ 8a1fb464666ffff (res:10, total_weight:69052, count:4, children:0)
#    │  │  │  │  └─ 891fb464673ffff (res:9, total_weight:5499, count:3, children:1)
#    │  │  │  │     └─ 8a1fb4646727fff (res:10, total_weight:5499, count:3, children:0)
#    │  │  │  ├─ 881fb4646dfffff (res:8, total_weight:771818, count:289, children:7)
#    │  │  │  │  ├─ 891fb4646dbffff (res:9, total_weight:181267, count:73, children:7)
#    │  │  │  │  │  ├─ 8a1fb4646d97fff (res:10, total_weight:79724, count:24, children:0)
#    │  │  │  │  │  ├─ 8a1fb4646d87fff (res:10, total_weight:14833, count:8, children:0)
#    │  │  │  │  │  ├─ 8a1fb4646d9ffff (res:10, total_weight:8437, count:2, children:0)
#    │  │  │  │  │  ├─ 8a1fb4646daffff (res:10, total_weight:14184, count:11, children:0)
#    │  │  │  │  │  ├─ 8a1fb4646d8ffff (res:10, total_weight:11992, count:7, children:0)
#    │  │  │  │  │  ├─ 8a1fb4646db7fff (res:10, total_weight:18585, count:7, children:0)
#    │  │  │  │  │  └─ 8a1fb4646da7fff (res:10, total_weight:33512, count:14, children:0)
#    │  │  │  │  ├─ 891fb4646cfffff (res:9, total_weight:158440, count:59, children:7)
#    │  │  │  │  │  ├─ 8a1fb4646cd7fff (res:10, total_weight:13068, count:7, children:0)
#    │  │  │  │  │  ├─ 8a1fb4646ce7fff (res:10, total_weight:12736, count:5, children:0)
#    │  │  │  │  │  ├─ 8a1fb4646cf7fff (res:10, total_weight:13256, count:5, children:0)
#    │  │  │  │  │  ├─ 8a1fb4646ccffff (res:10, total_weight:29094, count:11, children:0)
#    │  │  │  │  │  ├─ 8a1fb4646cc7fff (res:10, total_weight:39087, count:15, children:0)
#    │  │  │  │  │  ├─ 8a1fb4646cdffff (res:10, total_weight:25504, count:9, children:0)
#    │  │  │  │  │  └─ 8a1fb4646ceffff (res:10, total_weight:25695, count:7, children:0)
#    │  │  │  │  ├─ 891fb4646c7ffff (res:9, total_weight:168219, count:59, children:6)
#    │  │  │  │  │  ├─ 8a1fb4646c57fff (res:10, total_weight:48177, count:14, children:0)
#    │  │  │  │  │  ├─ 8a1fb4646c47fff (res:10, total_weight:6013, count:2, children:0)
#    │  │  │  │  │  ├─ 8a1fb4646c77fff (res:10, total_weight:36604, count:15, children:0)
#    │  │  │  │  │  ├─ 8a1fb4646c6ffff (res:10, total_weight:26221, count:11, children:0)
#    │  │  │  │  │  ├─ 8a1fb4646c67fff (res:10, total_weight:41937, count:12, children:0)
#    │  │  │  │  │  └─ 8a1fb4646c5ffff (res:10, total_weight:9267, count:5, children:0)
#    │  │  │  │  ├─ 891fb4646cbffff (res:9, total_weight:76448, count:30, children:6)
#    │  │  │  │  │  ├─ 8a1fb4646caffff (res:10, total_weight:34597, count:11, children:0)
#    │  │  │  │  │  ├─ 8a1fb4646c97fff (res:10, total_weight:7682, count:4, children:0)
#    │  │  │  │  │  ├─ 8a1fb4646c8ffff (res:10, total_weight:3479, count:2, children:0)
#    │  │  │  │  │  ├─ 8a1fb4646cb7fff (res:10, total_weight:11980, count:5, children:0)
#    │  │  │  │  │  ├─ 8a1fb4646ca7fff (res:10, total_weight:17242, count:7, children:0)
#    │  │  │  │  │  └─ 8a1fb4646c9ffff (res:10, total_weight:1468, count:1, children:0)
#    │  │  │  │  ├─ 891fb4646c3ffff (res:9, total_weight:59999, count:20, children:4)
#    │  │  │  │  │  ├─ 8a1fb4646c0ffff (res:10, total_weight:25599, count:7, children:0)
#    │  │  │  │  │  ├─ 8a1fb4646c2ffff (res:10, total_weight:7229, count:2, children:0)
#    │  │  │  │  │  ├─ 8a1fb4646c17fff (res:10, total_weight:22259, count:9, children:0)
#    │  │  │  │  │  └─ 8a1fb4646c27fff (res:10, total_weight:4912, count:2, children:0)
#    │  │  │  │  ├─ 891fb4646d7ffff (res:9, total_weight:105733, count:33, children:7)
#    │  │  │  │  │  ├─ 8a1fb4646d77fff (res:10, total_weight:2679, count:2, children:0)
#    │  │  │  │  │  ├─ 8a1fb4646d47fff (res:10, total_weight:27289, count:8, children:0)
#    │  │  │  │  │  ├─ 8a1fb4646d67fff (res:10, total_weight:8914, count:1, children:0)
#    │  │  │  │  │  ├─ 8a1fb4646d5ffff (res:10, total_weight:43801, count:13, children:0)
#    │  │  │  │  │  ├─ 8a1fb4646d57fff (res:10, total_weight:9374, count:3, children:0)
#    │  │  │  │  │  ├─ 8a1fb4646d4ffff (res:10, total_weight:7791, count:3, children:0)
#    │  │  │  │  │  └─ 8a1fb4646d6ffff (res:10, total_weight:5885, count:3, children:0)
#    │  │  │  │  └─ 891fb4646d3ffff (res:9, total_weight:21712, count:15, children:7)
#    │  │  │  │     ├─ 8a1fb4646d07fff (res:10, total_weight:718, count:1, children:0)
#    │  │  │  │     ├─ 8a1fb4646d1ffff (res:10, total_weight:2038, count:2, children:0)
#    │  │  │  │     ├─ 8a1fb4646d2ffff (res:10, total_weight:4424, count:2, children:0)
#    │  │  │  │     ├─ 8a1fb4646d0ffff (res:10, total_weight:2592, count:2, children:0)
#    │  │  │  │     ├─ 8a1fb4646d27fff (res:10, total_weight:1056, count:2, children:0)
#    │  │  │  │     ├─ 8a1fb4646d37fff (res:10, total_weight:5667, count:3, children:0)
#    │  │  │  │     └─ 8a1fb4646d17fff (res:10, total_weight:5217, count:3, children:0)
#    │  │  │  ├─ 881fb46469fffff (res:8, total_weight:1040377, count:262, children:7)
#    │  │  │  │  ├─ 891fb46468bffff (res:9, total_weight:125058, count:28, children:7)
#    │  │  │  │  │  ├─ 8a1fb46468affff (res:10, total_weight:40597, count:7, children:0)
#    │  │  │  │  │  ├─ 8a1fb4646897fff (res:10, total_weight:5291, count:3, children:0)
#    │  │  │  │  │  ├─ 8a1fb46468a7fff (res:10, total_weight:28156, count:6, children:0)
#    │  │  │  │  │  ├─ 8a1fb464688ffff (res:10, total_weight:14647, count:3, children:0)
#    │  │  │  │  │  ├─ 8a1fb46468b7fff (res:10, total_weight:18844, count:5, children:0)
#    │  │  │  │  │  ├─ 8a1fb464689ffff (res:10, total_weight:8321, count:3, children:0)
#    │  │  │  │  │  └─ 8a1fb4646887fff (res:10, total_weight:9202, count:1, children:0)
#    │  │  │  │  ├─ 891fb464697ffff (res:9, total_weight:131587, count:29, children:7)
#    │  │  │  │  │  ├─ 8a1fb464695ffff (res:10, total_weight:2443, count:2, children:0)
#    │  │  │  │  │  ├─ 8a1fb464696ffff (res:10, total_weight:21871, count:2, children:0)
#    │  │  │  │  │  ├─ 8a1fb4646947fff (res:10, total_weight:21643, count:5, children:0)
#    │  │  │  │  │  ├─ 8a1fb4646967fff (res:10, total_weight:375, count:1, children:0)
#    │  │  │  │  │  ├─ 8a1fb464694ffff (res:10, total_weight:4228, count:3, children:0)
#    │  │  │  │  │  ├─ 8a1fb4646957fff (res:10, total_weight:67811, count:11, children:0)
#    │  │  │  │  │  └─ 8a1fb4646977fff (res:10, total_weight:13216, count:5, children:0)
#    │  │  │  │  ├─ 891fb464687ffff (res:9, total_weight:123569, count:28, children:7)
#    │  │  │  │  │  ├─ 8a1fb464685ffff (res:10, total_weight:2923, count:1, children:0)
#    │  │  │  │  │  ├─ 8a1fb464684ffff (res:10, total_weight:3678, count:2, children:0)
#    │  │  │  │  │  ├─ 8a1fb4646847fff (res:10, total_weight:19655, count:4, children:0)
#    │  │  │  │  │  ├─ 8a1fb464686ffff (res:10, total_weight:18451, count:8, children:0)
#    │  │  │  │  │  ├─ 8a1fb4646857fff (res:10, total_weight:49665, count:7, children:0)
#    │  │  │  │  │  ├─ 8a1fb4646877fff (res:10, total_weight:15486, count:3, children:0)
#    │  │  │  │  │  └─ 8a1fb4646867fff (res:10, total_weight:13711, count:3, children:0)
#    │  │  │  │  ├─ 891fb46469bffff (res:9, total_weight:163001, count:67, children:7)
#    │  │  │  │  │  ├─ 8a1fb4646997fff (res:10, total_weight:14004, count:6, children:0)
#    │  │  │  │  │  ├─ 8a1fb4646987fff (res:10, total_weight:18141, count:6, children:0)
#    │  │  │  │  │  ├─ 8a1fb464699ffff (res:10, total_weight:13894, count:7, children:0)
#    │  │  │  │  │  ├─ 8a1fb46469affff (res:10, total_weight:2888, count:1, children:0)
#    │  │  │  │  │  ├─ 8a1fb46469a7fff (res:10, total_weight:23513, count:9, children:0)
#    │  │  │  │  │  ├─ 8a1fb46469b7fff (res:10, total_weight:81591, count:34, children:0)
#    │  │  │  │  │  └─ 8a1fb464698ffff (res:10, total_weight:8970, count:4, children:0)
#    │  │  │  │  ├─ 891fb464683ffff (res:9, total_weight:80093, count:17, children:5)
#    │  │  │  │  │  ├─ 8a1fb4646827fff (res:10, total_weight:12073, count:6, children:0)
#    │  │  │  │  │  ├─ 8a1fb4646837fff (res:10, total_weight:463, count:1, children:0)
#    │  │  │  │  │  ├─ 8a1fb464681ffff (res:10, total_weight:41193, count:4, children:0)
#    │  │  │  │  │  ├─ 8a1fb464682ffff (res:10, total_weight:4133, count:2, children:0)
#    │  │  │  │  │  └─ 8a1fb464680ffff (res:10, total_weight:22231, count:4, children:0)
#    │  │  │  │  ├─ 891fb46468fffff (res:9, total_weight:228077, count:53, children:7)
#    │  │  │  │  │  ├─ 8a1fb46468dffff (res:10, total_weight:64411, count:20, children:0)
# ...
#          │  │  │  ├─ 8a1fb475c687fff (res:10, total_weight:1834, count:2, children:0)
#          │  │  │  ├─ 8a1fb475c6a7fff (res:10, total_weight:1834, count:2, children:0)
#          │  │  │  ├─ 8a1fb475c68ffff (res:10, total_weight:1805, count:2, children:0)
#          │  │  │  └─ 8a1fb475c69ffff (res:10, total_weight:3621, count:1, children:0)
#          │  │  ├─ 891fb475c67ffff (res:9, total_weight:5774, count:4, children:4)
#          │  │  │  ├─ 8a1fb475c66ffff (res:10, total_weight:1093, count:1, children:0)
#          │  │  │  ├─ 8a1fb475c64ffff (res:10, total_weight:1286, count:1, children:0)
#          │  │  │  ├─ 8a1fb475c657fff (res:10, total_weight:2109, count:1, children:0)
#          │  │  │  └─ 8a1fb475c65ffff (res:10, total_weight:1286, count:1, children:0)
#          │  │  ├─ 891fb475c6fffff (res:9, total_weight:6305, count:6, children:3)
#          │  │  │  ├─ 8a1fb475c6f7fff (res:10, total_weight:2857, count:3, children:0)
#          │  │  │  ├─ 8a1fb475c6e7fff (res:10, total_weight:1713, count:2, children:0)
#          │  │  │  └─ 8a1fb475c6c7fff (res:10, total_weight:1735, count:1, children:0)
#          │  │  ├─ 891fb475c7bffff (res:9, total_weight:2960, count:2, children:2)
#          │  │  │  ├─ 8a1fb475c797fff (res:10, total_weight:1480, count:1, children:0)
#          │  │  │  └─ 8a1fb475c7b7fff (res:10, total_weight:1480, count:1, children:0)
#          │  │  ├─ 891fb475c63ffff (res:9, total_weight:8736, count:8, children:3)
#          │  │  │  ├─ 8a1fb475c60ffff (res:10, total_weight:5038, count:4, children:0)
#          │  │  │  ├─ 8a1fb475c607fff (res:10, total_weight:2046, count:2, children:0)
#          │  │  │  └─ 8a1fb475c61ffff (res:10, total_weight:1652, count:2, children:0)
#          │  │  ├─ 891fb475c77ffff (res:9, total_weight:2433, count:1, children:1)
#          │  │  │  └─ 8a1fb475c747fff (res:10, total_weight:2433, count:1, children:0)
#          │  │  └─ 891fb475c73ffff (res:9, total_weight:1300, count:2, children:1)
#          │  │     └─ 8a1fb475c71ffff (res:10, total_weight:1300, count:2, children:0)
#          │  └─ 881fb475c1fffff (res:8, total_weight:53779, count:16, children:5)
#          │     ├─ 891fb475c0bffff (res:9, total_weight:5017, count:4, children:3)
#          │     │  ├─ 8a1fb475c097fff (res:10, total_weight:2509, count:2, children:0)
#          │     │  ├─ 8a1fb475c08ffff (res:10, total_weight:1254, count:1, children:0)
#          │     │  └─ 8a1fb475c087fff (res:10, total_weight:1254, count:1, children:0)
#          │     ├─ 891fb475c03ffff (res:9, total_weight:12475, count:5, children:3)
#          │     │  ├─ 8a1fb475c007fff (res:10, total_weight:1254, count:1, children:0)
#          │     │  ├─ 8a1fb475c02ffff (res:10, total_weight:2160, count:2, children:0)
#          │     │  └─ 8a1fb475c017fff (res:10, total_weight:9061, count:2, children:0)
#          │     ├─ 891fb475c17ffff (res:9, total_weight:4207, count:1, children:1)
#          │     │  └─ 8a1fb475c14ffff (res:10, total_weight:4207, count:1, children:0)
#          │     ├─ 891fb475c13ffff (res:9, total_weight:16800, count:3, children:3)
#          │     │  ├─ 8a1fb475c12ffff (res:10, total_weight:3593, count:1, children:0)
#          │     │  ├─ 8a1fb475c137fff (res:10, total_weight:9614, count:1, children:0)
#          │     │  └─ 8a1fb475c10ffff (res:10, total_weight:3593, count:1, children:0)
#          │     └─ 891fb475c0fffff (res:9, total_weight:15280, count:3, children:2)
#          │        ├─ 8a1fb475c0effff (res:10, total_weight:13486, count:1, children:0)
#          │        └─ 8a1fb475c0cffff (res:10, total_weight:1794, count:2, children:0)
#          └─ 871fb475dffffff (res:7, total_weight:987751, count:338, children:7)
#             ├─ 881fb475d9fffff (res:8, total_weight:240105, count:53, children:7)
#             │  ├─ 891fb475d87ffff (res:9, total_weight:15270, count:3, children:3)
#             │  │  ├─ 8a1fb475d867fff (res:10, total_weight:2127, count:1, children:0)
#             │  │  ├─ 8a1fb475d857fff (res:10, total_weight:6832, count:1, children:0)
#             │  │  └─ 8a1fb475d85ffff (res:10, total_weight:6311, count:1, children:0)
#             │  ├─ 891fb475d8fffff (res:9, total_weight:95406, count:16, children:5)
#             │  │  ├─ 8a1fb475d8dffff (res:10, total_weight:8439, count:2, children:0)
#             │  │  ├─ 8a1fb475d8cffff (res:10, total_weight:9148, count:2, children:0)
#             │  │  ├─ 8a1fb475d8c7fff (res:10, total_weight:6311, count:1, children:0)
#             │  │  ├─ 8a1fb475d8e7fff (res:10, total_weight:18934, count:3, children:0)
#             │  │  └─ 8a1fb475d8effff (res:10, total_weight:52574, count:8, children:0)
#             │  ├─ 891fb475d93ffff (res:9, total_weight:7120, count:3, children:1)
#             │  │  └─ 8a1fb475d91ffff (res:10, total_weight:7120, count:3, children:0)
#             │  ├─ 891fb475d9bffff (res:9, total_weight:16342, count:8, children:4)
#             │  │  ├─ 8a1fb475d99ffff (res:10, total_weight:1106, count:1, children:0)
#             │  │  ├─ 8a1fb475d987fff (res:10, total_weight:1106, count:1, children:0)
#             │  │  ├─ 8a1fb475d9a7fff (res:10, total_weight:9791, count:3, children:0)
#             │  │  └─ 8a1fb475d9affff (res:10, total_weight:4339, count:3, children:0)
#             │  ├─ 891fb475d8bffff (res:9, total_weight:12622, count:2, children:2)
#             │  │  ├─ 8a1fb475d88ffff (res:10, total_weight:6311, count:1, children:0)
#             │  │  └─ 8a1fb475d8affff (res:10, total_weight:6311, count:1, children:0)
#             │  ├─ 891fb475d83ffff (res:9, total_weight:52353, count:15, children:4)
#             │  │  ├─ 8a1fb475d817fff (res:10, total_weight:22010, count:5, children:0)
#             │  │  ├─ 8a1fb475d81ffff (res:10, total_weight:6311, count:1, children:0)
#             │  │  ├─ 8a1fb475d807fff (res:10, total_weight:13432, count:4, children:0)
#             │  │  └─ 8a1fb475d837fff (res:10, total_weight:10600, count:5, children:0)
#             │  └─ 891fb475d97ffff (res:9, total_weight:40992, count:6, children:3)
#             │     ├─ 8a1fb475d957fff (res:10, total_weight:6832, count:1, children:0)
#             │     ├─ 8a1fb475d977fff (res:10, total_weight:13664, count:2, children:0)
#             │     └─ 8a1fb475d967fff (res:10, total_weight:20496, count:3, children:0)
#             ├─ 881fb475d5fffff (res:8, total_weight:149872, count:47, children:6)
#             │  ├─ 891fb475d4fffff (res:9, total_weight:45876, count:9, children:3)
#             │  │  ├─ 8a1fb475d4d7fff (res:10, total_weight:40460, count:3, children:0)
#             │  │  ├─ 8a1fb475d4dffff (res:10, total_weight:1805, count:2, children:0)
#             │  │  └─ 8a1fb475d4cffff (res:10, total_weight:3611, count:4, children:0)
#             │  ├─ 891fb475d5bffff (res:9, total_weight:10771, count:3, children:3)
#             │  │  ├─ 8a1fb475d58ffff (res:10, total_weight:1865, count:1, children:0)
#             │  │  ├─ 8a1fb475d587fff (res:10, total_weight:3279, count:1, children:0)
#             │  │  └─ 8a1fb475d5affff (res:10, total_weight:5627, count:1, children:0)
#             │  ├─ 891fb475d57ffff (res:9, total_weight:23675, count:6, children:2)
#             │  │  ├─ 8a1fb475d577fff (res:10, total_weight:21548, count:5, children:0)
#             │  │  └─ 8a1fb475d54ffff (res:10, total_weight:2127, count:1, children:0)
#             │  ├─ 891fb475d53ffff (res:9, total_weight:50887, count:21, children:6)
#             │  │  ├─ 8a1fb475d527fff (res:10, total_weight:3621, count:1, children:0)
#             │  │  ├─ 8a1fb475d52ffff (res:10, total_weight:6804, count:3, children:0)
#             │  │  ├─ 8a1fb475d507fff (res:10, total_weight:19328, count:9, children:0)
#             │  │  ├─ 8a1fb475d537fff (res:10, total_weight:9901, count:5, children:0)
#             │  │  ├─ 8a1fb475d50ffff (res:10, total_weight:7612, count:2, children:0)
#             │  │  └─ 8a1fb475d517fff (res:10, total_weight:3621, count:1, children:0)
#             │  ├─ 891fb475d47ffff (res:9, total_weight:15384, count:7, children:4)
#             │  │  ├─ 8a1fb475d45ffff (res:10, total_weight:855, count:1, children:0)
#             │  │  ├─ 8a1fb475d447fff (res:10, total_weight:7507, count:2, children:0)
#             │  │  ├─ 8a1fb475d44ffff (res:10, total_weight:4895, count:3, children:0)
#             │  │  └─ 8a1fb475d467fff (res:10, total_weight:2127, count:1, children:0)
#             │  └─ 891fb475d4bffff (res:9, total_weight:3279, count:1, children:1)
#             │     └─ 8a1fb475d4a7fff (res:10, total_weight:3279, count:1, children:0)
#             ├─ 881fb475ddfffff (res:8, total_weight:197468, count:92, children:5)
#             │  ├─ 891fb475dcfffff (res:9, total_weight:38875, count:15, children:6)
#             │  │  ├─ 8a1fb475dcd7fff (res:10, total_weight:2744, count:1, children:0)
#             │  │  ├─ 8a1fb475dcdffff (res:10, total_weight:4309, count:1, children:0)
#             │  │  ├─ 8a1fb475dcf7fff (res:10, total_weight:16293, count:6, children:0)
#             │  │  ├─ 8a1fb475dceffff (res:10, total_weight:1248, count:2, children:0)
#             │  │  ├─ 8a1fb475dccffff (res:10, total_weight:3303, count:1, children:0)
#             │  │  └─ 8a1fb475dce7fff (res:10, total_weight:10978, count:4, children:0)
#             │  ├─ 891fb475dc7ffff (res:9, total_weight:101310, count:51, children:6)
#             │  │  ├─ 8a1fb475dc67fff (res:10, total_weight:4483, count:2, children:0)
#             │  │  ├─ 8a1fb475dc6ffff (res:10, total_weight:1106, count:1, children:0)
#             │  │  ├─ 8a1fb475dc5ffff (res:10, total_weight:32241, count:20, children:0)
#             │  │  ├─ 8a1fb475dc77fff (res:10, total_weight:32046, count:17, children:0)
#             │  │  ├─ 8a1fb475dc47fff (res:10, total_weight:11087, count:3, children:0)
#             │  │  └─ 8a1fb475dc57fff (res:10, total_weight:20347, count:8, children:0)
#             │  ├─ 891fb475dcbffff (res:9, total_weight:16863, count:6, children:5)
#             │  │  ├─ 8a1fb475dca7fff (res:10, total_weight:2744, count:1, children:0)
#             │  │  ├─ 8a1fb475dc8ffff (res:10, total_weight:2388, count:1, children:0)
#             │  │  ├─ 8a1fb475dc9ffff (res:10, total_weight:2570, count:1, children:0)
#             │  │  ├─ 8a1fb475dcaffff (res:10, total_weight:2744, count:1, children:0)
#             │  │  └─ 8a1fb475dc87fff (res:10, total_weight:6417, count:2, children:0)
#             │  ├─ 891fb475dd7ffff (res:9, total_weight:21228, count:13, children:4)
#             │  │  ├─ 8a1fb475dd47fff (res:10, total_weight:2570, count:1, children:0)
#             │  │  ├─ 8a1fb475dd4ffff (res:10, total_weight:3608, count:1, children:0)
#             │  │  ├─ 8a1fb475dd5ffff (res:10, total_weight:3933, count:3, children:0)
#             │  │  └─ 8a1fb475dd57fff (res:10, total_weight:11117, count:8, children:0)
#             │  └─ 891fb475dc3ffff (res:9, total_weight:19192, count:7, children:3)
#             │     ├─ 8a1fb475dc07fff (res:10, total_weight:2570, count:1, children:0)
#             │     ├─ 8a1fb475dc0ffff (res:10, total_weight:11133, count:4, children:0)
#             │     └─ 8a1fb475dc17fff (res:10, total_weight:5489, count:2, children:0)
#             ├─ 881fb475d7fffff (res:8, total_weight:315851, count:122, children:7)
#             │  ├─ 891fb475d77ffff (res:9, total_weight:17743, count:5, children:4)
#             │  │  ├─ 8a1fb475d747fff (res:10, total_weight:5699, count:2, children:0)
#             │  │  ├─ 8a1fb475d75ffff (res:10, total_weight:608, count:1, children:0)
#             │  │  ├─ 8a1fb475d777fff (res:10, total_weight:10978, count:1, children:0)
#             │  │  └─ 8a1fb475d74ffff (res:10, total_weight:458, count:1, children:0)
#             │  ├─ 891fb475d6fffff (res:9, total_weight:8511, count:3, children:2)
#             │  │  ├─ 8a1fb475d6dffff (res:10, total_weight:5674, count:2, children:0)
#             │  │  └─ 8a1fb475d6cffff (res:10, total_weight:2837, count:1, children:0)
#             │  ├─ 891fb475d73ffff (res:9, total_weight:4859, count:1, children:1)
#             │  │  └─ 8a1fb475d71ffff (res:10, total_weight:4859, count:1, children:0)
#             │  ├─ 891fb475d6bffff (res:9, total_weight:140877, count:44, children:7)
#             │  │  ├─ 8a1fb475d6affff (res:10, total_weight:22731, count:10, children:0)
#             │  │  ├─ 8a1fb475d6b7fff (res:10, total_weight:5610, count:4, children:0)
#             │  │  ├─ 8a1fb475d687fff (res:10, total_weight:4013, count:3, children:0)
#             │  │  ├─ 8a1fb475d697fff (res:10, total_weight:1321, count:1, children:0)
#             │  │  ├─ 8a1fb475d6a7fff (res:10, total_weight:41659, count:10, children:0)
#             │  │  ├─ 8a1fb475d68ffff (res:10, total_weight:62612, count:14, children:0)
#             │  │  └─ 8a1fb475d69ffff (res:10, total_weight:2931, count:2, children:0)
#             │  ├─ 891fb475d7bffff (res:9, total_weight:138652, count:66, children:5)
#             │  │  ├─ 8a1fb475d79ffff (res:10, total_weight:30161, count:14, children:0)
#             │  │  ├─ 8a1fb475d787fff (res:10, total_weight:681, count:1, children:0)
#             │  │  ├─ 8a1fb475d7affff (res:10, total_weight:96364, count:45, children:0)
#             │  │  ├─ 8a1fb475d797fff (res:10, total_weight:902, count:1, children:0)
#             │  │  └─ 8a1fb475d7a7fff (res:10, total_weight:10544, count:5, children:0)
#             │  ├─ 891fb475d63ffff (res:9, total_weight:2119, count:2, children:2)
#             │  │  ├─ 8a1fb475d60ffff (res:10, total_weight:1285, count:1, children:0)
#             │  │  └─ 8a1fb475d61ffff (res:10, total_weight:834, count:1, children:0)
#             │  └─ 891fb475d67ffff (res:9, total_weight:3090, count:1, children:1)
#             │     └─ 8a1fb475d657fff (res:10, total_weight:3090, count:1, children:0)
#             ├─ 881fb475dbfffff (res:8, total_weight:33586, count:7, children:4)
#             │  ├─ 891fb475da7ffff (res:9, total_weight:3640, count:1, children:1)
#             │  │  └─ 8a1fb475da47fff (res:10, total_weight:3640, count:1, children:0)
#             │  ├─ 891fb475dabffff (res:9, total_weight:608, count:1, children:1)
#             │  │  └─ 8a1fb475da87fff (res:10, total_weight:608, count:1, children:0)
#             │  ├─ 891fb475dbbffff (res:9, total_weight:26287, count:4, children:1)
#             │  │  └─ 8a1fb475dbb7fff (res:10, total_weight:26287, count:4, children:0)
#             │  └─ 891fb475db7ffff (res:9, total_weight:3051, count:1, children:1)
#             │     └─ 8a1fb475db4ffff (res:10, total_weight:3051, count:1, children:0)
#             ├─ 881fb475d1fffff (res:8, total_weight:49174, count:16, children:4)
#             │  ├─ 891fb475d03ffff (res:9, total_weight:20867, count:6, children:3)
#             │  │  ├─ 8a1fb475d027fff (res:10, total_weight:3827, count:1, children:0)
#             │  │  ├─ 8a1fb475d037fff (res:10, total_weight:3827, count:1, children:0)
#             │  │  └─ 8a1fb475d017fff (res:10, total_weight:13213, count:4, children:0)
#             │  ├─ 891fb475d0bffff (res:9, total_weight:9909, count:3, children:3)
#             │  │  ├─ 8a1fb475d0b7fff (res:10, total_weight:3303, count:1, children:0)
#             │  │  ├─ 8a1fb475d087fff (res:10, total_weight:3303, count:1, children:0)
#             │  │  └─ 8a1fb475d0a7fff (res:10, total_weight:3303, count:1, children:0)
#             │  ├─ 891fb475d1bffff (res:9, total_weight:10743, count:5, children:4)
#             │  │  ├─ 8a1fb475d18ffff (res:10, total_weight:6606, count:2, children:0)
#             │  │  ├─ 8a1fb475d1a7fff (res:10, total_weight:1254, count:1, children:0)
#             │  │  ├─ 8a1fb475d197fff (res:10, total_weight:2127, count:1, children:0)
#             │  │  └─ 8a1fb475d1affff (res:10, total_weight:756, count:1, children:0)
#             │  └─ 891fb475d13ffff (res:9, total_weight:7655, count:2, children:1)
#             │     └─ 8a1fb475d11ffff (res:10, total_weight:7655, count:2, children:0)
#             └─ 881fb475d3fffff (res:8, total_weight:1695, count:1, children:1)
#                └─ 891fb475d3bffff (res:9, total_weight:1695, count:1, children:1)
#                   └─ 8a1fb475d397fff (res:10, total_weight:1695, count:1, children:0)

# %%
import numpy as np
import pandas as pd
import weakref
from math import *

class H3SbaAggregator:
    def __init__(self, od_matrix, tree_start, tree_end, param):
        # Copia e rinomina colonne
        self.od_matrix = od_matrix.copy()
        self.od_matrix = self.od_matrix.rename(columns={
            'start_h3': 'oi', 
            'end_h3': 'di', 
            'count': 'vol',
            'total_weight': 'weight'
        })
        
        self.tree_start = tree_start
        self.tree_end = tree_end
        self.param = param

        if param.get('target_vol_o') is None:
            raise ValueError('Must set a target_vol_o for tree aggregation')
        self.target_vol_o = param['target_vol_o']
        
        self.anon_thres = param['anon_thres']
        self.suppr_thres_frac = param['suppr_thres_frac']

        # Gestione dei timestep
        if 't' in self.od_matrix.columns:
            vol_ori_df = self.od_matrix.groupby('t')['vol'].sum().reset_index()
        else:
            self.od_matrix['t'] = 0
            vol_ori_df = pd.DataFrame({'t': [0], 'vol': [self.od_matrix['vol'].sum()]})

        self.eval_df = pd.DataFrame(columns=['t', 'vol_ori', 'vol_kept', 'nb_flows'])
        self.od_matrix_agg = pd.DataFrame(columns=['coi', 'cdi', 'vol', 'weight', 't', 'censored'])
        self.od_matrix_agg['censored'] = self.od_matrix_agg['censored'].astype(bool)

        for _, vol_ori_row in vol_ori_df.iterrows():
            timestep = vol_ori_row['t']
            od_matrix_agg_timestep = self.solve_timestep(timestep)

            total_vol = od_matrix_agg_timestep['vol'].sum()
            if total_vol != vol_ori_row['vol']:
                if total_vol >= self.anon_thres:
                    print(f"Warning: missing some volumes! ({od_matrix_agg_timestep['vol'].sum()} vs {vol_ori_row['vol']})")
                else:
                    print('Censored everything as total volume < anon thres')

            self.od_matrix_agg = pd.concat([self.od_matrix_agg, od_matrix_agg_timestep])

            eval_row = {
                't': timestep,
                'vol_ori': vol_ori_row['vol'],
                'vol_kept': (od_matrix_agg_timestep['vol']*(~od_matrix_agg_timestep['censored'])).sum(),
                'nb_flows': len(self.od_matrix_timestep),
            }
            self.eval_df = pd.concat([self.eval_df, pd.DataFrame(eval_row, index=[len(self.eval_df)])])

    def solve_timestep(self, timestep):
        ori_df = self.get_ori_df(timestep)
        total_vol = ori_df.sum()
        
        if total_vol < self.anon_thres:
            return pd.DataFrame({'coi': [self.tree_start.root.h3_id],
                                 'cdi': [self.tree_end.root.h3_id],
                                 'vol': 0,
                                 'weight': 0,
                                 't': timestep,
                                 'censored': total_vol != 0})
        elif total_vol == self.anon_thres:
            return pd.DataFrame({'coi': [self.tree_start.root.h3_id],
                                 'cdi': [self.tree_end.root.h3_id],
                                 'vol': total_vol,
                                 'weight': self.od_matrix_timestep['weight'].sum(),
                                 't': timestep,
                                 'censored': False})
        
        qo = H3VQuadtree(pop_df=ori_df,
                         h3_root=self.tree_start.root,
                         target_vol=self.target_vol_o,
                         ci_col='oi', vol_col='vol')
        o_partition = qo.flat_leaves

        od_matrix_agg_timestep = self.get_dest_agg(o_partition)
        od_matrix_agg_timestep['t'] = timestep
        od_matrix_agg_timestep['censored'] = (od_matrix_agg_timestep['vol'] < self.param['anon_thres']) & (od_matrix_agg_timestep['vol'] != 0)

        return od_matrix_agg_timestep

    def get_dest_agg(self, clusters_o):
        dest_df = self.get_dest_df(clusters_o)

        tree = H3SbaTree(pop_df=dest_df,
                         h3_root=self.tree_end.root,
                         clusters_o=clusters_o,
                         anon_thres=self.anon_thres)

        OD_report = tree.sba_solve(self.suppr_thres_frac * sum([co.vol for co in clusters_o]))
        od_matrix_agg_timestep = pd.DataFrame(OD_report, columns=['coi', 'cdi', 'vol', 'weight'])

        return od_matrix_agg_timestep

    def get_ori_df(self, timestep):
        self.od_matrix_timestep = self.od_matrix[self.od_matrix['t'] == timestep]
        ori_df = self.od_matrix_timestep.groupby('oi')['vol'].sum()
        return ori_df

    def get_dest_df(self, clusters_o):
        nb_leaves_by_cluster_o = [len(cluster_o.flat_leaves_name) for cluster_o in clusters_o]
        oicoidf = pd.DataFrame({
             'oi': np.concatenate([cluster_o.flat_leaves_name for cluster_o in clusters_o]),
             'coi': np.repeat([cluster_o.h3_node.h3_id for cluster_o in clusters_o], nb_leaves_by_cluster_o)
        })

        dest_df = self.od_matrix_timestep.merge(oicoidf, on='oi', how='outer').drop(columns=['oi'])
        dest_df = dest_df.groupby(['coi', 'di']).agg({'vol': 'sum', 'weight': 'sum'}).reset_index()
        dest_df = dest_df.groupby('di').agg(list)

        return dest_df


class H3SbaTree:
    def __init__(self, pop_df, h3_root, clusters_o, anon_thres=0):
        self.pop_df = pop_df
        self.anon_thres = anon_thres
        
        self.clusters_o = clusters_o
        self.cluster_order = {cluster.h3_node.h3_id: i for i, cluster in enumerate(clusters_o)}
        
        self.area = h3_root.resolution
        self.areas_o = np.array([co.h3_node.resolution for co in self.clusters_o])
        
        self.root = H3SbaNode(h3_root, weakref.ref(self))

    def sba_solve(self, S):
        left_delta = 0
        self.root.activate(left_delta)
        left_slope = self.root.best_vol_suppr.sum() - S
        left_score = self.root.best_score.sum() - left_delta*S
        if left_slope < 0:
            return self.get_leaves_arr()

        right_delta = self.area
        self.root.activate(right_delta)
        right_slope = self.root.best_vol_suppr.sum() - S
        right_score = self.root.best_score.sum() - right_delta*S
        
        while right_slope > 0:
            left_delta = right_delta
            left_slope = right_slope
            left_score = right_score
            right_delta += self.area
            self.root.activate(right_delta)
            right_slope = self.root.best_vol_suppr.sum() - S
            right_score = self.root.best_score.sum() - right_delta*S
        
        while True:
            mid_delta = (left_slope*left_delta - right_slope*right_delta + right_score - left_score)/(left_slope - right_slope)
            self.root.activate(mid_delta)
            mid_slope = self.root.best_vol_suppr.sum() - S
            mid_score = self.root.best_score.sum() - mid_delta*S
            
            if round(mid_delta-left_delta, 5) == 0 or round(mid_delta-right_delta, 5) == 0:
                return self.get_leaves_arr()
            else:
                if mid_slope > 0:
                    left_delta = mid_delta
                    left_slope = mid_slope
                    left_score = mid_score
                else:
                    right_delta = mid_delta
                    right_slope = mid_slope
                    right_score = mid_score

    def get_leaves_arr(self):
        leaves_arr = []
        for ori_counter in range(len(self.cluster_order)):
            self.root.get_leaves_arr_rec(leaves_arr, ori_counter)
        return leaves_arr


class H3SbaNode:
    def __init__(self, h3_tree_node, tree_weakref, parent=None):
        self.tree_weakref = tree_weakref
        self.h3_node = h3_tree_node
        self.k = self.tree_weakref().anon_thres
        
        self.children = [H3SbaNode(child, tree_weakref, self) for child in h3_tree_node.children.values()]
        cluster_order = self.tree_weakref().cluster_order
        self.vol_raw = np.zeros(len(cluster_order))
        self.weight_raw = np.zeros(len(cluster_order))
        
        if len(self.children) == 0:
            row = None
            try:
                row = self.tree_weakref().pop_df.loc[self.h3_node.h3_id]
            except KeyError:
                pass
            if row is not None:
                vols = row['vol']
                weights = row['weight']
                cois = row['coi']
                for i in range(len(cois)):
                    self.vol_raw[cluster_order[cois[i]]] = vols[i]
                    self.weight_raw[cluster_order[cois[i]]] = weights[i]
        elif len(self.children) > 0:
            self.vol_raw = np.sum([c.vol_raw for c in self.children], axis=0)
            self.weight_raw = np.sum([c.weight_raw for c in self.children], axis=0)
        
        self.censored = (self.vol_raw > 0) & (self.vol_raw < self.k)
        self.agg_vol_suppr = self.vol_raw * self.censored
        
        self.area = self.h3_node.resolution
        self.agg_error = self.vol_raw * (~self.censored) * (self.tree_weakref().areas_o + self.area)

    def activate(self, delta):
        for c in self.children:
            c.activate(delta)

        self.split_this = np.zeros(len(self.tree_weakref().clusters_o), dtype=bool)
        self.best_vol_suppr = self.agg_vol_suppr.copy()
        self.best_score = self.agg_error + self.agg_vol_suppr * delta

        if len(self.children) > 0:
            split_score = np.sum([c.best_score for c in self.children], axis=0)
            split_mask = (split_score < self.best_score) & (self.vol_raw > self.k)
            self.split_this[split_mask] = True
            self.best_score[split_mask] = split_score[split_mask]
            split_vol_suppr = np.sum([c.best_vol_suppr for c in self.children], axis=0)
            self.best_vol_suppr[split_mask] = split_vol_suppr[split_mask]

    def summary(self, ori_counter):
        cluster_h3_id = self.tree_weakref().clusters_o[ori_counter].h3_node.h3_id
        return [cluster_h3_id, self.h3_node.h3_id, self.vol_raw[ori_counter], self.weight_raw[ori_counter]]

    def get_leaves_arr_rec(self, leaves_arr, ori_counter):
        if not self.split_this[ori_counter]:
            leaves_arr += [self.summary(ori_counter)]
        else:
            for c in self.children:
                c.get_leaves_arr_rec(leaves_arr, ori_counter)


class H3VQuadtree:
    def __init__(self, pop_df, h3_root, target_vol, ci_col, vol_col):
        self.h3_root = h3_root
        self.pop_df = pop_df
        self.target_vol = target_vol
        self.flat_leaves = []
        self.ci_col = ci_col
        self.vol_col = vol_col
        self.grow()

    def grow(self):
        self.root = H3VQuadNode(self.h3_root, self)
        self.root.compute_best_split()
        self.root.keep_subtree(keep_condition=lambda x: x.split_this)
        self.flat_leaves = self.flatten_leaves()

    def flatten_leaves(self):
        flat_leaves = []
        self.root.flatten_leaves_rec(flat_leaves)
        return flat_leaves

    def get_total_error(self):
        return sum([leaf.error for leaf in self.flat_leaves])


class H3VQuadNode:
    def __init__(self, h3_tree_node, tree):
        self.tree = tree
        self.h3_node = h3_tree_node
        self.children = [H3VQuadNode(child, tree) for child in h3_tree_node.children.values()]
        if len(self.children) == 0:
            try:
                self.vol = self.tree.pop_df.loc[self.h3_node.h3_id]
            except KeyError:
                self.vol = 0
        else:
            self.vol = sum([c.vol for c in self.children])
        self.h3_node.vol = self.vol
        if len(self.children) == 0:
            self.flat_leaves_name = [self.h3_node.h3_id]
        else:
            self.flat_leaves_name = []
            for child in self.children:
                self.flat_leaves_name.extend(child.flat_leaves_name)
        self.error = self.compute_error()

    def compute_error(self):
        if self.vol == 0:
            return 0
        return (self.tree.target_vol - self.vol)**2

    def keep_subtree(self, keep_condition):
        if keep_condition(self):
            for c in self.children:
                c.keep_subtree(keep_condition)
        else:
            self.children = []

    def compute_best_split(self):
        self.split_this = False
        self.best_score = self.error
        if self.vol > 0:
            if len(self.children) == 0:
                self.split_this = False
            else:
                for c in self.children:
                    c.compute_best_split()
                split_score = sum([c.best_score for c in self.children])
                if split_score <= self.error:
                    self.split_this = True
                    self.best_score = split_score

    def flatten_leaves_rec(self, flat_leaves):
        if len(self.children) == 0:
            flat_leaves += [self]
        else:
            for c in self.children:
                c.flatten_leaves_rec(flat_leaves)


param = {
    'anon_thres': 10,
    'suppr_thres_frac': 0.1,
    'target_vol_o': 1000,
}

aggregator = H3SbaAggregator(
    od_matrix=od_matrix,
    tree_start=tree_start,
    tree_end=tree_end,
    param=param
)
# Out:
# C:\Users\dmc\AppData\Local\Temp\ipykernel_7208\4068854685.py:50: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   self.od_matrix_agg = pd.concat([self.od_matrix_agg, od_matrix_agg_timestep])
# C:\Users\dmc\AppData\Local\Temp\ipykernel_7208\4068854685.py:58: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   self.eval_df = pd.concat([self.eval_df, pd.DataFrame(eval_row, index=[len(self.eval_df)])])

# %%
od_matrix_agg = aggregator.od_matrix_agg

# %%
censored_rows = od_matrix_agg[od_matrix_agg["censored"] == True]
print(censored_rows)
# Out:
#                   coi              cdi  vol        weight  t  censored
# 2     871fb4640ffffff  871fb4671ffffff  5.0   9371.458158  0      True
# 3     871fb4640ffffff  871fb4675ffffff  1.0   2558.478648  0      True
# 4     871fb4640ffffff  871fb4670ffffff  3.0   7383.479119  0      True
# 6     871fb4640ffffff  871fb4672ffffff  4.0   6794.059745  0      True
# 8     871fb4640ffffff  871fb4673ffffff  3.0  18021.516601  0      True
# ...               ...              ...  ...           ... ..       ...
# 1170  871fb4758ffffff  881fb475cbfffff  4.0  13717.913262  0      True
# 1171  871fb4758ffffff  881fb475c7fffff  9.0   8533.801954  0      True
# 1174  871fb4758ffffff  881fb475d5fffff  4.0   7735.509406  0      True
# 1175  871fb4758ffffff  881fb475ddfffff  1.0   2127.667475  0      True
# 1178  871fb4758ffffff  881fb475d1fffff  1.0   3303.270685  0      True
#
# [936 rows x 6 columns]

# %%
suppressed_count = od_matrix_agg[od_matrix_agg["censored"] == True]["vol"].sum()
print(f"Totale volume soppresso: {suppressed_count}")
# Out:
# Totale volume soppresso: 3087.0

# %%
od_matrix_agg = od_matrix_agg[od_matrix_agg["censored"] == False]
od_matrix_agg = od_matrix_agg.rename(columns={
    "coi": "start_h3",
    "cdi": "end_h3",
    "vol": "count"
})

od_matrix_agg = od_matrix_agg.drop(columns=["t", "censored"], errors="ignore")
od_matrix_agg
# Out:
#              start_h3           end_h3   count        weight
# 0     871fb4644ffffff  841fb47ffffffff  2011.0  5.173206e+06
# 1     871fb4646ffffff  841fb47ffffffff  1394.0  4.506555e+06
# 5     871fb4640ffffff  871fb4676ffffff     0.0  0.000000e+00
# 7     871fb4640ffffff  871fb4674ffffff     0.0  0.000000e+00
# 10    871fb4640ffffff  881fb4644bfffff     0.0  0.000000e+00
# ...               ...              ...     ...           ...
# 1177  871fb4758ffffff  881fb475dbfffff     0.0  0.000000e+00
# 1179  871fb4758ffffff  881fb475d3fffff     0.0  0.000000e+00
# 1180  871fb475cffffff  841fb47ffffffff   167.0  4.003001e+05
# 1181  871fb475effffff  841fb47ffffffff   403.0  1.300340e+06
# 1182  871fb475dffffff  841fb47ffffffff   344.0  1.035581e+06
#
# [247 rows x 4 columns]

# %%
od_matrix_agg[od_matrix_agg['count'] == 0.0]
# Out:
#              start_h3           end_h3  count  weight
# 5     871fb4640ffffff  871fb4676ffffff    0.0     0.0
# 7     871fb4640ffffff  871fb4674ffffff    0.0     0.0
# 10    871fb4640ffffff  881fb4644bfffff    0.0     0.0
# 11    871fb4640ffffff  881fb4644dfffff    0.0     0.0
# 16    871fb4640ffffff  8a1fb4644677fff    0.0     0.0
# ...               ...              ...    ...     ...
# 1169  871fb4758ffffff  881fb475cdfffff    0.0     0.0
# 1172  871fb4758ffffff  881fb475c1fffff    0.0     0.0
# 1173  871fb4758ffffff  881fb475d9fffff    0.0     0.0
# 1177  871fb4758ffffff  881fb475dbfffff    0.0     0.0
# 1179  871fb4758ffffff  881fb475d3fffff    0.0     0.0
#
# [193 rows x 4 columns]

# %%
od_matrix_agg = od_matrix_agg[od_matrix_agg['count'] > 0.0]

# %%
import folium
import h3
import pandas as pd
import numpy as np

class H3FoliumODVisualizer:
    """
    Visualizza i risultati di od_matrix_agg su mappa Folium
    """
    def __init__(self, od_matrix_agg, center_lat=48.8566, center_lon=2.3522):
        """
        Args:
            od_matrix_agg: DataFrame con colonne ['start_h3', 'end_h3', 'count']
                           (eventualmente anche altre colonne come censored/t)
            center_lat, center_lon: centro della mappa (default: Torino)
        """
        self.od_matrix = od_matrix_agg.copy()
        self.center_lat = center_lat
        self.center_lon = center_lon
        
        # Calcola aggregati per origine e destinazione
        self.origin_data = self.od_matrix.groupby("start_h3")["count"].sum().to_dict()
        self.destination_data = self.od_matrix.groupby("end_h3")["count"].sum().to_dict()
        
        # Estrai coppie OD con flussi
        self.od_pairs = list(zip(
            self.od_matrix["start_h3"],
            self.od_matrix["end_h3"],
            self.od_matrix["count"]
        ))
        
        print(f"✅ Estratti {len(self.origin_data)} origini, {len(self.destination_data)} destinazioni, {len(self.od_pairs)} coppie OD")

    def _h3_to_geojson(self, h3_id: str) -> dict:
        """Converte un esagono H3 in GeoJSON"""
        boundary = h3.cell_to_boundary(h3_id)
        coords = [[[lon, lat] for lat, lon in boundary]]
        return {
            "type": "Feature",
            "geometry": {"type": "Polygon", "coordinates": coords},
            "properties": {"h3_id": h3_id, "resolution": h3.get_resolution(h3_id)},
        }

    def create_base_map(self, zoom_start=10) -> folium.Map:
        """Crea la mappa base"""
        m = folium.Map(
            location=[self.center_lat, self.center_lon],
            zoom_start=zoom_start,
            tiles="OpenStreetMap"
        )
        return m
    
    def add_origin_hexagons(self, m: folium.Map, alpha=0.6):
        """Aggiunge esagoni di origine"""
        sorted_origins = sorted(self.origin_data.items(), key=lambda x: x[1], reverse=True)
        if not sorted_origins:
            return
        
        flows = [f for _, f in sorted_origins]
        min_flow, max_flow = min(flows), max(flows)
        group = folium.FeatureGroup(name=f"Origini ({len(sorted_origins)})", show=True)
        
        for rank, (h3_id, flow) in enumerate(sorted_origins, 1):
            try:
                geojson = self._h3_to_geojson(h3_id)
                intensity = (flow - min_flow) / (max_flow - min_flow) if max_flow > min_flow else 1.0
                blue_intensity = int(255 * (0.3 + intensity * 0.7))
                fill_color = f"#{0:02x}{0:02x}{blue_intensity:02x}"
                
                folium.GeoJson(
                    geojson,
                    style_function=lambda x, c=fill_color: {
                        "fillColor": c,
                        "color": "darkblue",
                        "weight": 1,
                        "fillOpacity": alpha,
                        "opacity": 0.8
                    },
                    tooltip=f"Origine: {flow:,} viaggi",
                    popup=folium.Popup(
                        f"<b>Origine H3</b><br>ID: {h3_id}<br>"
                        f"Risoluzione: {h3.get_resolution(h3_id)}<br>"
                        f"Flusso totale: {flow:,}<br>"
                        f"Rank: {rank}",
                        max_width=250
                    )
                ).add_to(group)
            except Exception as e:
                print(f"⚠️ Errore con origine {h3_id}: {e}")
        
        group.add_to(m)

    def add_destination_hexagons(self, m: folium.Map, alpha=0.6):
        """Aggiunge esagoni di destinazione"""
        sorted_dests = sorted(self.destination_data.items(), key=lambda x: x[1], reverse=True)
        if not sorted_dests:
            return
        
        flows = [f for _, f in sorted_dests]
        min_flow, max_flow = min(flows), max(flows)
        group = folium.FeatureGroup(name=f"Destinazioni ({len(sorted_dests)})", show=True)
        
        for rank, (h3_id, flow) in enumerate(sorted_dests, 1):
            try:
                geojson = self._h3_to_geojson(h3_id)
                intensity = (flow - min_flow) / (max_flow - min_flow) if max_flow > min_flow else 1.0
                red_intensity = int(255 * (0.3 + intensity * 0.7))
                fill_color = f"#{red_intensity:02x}{0:02x}{0:02x}"
                
                folium.GeoJson(
                    geojson,
                    style_function=lambda x, c=fill_color: {
                        "fillColor": c,
                        "color": "darkred",
                        "weight": 1,
                        "fillOpacity": alpha,
                        "opacity": 0.8
                    },
                    tooltip=f"Destinazione: {flow:,} viaggi",
                    popup=folium.Popup(
                        f"<b>Destinazione H3</b><br>ID: {h3_id}<br>"
                        f"Risoluzione: {h3.get_resolution(h3_id)}<br>"
                        f"Flusso totale: {flow:,}<br>"
                        f"Rank: {rank}",
                        max_width=250
                    )
                ).add_to(group)
            except Exception as e:
                print(f"⚠️ Errore con destinazione {h3_id}: {e}")
        
        group.add_to(m)

# %%
visualizer = H3FoliumODVisualizer(od_matrix_agg)

mappa = visualizer.create_base_map(zoom_start=11)

visualizer.add_origin_hexagons(mappa)
visualizer.add_destination_hexagons(mappa)

folium.LayerControl(collapsed=False).add_to(mappa)

mappa
# Out:
# ✅ Estratti 34 origini, 29 destinazioni, 54 coppie OD
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ab583aeb9060824866691c24b743b5ca {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ab583aeb9060824866691c24b743b5ca&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ab583aeb9060824866691c24b743b5ca = L.map(
#                 &quot;map_ab583aeb9060824866691c24b743b5ca&quot;,
#                 {
#                     center: [48.8566, 2.3522],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 11,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e95213f3e428d6b7d3fc64d6201a28d5 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_e95213f3e428d6b7d3fc64d6201a28d5.addTo(map_ab583aeb9060824866691c24b743b5ca);
#
#
#             var feature_group_aadb27713a40c128efebbdbcbb443872 = L.featureGroup(
#                 {
# }
#             );
#
#
#         function geo_json_056803739925258a57a6b9d52ee74272_styler(feature) {
#             switch(feature.properties.h3_id) {
#                 default:
#                     return {&quot;color&quot;: &quot;darkblue&quot;, &quot;fillColor&quot;: &quot;#0000ff&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 0.8, &quot;weight&quot;: 1};
#             }
#         }
#
#         function geo_json_056803739925258a57a6b9d52ee74272_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_056803739925258a57a6b9d52ee74272 = L.geoJson(null, {
#                 onEachFeature: geo_json_056803739925258a57a6b9d52ee74272_onEachFeature,
#
#                 style: geo_json_056803739925258a57a6b9d52ee74272_styler,
#             ...{
# }
#         });
#
#         function geo_json_056803739925258a57a6b9d52ee74272_add (data) {
#             geo_json_056803739925258a57a6b9d52ee74272
#                 .addData(data);
#         }
#             geo_json_056803739925258a57a6b9d52ee74272_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[2.3566379878109576, 48.872358853032914], [2.3426788320360767, 48.865563138551636], [2.34501524871865, 48.853193823762325], [2.3613039682833943, 48.84762155340606], [2.37525849778537, 48.85441646318688], [2.372928933615189, 48.86678444763622]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;properties&quot;: {&quot;h3_id&quot;: &quot;871fb4662ffffff&quot;, &quot;resolution&quot;: 7}, &quot;type&quot;: &quot;Feature&quot;}], &quot;type&quot;: &quot;FeatureCollection&quot;});
#
#
#
#             geo_json_056803739925258a57a6b9d52ee74272.bindTooltip(
#                 `&lt;div&gt;
#                      Origine: 2,605.0 viaggi
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#         var popup_54262dcd2f5c7b528fbc53fad128cf55 = L.popup({
#   &quot;maxWidth&quot;: 250,
# });
#
#
#
#                 var html_eef6833bcf08517ab02bc6d762446a4e = $(`&lt;div id=&quot;html_eef6833bcf08517ab02bc6d762446a4e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Origine H3&lt;/b&gt;&lt;br&gt;ID: 871fb4662ffffff&lt;br&gt;Risoluzione: 7&lt;br&gt;Flusso totale: 2,605.0&lt;br&gt;Rank: 1&lt;/div&gt;`)[0];
#                 popup_54262dcd2f5c7b528fbc53fad128cf55.setContent(html_eef6833bcf08517ab02bc6d762446a4e);
#
#
#
#         geo_json_056803739925258a57a6b9d52ee74272.bindPopup(popup_54262dcd2f5c7b528fbc53fad128cf55)
#         ;
#
#
#
#
#             geo_json_056803739925258a57a6b9d52ee74272.addTo(feature_group_aadb27713a40c128efebbdbcbb443872);
#
#
#         function geo_json_c40c4745786621dcb237bc6cda02363a_styler(feature) {
#             switch(feature.properties.h3_id) {
#                 default:
#                     return {&quot;color&quot;: &quot;darkblue&quot;, &quot;fillColor&quot;: &quot;#0000d6&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 0.8, &quot;weight&quot;: 1};
#             }
#         }
#
#         function geo_json_c40c4745786621dcb237bc6cda02363a_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_c40c4745786621dcb237bc6cda02363a = L.geoJson(null, {
#                 onEachFeature: geo_json_c40c4745786621dcb237bc6cda02363a_onEachFeature,
#
#                 style: geo_json_c40c4745786621dcb237bc6cda02363a_styler,
#             ...{
# }
#         });
#
#         function geo_json_c40c4745786621dcb237bc6cda02363a_add (data) {
#             geo_json_c40c4745786621dcb237bc6cda02363a
#                 .addData(data);
#         }
#             geo_json_c40c4745786621dcb237bc6cda02363a_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[2.37525849778537, 48.85441646318688], [2.3613039682833943, 48.84762155340606], [2.363635443411, 48.835251700782784], [2.3799146007280148, 48.82967809012165], [2.393864503984397, 48.836472196631405], [2.3915398757874975, 48.848840716685864

# %%
import numpy as np
import pandas as pd

def compute_discernability_and_cavg(df: pd.DataFrame, k: int, suppressed_count: int = 0) -> dict:
    """
    Calcola C_DM e C_AVG per un dataset OD generalizzato.
    
    Args:
        df: DataFrame con colonne ['start_h3', 'end_h3', 'count']
        k: soglia k-anonimity
        suppressed_count: numero di coppie OD soppressi (facoltativo)
    
    Returns:
        dict con C_DM, C_AVG, numero totale record e classi equivalenza
    """
    counts = df['count'].values
    total_records = counts.sum() + suppressed_count
    total_equiv_classes = len(counts) + suppressed_count
    total_records_avg = counts.sum()
    total_equiv_classes_avg = len(counts)
    
    # C_DM: somma dei quadrati dei count >= k
    k_anonymous_counts = counts[counts >= k]
    c_dm_gen = np.sum(k_anonymous_counts**2)
    
    # Penalità per record soppressi
    suppression_penalty = suppressed_count * counts.sum() # ogni record soppresso "costa" quanto l'intero dataset
    c_dm = c_dm_gen + suppression_penalty
    
    # C_AVG: (total_records / total_equiv_classes) / k
    c_avg = (total_records_avg / total_equiv_classes_avg) / k if total_equiv_classes_avg > 0 else float('inf')
    
    return {
        'C_DM': c_dm,
        'C_AVG': c_avg,
        'total_records': total_records,
        'total_equivalence_classes': total_equiv_classes,
        'k': k
    }

# Esempio di utilizzo
metrics = compute_discernability_and_cavg(od_matrix_agg, k=10, suppressed_count=suppressed_count)
print("\n📊 Metrics di Discernibilità e CAVG:")
print(f"C_DM: {metrics['C_DM']:,}")
print(f"C_AVG: {metrics['C_AVG']:.4f}")
# Out:
# 📊 Metrics di Discernibilità e CAVG:
# C_DM: 111,826,844.0
# C_AVG: 46.5111

# %%
from geopy.distance import geodesic

def calculate_generalization_distance_metric(df: pd.DataFrame, od_matrix_generalized: pd.DataFrame) -> Dict:
   
   print("🔍 Calcolo metrica di distanza post-generalizzazione...")
   
   # 1. Crea mapping da esagoni originali a esagoni generalizzati
   start_original_to_generalized = {}
   end_original_to_generalized = {}
   
   # Ottieni tutti gli esagoni generalizzati unici
   generalized_start_h3 = set(od_matrix_generalized['start_h3'].unique())
   generalized_end_h3 = set(od_matrix_generalized['end_h3'].unique())
   
   # Per ogni esagono originale, trova l'esagono generalizzato corrispondente
   unique_start_h3 = df['start_h3'].unique()
   unique_end_h3 = df['end_h3'].unique()
   
   print(f"📊 Mappatura {len(unique_start_h3)} esagoni origine...")
   for original_h3 in unique_start_h3:
       generalized_h3 = find_generalized_hexagon(original_h3, generalized_start_h3)
       if generalized_h3:
           start_original_to_generalized[original_h3] = generalized_h3
   
   print(f"📊 Mappatura {len(unique_end_h3)} esagoni destinazione...")
   for original_h3 in unique_end_h3:
       generalized_h3 = find_generalized_hexagon(original_h3, generalized_end_h3)
       if generalized_h3:
           end_original_to_generalized[original_h3] = generalized_h3
   
   # 3. Calcola distanze per i punti di partenza
   start_distances = []
   start_coords = []
   
   for idx, row in df.iterrows():
       original_h3 = row['start_h3']
       original_coords = (row['start_lat'], row['start_lon'])
       
       if original_h3 in start_original_to_generalized:
           generalized_h3 = start_original_to_generalized[original_h3]
           generalized_coords = h3.cell_to_latlng(generalized_h3)
           
           distance = geodesic(original_coords, generalized_coords).meters
           
           start_distances.append(distance)
           start_coords.append({
               'original_h3': original_h3,
               'generalized_h3': generalized_h3,
               'original_coords': original_coords,
               'generalized_coords': generalized_coords,
               'distance': distance
           })
   
   # 4. Calcola distanze per i punti di destinazione
   end_distances = []
   end_coords = []
   
   for idx, row in df.iterrows():
       original_h3 = row['end_h3']
       original_coords = (row['end_lat'], row['end_lon'])
       
       if original_h3 in end_original_to_generalized:
           generalized_h3 = end_original_to_generalized[original_h3]
           generalized_coords = h3.cell_to_latlng(generalized_h3)
           
           distance = geodesic(original_coords, generalized_coords).meters
               
           end_distances.append(distance)
           end_coords.append({
               'original_h3': original_h3,
               'generalized_h3': generalized_h3,
               'original_coords': original_coords,
               'generalized_coords': generalized_coords,
               'distance': distance
           })
   
   # 5. Calcola statistiche
   results = {
       'start_distances': {
           'mean': np.mean(start_distances) if start_distances else 0,
           'median': np.median(start_distances) if start_distances else 0,
           'std': np.std(start_distances) if start_distances else 0,
           'min': np.min(start_distances) if start_distances else 0,
           'max': np.max(start_distances) if start_distances else 0,
           'count': len(start_distances)
       },
       'end_distances': {
           'mean': np.mean(end_distances) if end_distances else 0,
           'median': np.median(end_distances) if end_distances else 0,
           'std': np.std(end_distances) if end_distances else 0,
           'min': np.min(end_distances) if end_distances else 0,
           'max': np.max(end_distances) if end_distances else 0,
           'count': len(end_distances)
       },
       'overall': {
           'mean': np.mean(start_distances + end_distances) if (start_distances or end_distances) else 0,
           'median': np.median(start_distances + end_distances) if (start_distances or end_distances) else 0,
           'std': np.std(start_distances + end_distances) if (start_distances or end_distances) else 0,
           'total_points': len(start_distances) + len(end_distances)
       },
       'mappings': {
           'start_original_to_generalized': start_original_to_generalized,
           'end_original_to_generalized': end_original_to_generalized
       },
       'detailed_coords': {
           'start': start_coords,
           'end': end_coords
       }
   }
   
   # 6. Stampa risultati
   print("\n" + "="*60)
   print("📏 METRICHE DI DISTANZA POST-GENERALIZZAZIONE")
   print("="*60)
   
   print(f"\n🎯 PUNTI DI PARTENZA:")
   print(f"   • Distanza media: {results['start_distances']['mean']:.2f} metri")
   print(f"   • Distanza mediana: {results['start_distances']['median']:.2f} metri")
   print(f"   • Deviazione standard: {results['start_distances']['std']:.2f} metri")
   print(f"   • Min-Max: {results['start_distances']['min']:.2f} - {results['start_distances']['max']:.2f} metri")
   print(f"   • Punti analizzati: {results['start_distances']['count']:,}")
   
   print(f"\n🏁 PUNTI DI DESTINAZIONE:")
   print(f"   • Distanza media: {results['end_distances']['mean']:.2f} metri")
   print(f"   • Distanza mediana: {results['end_distances']['median']:.2f} metri")
   print(f"   • Deviazione standard: {results['end_distances']['std']:.2f} metri")
   print(f"   • Min-Max: {results['end_distances']['min']:.2f} - {results['end_distances']['max']:.2f} metri")
   print(f"   • Punti analizzati: {results['end_distances']['count']:,}")
   
   print(f"\n🌍 COMPLESSIVO:")
   print(f"   • Distanza media totale: {results['overall']['mean']:.2f} metri")
   print(f"   • Distanza mediana totale: {results['overall']['median']:.2f} metri")
   print(f"   • Deviazione standard totale: {results['overall']['std']:.2f} metri")
   print(f"   • Punti totali: {results['overall']['total_points']:,}")
   
   return results

def find_generalized_hexagon(original_h3: str, generalized_hexagons: set) -> str:
   """
   Trova l'esagono generalizzato corrispondente a un esagono originale
   """
   # Se l'esagono è già nella lista degli esagoni generalizzati
   if original_h3 in generalized_hexagons:
       return original_h3
   
   # Altrimenti cerca tra tutti gli esagoni generalizzati se l'originale è loro discendente
   for generalized_h3 in generalized_hexagons:
       if is_descendant_of(original_h3, generalized_h3):
           return generalized_h3
   
   return None

def is_descendant_of(child_h3: str, parent_h3: str) -> bool:
   """
   Controlla se child_h3 è discendente di parent_h3
   """
   child_res = h3.get_resolution(child_h3)
   parent_res = h3.get_resolution(parent_h3)
   
   if parent_res >= child_res:
       return False
   
   current = child_h3
   while h3.get_resolution(current) > parent_res:
       current = h3.cell_to_parent(current, h3.get_resolution(current) - 1)
   
   return current == parent_h3

def analyze_generalization_impact(results: Dict) -> None:
   """
   Analizza l'impatto della generalizzazione sulle distanze
   """
   print("\n" + "="*60)
   print("📊 ANALISI IMPATTO GENERALIZZAZIONE")
   print("="*60)
   
   # Calcola percentili
   all_distances = []
   for coord in results['detailed_coords']['start'] + results['detailed_coords']['end']:
       all_distances.append(coord['distance'])
   
   if all_distances:
       percentiles = [25, 50, 75, 90, 95, 99]
       print("\n📏 Distribuzione distanze:")
       for p in percentiles:
           value = np.percentile(all_distances, p)
           print(f"   • {p}° percentile: {value:.2f} metri")
   
   # Analizza per risoluzione
   resolution_analysis = {}
   for coord in results['detailed_coords']['start'] + results['detailed_coords']['end']:
       original_res = h3.get_resolution(coord['original_h3'])
       generalized_res = h3.get_resolution(coord['generalized_h3'])
       
       key = f"{original_res}→{generalized_res}"
       if key not in resolution_analysis:
           resolution_analysis[key] = []
       resolution_analysis[key].append(coord['distance'])
   
   print("\n🔍 Analisi per risoluzione:")
   for resolution_change, distances in resolution_analysis.items():
       mean_dist = np.mean(distances)
       count = len(distances)
       print(f"   • {resolution_change}: {mean_dist:.2f}m (n={count})")

distance_results = calculate_generalization_distance_metric(
   df=filtered_df, 
   od_matrix_generalized=od_matrix_agg
)

analyze_generalization_impact(distance_results)
# Out:
# 🔍 Calcolo metrica di distanza post-generalizzazione...
# 📊 Mappatura 6624 esagoni origine...
# 📊 Mappatura 6651 esagoni destinazione...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[17], line 206
#     203        count = len(distances)
#     204        print(f"   • {resolution_change}: {mean_dist:.2f}m (n={count})")
# --> 206 distance_results = calculate_generalization_distance_metric(
#     207    df=filtered_df,
#     208    od_matrix_generalized=od_matrix_agg
#     209 )
#     211 analyze_generalization_impact(distance_results)
#
# Cell In[17], line 43, in calculate_generalization_distance_metric(df, od_matrix_generalized)
#      40 generalized_h3 = start_original_to_generalized[original_h3]
#      41 generalized_coords = h3.cell_to_latlng(generalized_h3)
# ---> 43 distance = geodesic(original_coords, generalized_coords).meters
#      45 start_distances.append(distance)
#      46 start_coords.append({
#      47     'original_h3': original_h3,
#      48     'generalized_h3': generalized_h3,
#    (...)     51     'distance': distance
#      52 })
#
# File c:\Users\dmc\AppData\Local\Programs\Python\Python311\Lib\site-packages\geopy\distance.py:540, in geodesic.__init__(self, *args, **kwargs)
#     538 self.set_ellipsoid(kwargs.pop('ellipsoid', 'WGS-84'))
#     539 major, minor, f = self.ELLIPSOID
# --> 540 super().__init__(*args, **kwargs)
#
# File c:\Users\dmc\AppData\Local\Programs\Python\Python311\Lib\site-packages\geopy\distance.py:276, in Distance.__init__(self, *args, **kwargs)
#     274 elif len(args) > 1:
#     275     for a, b in util.pairwise(args):
# --> 276         kilometers += self.measure(a, b)
#     278 kilometers += units.kilometers(**kwargs)
#     279 self.__kilometers = kilometers
#
# File c:\Users\dmc\AppData\Local\Programs\Python\Python311\Lib\site-packages\geopy\distance.py:566, in geodesic.measure(self, a, b)
#     561 if not (isinstance(self.geod, Geodesic) and
#     562         self.geod.a == self.ELLIPSOID[0] and
#     563         self.geod.f == self.ELLIPSOID[2]):
#     564     self.geod = Geodesic(self.ELLIPSOID[0], self.ELLIPSOID[2])
# --> 566 s12 = self.geod.Inverse(lat1, lon1, lat2, lon2,
#     567                         Geodesic.DISTANCE)['s12']
#     569 return s12
#
# File c:\Users\dmc\AppData\Local\Programs\Python\Python311\Lib\site-packages\geographiclib\geodesic.py:1030, in Geodesic.Inverse(self, lat1, lon1, lat2, lon2, outmask)
#    1012 def Inverse(self, lat1, lon1, lat2, lon2,
#    1013             outmask = GeodesicCapability.STANDARD):
#    1014   """Solve the inverse geodesic problem
#    1015
#    1016   :param lat1: latitude of the first point in degrees
#    (...)   1027
#    1028   """
# -> 1030   a12, s12, salp1,calp1, salp2,calp2, m12, M12, M21, S12 = self._GenInverse(
#    1031     lat1, lon1, lat2, lon2, outmask)
#    1032   outmask &= Geodesic.OUT_MASK
#    1033   if outmask & Geodesic.LONG_UNROLL:
#
# File c:\Users\dmc\AppData\Local\Programs\Python\Python311\Lib\site-packages\geographiclib\geodesic.py:769, in Geodesic._GenInverse(self, lat1, lon1, lat2, lon2, outmask)
#     766     cbet2 = cbet1
#     768 dn1 = math.sqrt(1 + self._ep2 * Math.sq(sbet1))
# --> 769 dn2 = math.sqrt(1 + self._ep2 * Math.sq(sbet2))
#     771 # real a12, sig12, calp1, salp1, calp2, salp2
#     772 # index zero elements of these arrays are unused
#     773 C1a = list(range(Geodesic.nC1_ + 1))
#
# File c:\Users\dmc\AppData\Local\Programs\Python\Python311\Lib\site-packages\geographiclib\geomath.py:22, in Math.sq(x)
#      17 class Math:
#      18   """
#      19   Additional math routines for GeographicLib.
#      20   """
# ---> 22   @staticmethod
#      23   def sq(x):
#      24     """Square a number"""
#      26     return x * x
#
# KeyboardInterrupt:

# %%
import pandas as pd
import h3

class GeneralizationMetric:
    """
    Ḡ = (1/V+) × Σ(|o| + |d|) × v_{o→d}
    """
    def __init__(self, k_threshold: int = 10):
        self.k_threshold = k_threshold

    def calculate_generalization_error(self, od_matrix_generalized: pd.DataFrame, od_matrix: pd.DataFrame) -> float:
        # Costruisci dizionari: generalizzato -> numero di celle originali
        origin_counts = self._build_hexagon_counts(
            od_matrix_generalized, od_matrix, column_gen="start_h3", column_orig="start_h3"
        )
        destination_counts = self._build_hexagon_counts(
            od_matrix_generalized, od_matrix, column_gen="end_h3", column_orig="end_h3"
        )

        total_volume_anonymous = 0
        weighted_count_sum = 0

        for _, row in od_matrix_generalized.iterrows():
            flow_value = row["count"]
            if flow_value >= self.k_threshold:
                origin_h3 = row["start_h3"]
                dest_h3   = row["end_h3"]

                origin_count = origin_counts.get(origin_h3, 1)
                dest_count   = destination_counts.get(dest_h3, 1)

                total_volume_anonymous += flow_value
                weighted_count_sum += (origin_count + dest_count) * flow_value

        return weighted_count_sum / total_volume_anonymous if total_volume_anonymous > 0 else 0.0

    def _build_hexagon_counts(
        self, od_matrix_generalized: pd.DataFrame, od_matrix: pd.DataFrame, 
        column_gen: str, column_orig: str
    ) -> dict:
        """
        Conta quanti esagoni originali appartengono a ciascun esagono generalizzato
        """
        generalized_hexagons = od_matrix_generalized[column_gen].unique()
        original_hexagons = od_matrix[column_orig].unique()

        counts = {}
        for gen_hex in generalized_hexagons:
            target_res = h3.get_resolution(gen_hex)

            # Trova tutti i parent degli originali alla risoluzione target
            parent_series = [h3.cell_to_parent(h, target_res) for h in original_hexagons]

            # Conta quante volte compare il parent == gen_hex
            count = sum(1 for p in parent_series if p == gen_hex)
            counts[gen_hex] = max(count, 1)  # fallback a 1

        return counts


# Esempio di utilizzo:
metric = GeneralizationMetric(k_threshold=10)
error = metric.calculate_generalization_error(od_matrix_agg, od_matrix)
print(f"Errore di generalizzazione medio Ḡ: {error:.3f}")
# Out:
# Errore di generalizzazione medio Ḡ: 6807.563

# %%
import pandas as pd
import h3
from collections import defaultdict

def fast_reconstruction_loss(original_od_df: pd.DataFrame,
                                       od_matrix_generalized: pd.DataFrame) -> float:
    """
    Calcola la reconstruction loss includendo anche le celle con 0 viaggi.
    Versione ottimizzata, evita itertools.product su tutte le foglie.
    """
    # Dizionario dei flussi originali
    original_flows = {(row['start_h3'], row['end_h3']): row['count']
                      for _, row in original_od_df.iterrows()}

    total_volume = sum(original_flows.values())
    if total_volume == 0:
        return 0.0

    # Dizionario dei flussi generalizzati
    generalized_flows = {(row['start_h3'], row['end_h3']): row['count']
                         for _, row in od_matrix_generalized.iterrows()}

    gen_start_hexes = od_matrix_generalized['start_h3'].unique()
    gen_end_hexes   = od_matrix_generalized['end_h3'].unique()

    # Cache: gen_hex → leaves
    leaf_cache = {}

    def get_leaves(gen_hex, target_res):
        key = (gen_hex, target_res)
        if key in leaf_cache:
            return leaf_cache[key]
        res = h3.get_resolution(gen_hex)
        leaves = {gen_hex} if res == target_res else set(h3.cell_to_children(gen_hex, target_res))
        leaf_cache[key] = leaves
        return leaves

    # Risoluzione target
    target_res_start = h3.get_resolution(original_od_df['start_h3'].iloc[0])
    target_res_end   = h3.get_resolution(original_od_df['end_h3'].iloc[0])

    # Precompute mappe: leaf → parent generalized
    start_leaf_to_parent = {}
    for gen in gen_start_hexes:
        for leaf in get_leaves(gen, target_res_start):
            start_leaf_to_parent[leaf] = gen

    end_leaf_to_parent = {}
    for gen in gen_end_hexes:
        for leaf in get_leaves(gen, target_res_end):
            end_leaf_to_parent[leaf] = gen

    total_abs_error = 0.0

    # Itera solo sulle coppie presenti nell'originale
    for (s, d), true_count in original_flows.items():
        gen_s = start_leaf_to_parent.get(s)
        gen_d = end_leaf_to_parent.get(d)

        if gen_s is None or gen_d is None:
            reconstructed_count = 0.0
        else:
            gen_count = generalized_flows.get((gen_s, gen_d), 0.0)
            start_leaves = get_leaves(gen_s, target_res_start)
            end_leaves   = get_leaves(gen_d, target_res_end)
            reconstructed_count = gen_count / (len(start_leaves) * len(end_leaves))

        total_abs_error += abs(reconstructed_count - true_count)

    # Aggiungi errore per le coppie con count=0 nei generalized flows
    for (gen_s, gen_d), gen_count in generalized_flows.items():
        start_leaves = get_leaves(gen_s, target_res_start)
        end_leaves   = get_leaves(gen_d, target_res_end)
        count_per_leaf = gen_count / (len(start_leaves) * len(end_leaves))

        # Sottrai le coppie già contate
        for s in start_leaves:
            for d in end_leaves:
                if (s, d) not in original_flows:
                    total_abs_error += abs(count_per_leaf - 0.0)

    return total_abs_error / total_volume

loss = fast_reconstruction_loss(
    original_od_df=od_matrix,
    od_matrix_generalized=od_matrix_agg
)
print(f"Reconstruction Loss: {loss:.6f}")
# Out:
# Reconstruction Loss: 1.890015

# %% [markdown]
# ### Metriche con weight

# %%
import numpy as np
import pandas as pd

def compute_discernability_and_cavg(df: pd.DataFrame, k: int, suppressed_count: int = 0) -> dict:
    """
    Calcola C_DM e C_AVG per un dataset OD generalizzato.
    
    Args:
        df: DataFrame con colonne ['start_h3', 'end_h3', 'count']
        k: soglia k-anonimity
        suppressed_count: numero di coppie OD soppressi (facoltativo)
    
    Returns:
        dict con C_DM, C_AVG, numero totale record e classi equivalenza
    """
    counts = df['weight'].values
    total_records = counts.sum() + suppressed_count
    total_equiv_classes = len(counts) + suppressed_count
    total_records_avg = counts.sum()
    total_equiv_classes_avg = len(counts)
    
    # C_DM: somma dei quadrati dei count >= k
    k_anonymous_counts = counts[counts >= k]
    c_dm_gen = np.sum(k_anonymous_counts**2)
    
    # Penalità per record soppressi
    suppression_penalty = suppressed_count * counts.sum() # ogni record soppresso "costa" quanto l'intero dataset
    c_dm = c_dm_gen + suppression_penalty
    
    # C_AVG: (total_records / total_equiv_classes) / k
    c_avg = (total_records_avg / total_equiv_classes_avg) / k if total_equiv_classes_avg > 0 else float('inf')
    
    return {
        'C_DM': c_dm,
        'C_AVG': c_avg,
        'total_records': total_records,
        'total_equivalence_classes': total_equiv_classes,
        'k': k
    }

# Esempio di utilizzo
metrics = compute_discernability_and_cavg(od_matrix_agg, k=10*media_peso, suppressed_count=suppressed_count)
print("\n📊 Metrics di Discernibilità e CAVG:")
print(f"C_DM: {metrics['C_DM']:,}")
print(f"C_AVG: {metrics['C_AVG']:.4f}")
# Out:
# 📊 Metrics di Discernibilità e CAVG:
# C_DM: 221,856,985,347,188.62
# C_AVG: 44.2496

# %%
import pandas as pd
import h3

class GeneralizationMetric:
    """
    Ḡ = (1/V+) × Σ(|o| + |d|) × v_{o→d}
    """
    def __init__(self, k_threshold: int = 10):
        self.k_threshold = k_threshold

    def calculate_generalization_error(self, od_matrix_generalized: pd.DataFrame, od_matrix: pd.DataFrame) -> float:
        # Costruisci dizionari: generalizzato -> numero di celle originali
        origin_counts = self._build_hexagon_counts(
            od_matrix_generalized, od_matrix, column_gen="start_h3", column_orig="start_h3"
        )
        destination_counts = self._build_hexagon_counts(
            od_matrix_generalized, od_matrix, column_gen="end_h3", column_orig="end_h3"
        )

        total_volume_anonymous = 0
        weighted_count_sum = 0

        for _, row in od_matrix_generalized.iterrows():
            flow_value = row["weight"]
            if flow_value >= self.k_threshold:
                origin_h3 = row["start_h3"]
                dest_h3   = row["end_h3"]

                origin_count = origin_counts.get(origin_h3, 1)
                dest_count   = destination_counts.get(dest_h3, 1)

                total_volume_anonymous += flow_value
                weighted_count_sum += (origin_count + dest_count) * flow_value

        return weighted_count_sum / total_volume_anonymous if total_volume_anonymous > 0 else 0.0

    def _build_hexagon_counts(
        self, od_matrix_generalized: pd.DataFrame, od_matrix: pd.DataFrame, 
        column_gen: str, column_orig: str
    ) -> dict:
        """
        Conta quanti esagoni originali appartengono a ciascun esagono generalizzato
        """
        generalized_hexagons = od_matrix_generalized[column_gen].unique()
        original_hexagons = od_matrix[column_orig].unique()

        counts = {}
        for gen_hex in generalized_hexagons:
            target_res = h3.get_resolution(gen_hex)

            # Trova tutti i parent degli originali alla risoluzione target
            parent_series = [h3.cell_to_parent(h, target_res) for h in original_hexagons]

            # Conta quante volte compare il parent == gen_hex
            count = sum(1 for p in parent_series if p == gen_hex)
            counts[gen_hex] = max(count, 1)  # fallback a 1

        return counts


# Esempio di utilizzo:
metric = GeneralizationMetric(k_threshold=10*media_peso)
error = metric.calculate_generalization_error(od_matrix_agg, od_matrix)
print(f"Errore di generalizzazione medio Ḡ: {error:.3f}")
# Out:
# Errore di generalizzazione medio Ḡ: 6824.498

# %%
import pandas as pd
import h3
from collections import defaultdict

def fast_reconstruction_loss(original_od_df: pd.DataFrame,
                                       od_matrix_generalized: pd.DataFrame) -> float:
    """
    Calcola la reconstruction loss includendo anche le celle con 0 viaggi.
    Versione ottimizzata, evita itertools.product su tutte le foglie.
    """
    # Dizionario dei flussi originali
    original_flows = {(row['start_h3'], row['end_h3']): row['total_weight']
                      for _, row in original_od_df.iterrows()}

    total_volume = sum(original_flows.values())
    if total_volume == 0:
        return 0.0

    # Dizionario dei flussi generalizzati
    generalized_flows = {(row['start_h3'], row['end_h3']): row['weight']
                         for _, row in od_matrix_generalized.iterrows()}

    gen_start_hexes = od_matrix_generalized['start_h3'].unique()
    gen_end_hexes   = od_matrix_generalized['end_h3'].unique()

    # Cache: gen_hex → leaves
    leaf_cache = {}

    def get_leaves(gen_hex, target_res):
        key = (gen_hex, target_res)
        if key in leaf_cache:
            return leaf_cache[key]
        res = h3.get_resolution(gen_hex)
        leaves = {gen_hex} if res == target_res else set(h3.cell_to_children(gen_hex, target_res))
        leaf_cache[key] = leaves
        return leaves

    # Risoluzione target
    target_res_start = h3.get_resolution(original_od_df['start_h3'].iloc[0])
    target_res_end   = h3.get_resolution(original_od_df['end_h3'].iloc[0])

    # Precompute mappe: leaf → parent generalized
    start_leaf_to_parent = {}
    for gen in gen_start_hexes:
        for leaf in get_leaves(gen, target_res_start):
            start_leaf_to_parent[leaf] = gen

    end_leaf_to_parent = {}
    for gen in gen_end_hexes:
        for leaf in get_leaves(gen, target_res_end):
            end_leaf_to_parent[leaf] = gen

    total_abs_error = 0.0

    # Itera solo sulle coppie presenti nell'originale
    for (s, d), true_count in original_flows.items():
        gen_s = start_leaf_to_parent.get(s)
        gen_d = end_leaf_to_parent.get(d)

        if gen_s is None or gen_d is None:
            reconstructed_count = 0.0
        else:
            gen_count = generalized_flows.get((gen_s, gen_d), 0.0)
            start_leaves = get_leaves(gen_s, target_res_start)
            end_leaves   = get_leaves(gen_d, target_res_end)
            reconstructed_count = gen_count / (len(start_leaves) * len(end_leaves))

        total_abs_error += abs(reconstructed_count - true_count)

    # Aggiungi errore per le coppie con count=0 nei generalized flows
    for (gen_s, gen_d), gen_count in generalized_flows.items():
        start_leaves = get_leaves(gen_s, target_res_start)
        end_leaves   = get_leaves(gen_d, target_res_end)
        count_per_leaf = gen_count / (len(start_leaves) * len(end_leaves))

        # Sottrai le coppie già contate
        for s in start_leaves:
            for d in end_leaves:
                if (s, d) not in original_flows:
                    total_abs_error += abs(count_per_leaf - 0.0)

    return total_abs_error / total_volume

loss = fast_reconstruction_loss(
    original_od_df=od_matrix,
    od_matrix_generalized=od_matrix_agg
)
print(f"Reconstruction Loss: {loss:.6f}")
# Out:
# Reconstruction Loss: 1.879069
